# %% [markdown]
# Run the following commands in the terminal
# - ``` pip install selenium ```
# - ``` pip install webdriver-manager ```

# %%
import csv
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
url = "https://apps.bostonglobe.com/graphics/2020/law-enforcement/index.html?initialWidth=962&childId=police-embed&parentTitle=Database%3A%20Search%2010%20years%27%20worth%20of%20Boston%20Police%20Department%20disciplinary%20action&parentUrl=https%3A%2F%2Fwww.bostonglobe.com%2F2020%2F11%2F24%2Fmetro%2Fheres-searchable-database-boston-police-department-internal-investigations-disciplinary-actions-more%2F#detail"

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)

link = driver.find_element_by_link_text('Detail')
link.click()

data = []
stop = False
while not stop:
    name = driver.find_element_by_class_name("detail-name").text
    rank = driver.find_element_by_class_name("detail-rank").text
    race = driver.find_element_by_class_name("detail-race").text

    rows = driver.find_elements_by_xpath("//table/tbody/tr")
    for row in rows:
        year = row.find_elements_by_tag_name("td")[0].text
        caseID = row.find_elements_by_tag_name("td")[1].text
        typeMisconduct = row.find_elements_by_tag_name("td")[2].text
        outcome = row.find_elements_by_tag_name("td")[6].text

        data.append([name, rank, race, year, caseID, typeMisconduct, outcome])

    if name == "Peter A Zographos":
        stop = True 
    else:
        button = driver.find_element_by_id("next-officer-button")
        button.click()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [/Users/rachelpeng/.wdm/drivers/chromedriver/mac64/88.0.4324.96/chromedriver] found in cache

# %%
print(data)
# Out:
# [['Joseph Abasciano', 'Police Officer', 'White', '2011', 'IAD2011-0182', 'Citizen complaint', ''], ['Joseph Abasciano', 'Police Officer', 'White', '2011', 'IAD2011-0182', 'Citizen complaint', ''], ['Joseph Abasciano', 'Police Officer', 'White', '2013', 'IAD2013-0019', 'Citizen complaint', ''], ['Joseph Abasciano', 'Police Officer', 'White', '2019', 'IAD2019-0085', 'Citizen complaint', ''], ['Ramadani Abdul-Aziz', 'Police Officer', 'Black', '2011', 'IAD2011-0258', 'Citizen complaint', 'Oral Reprimand'], ['Ramadani Abdul-Aziz', 'Police Officer', 'Black', '2017', 'IAD2017-0431', 'Internal investigation', 'Oral Reprimand'], ['Patrick Olaf Abrahamson', 'Police Officer', 'White', '2015', 'IAD2015-0109', 'Citizen complaint', ''], ['Patrick Olaf Abrahamson', 'Police Officer', 'White', '2015', 'IAD2015-0109', 'Citizen complaint', ''], ['Patrick Olaf Abrahamson', 'Police Officer', 'White', '2015', 'IAD2015-0642', 'Citizen complaint', ''], ['Patrick Olaf Abrahamson', 'Police Officer', 'White', '2017', 'IAD2017-0257', 'Citizen complaint', ''], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2011', 'IAD2011-0548', 'Citizen complaint', 'Suspension'], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2014', 'IAD2014-0612', 'Internal investigation', 'Suspension'], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2014', 'IAD2014-0612', 'Internal investigation', 'Suspension'], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2014', 'IAD2014-0612', 'Internal investigation', 'Suspension'], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2015', 'IAD2015-0044', 'Citizen complaint', ''], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2015', 'IAD2015-0056', 'Citizen complaint', ''], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2015', 'IAD2015-0221', 'Citizen complaint', ''], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2015', 'IAD2015-0221', 'Citizen complaint', ''], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2015', 'IAD2015-0491', 'Internal investigation', ''], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2015', 'IAD2015-0491', 'Internal investigation', 'Suspension'], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2015', 'IAD2015-0491', 'Internal investigation', ''], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2016', 'IAD2016-0090', 'Citizen complaint', ''], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2016', 'IAD2016-0253', 'Internal investigation', 'Suspension'], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2016', 'IAD2016-0253', 'Internal investigation', ''], ['Cesar Abreu', 'Police Officer', 'Hispanic', '2018', 'IAD2018-0471', 'Internal investigation', 'Suspension'], ['Moises J Abreu', 'Police Officer', 'Hispanic', '2015', 'IAD2015-0680', 'Citizen complaint', ''], ['Rafael W Acevedo', 'Police Officer', 'Hispanic', '2012', 'IAD2012-0280', 'Internal investigation', 'Oral Reprimand'], ['Jean Moise Acloque', 'Detective', 'Black', '2010', 'IAD2013-0317', 'Citizen complaint', ''], ['Jean Moise Acloque', 'Detective', 'Black', '2010', 'IAD2013-0317', 'Citizen complaint', ''], ['Jean Moise Acloque', 'Detective', 'Black', '2010', 'IAD2013-0317', 'Citizen complaint', ''], ['Jean Moise Acloque', 'Detective', 'Black', '2012', 'IAD2012-0066', 'Citizen complaint', ''], ['Jean Moise Acloque', 'Detective', 'Black', '2012', 'IAD2012-0066', 'Citizen complaint', ''], ['Jean Moise Acloque', 'Detective', 'Black', '2012', 'IAD2012-0066', 'Citizen complaint', ''], ['Jose L Acosta', 'Police Officer', 'Hispanic', '2013', 'IAD2013-0485', 'Citizen complaint', ''], ['Jose L Acosta', 'Police Officer', 'Hispanic', '2018', 'IAD2018-0082', 'Internal investigation', 'Suspension'], ['Jose L Acosta', 'Police Officer', 'Hispanic', '2018', 'IAD2018-0096', 'Citizen complaint', ''], ['Christopher Adams', 'Police Officer', 'White', '2019', 'IAD2019-0207', 'Citizen complaint', ''], ['Christopher P Adams', 'Police Officer', 'White', '2011', 'IAD2011-0568', 'Citizen complaint', ''], ['Christopher P Adams', 'Police Officer', 'White', '2011', 'IAD2011-0568', 'Citizen complaint', ''] ...

# %%
filename = "BostonPoliceInternalAffairs.csv"
fields = ['Name', 'Rank', 'Race', 'Year', 'CaseID', 'TypeOfMisconduct', 'Outcome']

with open(filename, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(fields)
    writer.writerows(data)
