# %%
import pandas as pd

# Estimate!!Households!!Mean income (dollars)
df = pd.read_csv("./census_tract_data/Income/ACSST5Y2019.S1901_data_with_overlays_2021-03-29T072928.csv", usecols=['GEO_ID', 'NAME', 'S1901_C01_013E'])
df = df[1:]  # 除去第一行
df.head()
# Out:
#                  GEO_ID                                               NAME  \
# 1  1400000US25001010100  Census Tract 101, Barnstable County, Massachus...
# 2  1400000US25001010206  Census Tract 102.06, Barnstable County, Massac...
# 3  1400000US25001010208  Census Tract 102.08, Barnstable County, Massac...
# 4  1400000US25001010304  Census Tract 103.04, Barnstable County, Massac...
# 5  1400000US25001010306  Census Tract 103.06, Barnstable County, Massac...
#
#   S1901_C01_013E
# 1          99735
# 2          92081
# 3          81766
# 4         113038
# 5          78411

# %%
import seaborn as sns
sns.distplot(df.S1901_C01_013E,bins=30)
# Out:
# <AxesSubplot:xlabel='S1901_C01_013E', ylabel='Density'>

# %%
# RUN THIS CELL FIRST or the notebook won't work
import numpy as np
import geopandas as gpd
from IPython.display import display
import matplotlib.pyplot as plt

# These help the maps display nicely in the notebook
# %matplotlib inline
plt.rcParams['figure.figsize'] = [60, 40]

# This line tells iPython to not display warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
mass = gpd.read_file("./cb_2018_25_tract_500k/cb_2018_25_tract_500k.shp")
print(mass)
# Out:
#      STATEFP COUNTYFP TRACTCE              AFFGEOID        GEOID     NAME  \
# 0         25      009  202102  1400000US25009202102  25009202102  2021.02
# 1         25      009  205100  1400000US25009205100  25009205100     2051
# 2         25      017  339400  1400000US25017339400  25017339400     3394
# 3         25      017  342101  1400000US25017342101  25017342101  3421.01
# 4         25      017  351000  1400000US25017351000  25017351000     3510
# ...      ...      ...     ...                   ...          ...      ...
# 1470      25      005  641200  1400000US25005641200  25005641200     6412
# 1471      25      005  642200  1400000US25005642200  25005642200     6422
# 1472      25      009  203100  1400000US25009203100  25009203100     2031
# 1473      25      027  705100  1400000US25027705100  25027705100     7051
# 1474      25      027  709202  1400000US25027709202  25027709202  7092.02
#
#      LSAD     ALAND   AWATER  \
# 0      CT   2919051    24048
# 1      CT   1826284    92857
# 2      CT    629016    25734
# 3      CT    617841        0
# 4      CT    668312        0
# ...   ...       ...      ...
# 1470   CT   1040285   129476
# 1471   CT   1422770     3763
# 1472   CT   3720285  1481336
# 1473   CT  82565798  1318672
# 1474   CT  10703107    16127
#
#                                                geometry
# 0     POLYGON ((-70.93411 42.49083, -70.91355 42.485...
# 1     POLYGON ((-70.95086 42.49498, -70.94992 42.494...
# 2     POLYGON ((-71.12992 42.41333, -71.12699 42.416...
# 3     POLYGON ((-71.04568 42.40992, -71.04567 42.412...
# 4     POLYGON ((-71.11816 42.38802, -71.11745 42.388...
# ...                                                 ...
# 1470  POLYGON ((-71.15328 41.69987, -71.15210 41.699...
# 1471  POLYGON ((-71.15101 41.71589, -71.14834 41.718...
# 1472  MULTIPOLYGON (((-70.83563 42.48440, -70.83371 ...
# 1473  POLYGON ((-72.13895 42.62395, -72.11663 42.626...
# 1474  POLYGON ((-71.75875 42.52306, -71.75776 42.523...
#
# [1475 rows x 10 columns]

# %%
mass = pd.merge(mass, df, left_on='AFFGEOID', right_on='GEO_ID')

# %%
def to_float(string):
    if string.isdigit():
        return int(string)
    
mass['S1901_C01_013E'] = mass.S1901_C01_013E.apply(to_float)
print(mass.columns)
# Out:
# Index(['STATEFP', 'COUNTYFP', 'TRACTCE', 'AFFGEOID', 'GEOID', 'NAME_x', 'LSAD',
#        'ALAND', 'AWATER', 'geometry', 'GEO_ID', 'NAME_y', 'S1901_C01_013E'],
#       dtype='object')

# %%
mass.plot(column='S1901_C01_013E', legend = True)
#Bounds supplies information on the maximum and minimum values of the x-axis and y-axis of our plot.
bounds = mass.bounds.iloc[3]
minx = bounds["minx"]
miny = bounds["miny"]
print(bounds)

# We use that information to place the text label for our legend
plt.text(minx + 1, miny - 0.3, 'Mean income', fontsize=20, rotation=90, rotation_mode='anchor')
plt.title('Massachusetts Household Mean Income by Census Tract', fontsize = 30)
plt.axis('off');
# Out:
# minx   -71.046189
# miny    42.406318
# maxx   -71.032566
# maxy    42.415626
# Name: 3, dtype: float64
