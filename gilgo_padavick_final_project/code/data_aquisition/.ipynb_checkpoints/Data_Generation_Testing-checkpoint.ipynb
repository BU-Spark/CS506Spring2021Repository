# %%
import twitter_data
import datetime as dt
import pandas as pd

# %%
import tweepy
import json

# %%
with open('keys.json') as keys:
    config = json.load(keys)
auth = tweepy.OAuthHandler(config['twitter']['API_key'], config['twitter']['API_secret_key'])
api = tweepy.API(auth)

# %%
pd.options.display.max_rows = 10000
pd.set_option('display.max_colwidth', 40)

# %%
start_date = dt.date(year=2021, month=3, day=1)
end_date = dt.date(year=2021, month=3, day=23)

# %%
test_df = twitter_data.generate_df(['GNUS', 'XSPA', 'IBIO', 'GME', 'OPES'], start_date, end_date)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-13-8d2713f24fa9> in <module>
# ----> 1 test_df = twitter_data.generate_df(['GNUS', 'XSPA', 'IBIO', 'GME', 'OPES'], start_date, end_date)
#
# ~\Documents\BU\CS_506\final_project\CS506Spring2021Repository\gilgo_padavick_final_project\code\data_aquisition\twitter_data.py in generate_df(stocks, start_date, end_date)
#      18     data = pd.DataFrame()
#      19     for stock in stocks:
# ---> 20         tweets = get_stock_tweets_list(stock, start_date, end_date)
#      21         json_data = [tweet._json for tweet in tweets]
#      22         stock_data = pd.io.json.json_normalize(json_data)
#
# ~\Documents\BU\CS_506\final_project\CS506Spring2021Repository\gilgo_padavick_final_project\code\data_aquisition\twitter_data.py in get_stock_tweets_list(stock, start_date, end_date)
#      12
#      13 def get_stock_tweets_list(stock, start_date, end_date=None):
# ---> 14     searched_tweets = [status for status in tweepy.Cursor(api.search, q="${}".format(stock), since=start_date, until=end_date).items()]
#      15     return searched_tweets
#      16
#
# ~\Documents\BU\CS_506\final_project\CS506Spring2021Repository\gilgo_padavick_final_project\code\data_aquisition\twitter_data.py in <listcomp>(.0)
#      12
#      13 def get_stock_tweets_list(stock, start_date, end_date=None):
# ---> 14     searched_tweets = [status for status in tweepy.Cursor(api.search, q="${}".format(stock), since=start_date, until=end_date).items()]
#      15     return searched_tweets
#      16
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     241         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     242             # Reached end of current page, get the next page...
# --> 243             self.current_page = self.page_iterator.next()
#     244             while len(self.current_page) == 0:
#     245                 self.current_page = self.page_iterator.next()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     130
#     131         if self.index >= len(self.results) - 1:
# --> 132             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     133
#     134             if hasattr(self.method, '__self__'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %%
test_df.head()

# %%
test_df[test_df['stock'] == 'XSPA'].head()

# %%
test_df[test_df['stock'] == 'XSPA'][['stock', 'text']].head()

# %%
print(test_df.shape)

# %%
test_df.to_parquet('2021-03-01_to_2021-03-23.parquet')

# %%
test_df.dtypes
# Out:
# contributors            object
# coordinates             object
# entities.hashtags       object
# entities.media          object
# entities.symbols        object
#                          ...
# user.time_zone          object
# user.translator_type    object
# user.url                object
# user.utc_offset         object
# user.verified           object
# Length: 302, dtype: object

# %%
# looking at an example tweet
test_df.iloc[0]
# Out:
# contributors                                                                                                 None
# coordinates                                                                                                  None
# entities.hashtags                                                                                              []
# entities.media                                                                                                NaN
# entities.symbols                                                          [{'text': 'gnus', 'indices': [75, 80]}]
# entities.urls                                                                                                  []
# entities.user_mentions                                                                                         []
# extended_entities.media                                                                                       NaN
# favorite_count                                                                                                  0
# favorited                                                                                                   False
# geo                                                                                                          None
# id                                                                                                    1.37299e+18
# id_str                                                                                        1372988670337245194
# in_reply_to_screen_name                                                                              EdgeCritical
# in_reply_to_status_id                                                                                 1.37299e+18
# in_reply_to_status_id_str                                                                     1372986739984306180
# in_reply_to_user_id                                                                                    1.0916e+18
# in_reply_to_user_id_str                                                                       1091601911558623232
# is_quote_status                                                                                             False
# lang                                                                                                           en
# metadata.iso_language_code                                                                                     en
# metadata.result_type                                                                                       recent
# place                                                                                                        None
# place.bounding_box.coordinates                                                                                NaN
# place.bounding_box.type                                                                                       NaN
# place.contained_within                                                                                        NaN
# place.country                                                                                                 NaN
# place.country_code                                                                                            NaN
# place.full_name                                                                                               NaN
# place.id                                                                                                      NaN
# place.name                                                                                                    NaN
# place.place_type                                                                                              NaN
# place.url                                                                                                     NaN
# possibly_sensitive                                                                                            NaN
# quoted_status.contributors                                                                                    NaN
# quoted_status.coordinates                                                                                     NaN
# quoted_status.created_at                                                                                      NaN
# quoted_status.entities.hashtags                                                                               NaN
# quoted_status.entities.symbols                                                                                NaN
# quoted_status.entities.urls                                                                                   NaN
# quoted_status.entities.user_mentions                                                                          NaN
# quoted_status.favorite_count                                                                                  NaN
# quoted_status.favorited                                                                                       NaN
# quoted_status.geo                                                                                             NaN
# quoted_status.id                                                                                              NaN
# quoted_status.id_str                                                                                          NaN
# quoted_status.in_reply_to_screen_name                                                                         NaN
# quoted_status.in_reply_to_status_id                                                                           NaN
# quoted_status.in_reply_to_status_id_str                                                                       NaN
# quoted_status.in_reply_to_user_id                                                                             NaN
# quoted_status.in_reply_to_user_id_str                                                                         NaN
# quoted_status.is_quote_status                                                                                 NaN
# quoted_status.lang                                                                                            NaN
# quoted_status.metadata.iso_language_code                                                                      NaN
# quoted_status.metadata.result_type                                                                            NaN
# quoted_status.place                                                                                           NaN
# quoted_status.possibly_sensitive                                                                              NaN
# quoted_status.retweet_count                                                                                   NaN
# quoted_status.retweeted                                                                                       NaN
# quoted_status.source                                                                                          NaN
# quoted_status.text                                                                                            NaN
# quoted_status.truncated                                                                                       NaN
# quoted_status.user.contributors_enabled                                                                       NaN
# quoted_status.user.created_at                                                                                 NaN
# quoted_status.user.default_profile                                                                            NaN
# quoted_status.user.default_profile_image                                                                      NaN
# quoted_status.user.description                                                                                NaN
# quoted_status.user.entities.description.urls                                                                  NaN
# quoted_status.user.entities.url.urls                                                                          NaN
# quoted_status.user.favourites_count                                                                           NaN
# quoted_status.user.follow_request_sent                                                                        NaN
# quoted_status.user.followers_count                                                                            NaN
# quoted_status.user.following                                                                                  NaN
# quoted_status.user.friends_count                                                                              NaN
# quoted_status.user.geo_enabled                                                                                NaN
# quoted_status.user.has_extended_profile                                                                       NaN
# quoted_status.user.id                                                                                         NaN
# quoted_status.user.id_str                                                                                     NaN
# quoted_status.user.is_translation_enabled                                                                     NaN
# quoted_status.user.is_translator                                                                              NaN
# quoted_status.user.lang                                                                                       NaN
# quoted_status.user.listed_count                                                                               NaN
# quoted_status.user.location                                                                                   NaN
# quoted_status.user.name                                                                                       NaN
# quoted_status.user.notifications                                                                              NaN
# quoted_status.user.profile_background_color                                                                   NaN
# quoted_status.user.profile_background_image_url                                                               NaN
# quoted_status.user.profile_background_image_url_https                                                         NaN
# quoted_status.user.profile_background_tile                                                                    NaN
# quoted_status.user.profile_banner_url                                                                         NaN
# quoted_status.user.profile_image_url                                                                          NaN
# quoted_status.user.profile_image_url_https                                                                    NaN
# quoted_status.user.profile_link_color                                                                         NaN
# quoted_status.user.profile_sidebar_border_color                                                               NaN
# quoted_status.user.profile_sidebar_fill_color                                                                 NaN
# quoted_status.user.profile_text_color                                                                         NaN
# quoted_status.user.profile_use_background_image                                                               NaN
# quoted_status.user.protected                                                                                  NaN
# quoted_status.user.screen_name                                                                                NaN
# quoted_status.user.statuses_count                                                                             NaN
# quoted_status.user.time_zone                                                                                  NaN
# quoted_status.user.translator_type                                                                            NaN
# quoted_status.user.url                                                                                        NaN
# quoted_status.user.utc_offset                                                                                 NaN
# quoted_status.user.verified                                                                                   NaN
# quoted_status_id                                                                                              NaN
# quoted_status_id_str                                                                                          NaN
# retweet_count                                                                                                   0
# retweeted                                                                                                   False
# retweeted_status.contributors                                                                                 NaN
# retweeted_status.coordinates                                                                                  NaN
# retweeted_status.created_at                                                                                   NaN
# retweeted_status.entities.hashtags                                                                            NaN
# retweeted_status.entities.media                                                                               NaN
# retweeted_status.entities.symbols                                                                             NaN
# retweeted_status.entities.urls                                                                                NaN
# retweeted_status.entities.user_mentions                                                                       NaN
# retweeted_status.extended_entities.media                                                                      NaN
# retweeted_status.favorite_count                                                                               NaN
# retweeted_status.favorited                                                                                    NaN
# retweeted_status.geo                                                                                          NaN
# retweeted_status.id                                                                                           NaN
# retweeted_status.id_str                                                                                       NaN
# retweeted_status.in_reply_to_screen_name                                                                      NaN
# retweeted_status.in_reply_to_status_id                                                                        NaN
# retweeted_status.in_reply_to_status_id_str                                                                    NaN
# retweeted_status.in_reply_to_user_id                                                                          NaN
# retweeted_status.in_reply_to_user_id_str                                                                      NaN
# retweeted_status.is_quote_status                                                                              NaN
# retweeted_status.lang                                                                                         NaN
# retweeted_status.metadata.iso_language_code                                                                   NaN
# retweeted_status.metadata.result_type                                                                         NaN
# retweeted_status.place                                                                                        NaN
# retweeted_status.possibly_sensitive                                                                           NaN
# retweeted_status.quoted_status.contributors                                                                   NaN
# retweeted_status.quoted_status.coordinates                                                                    NaN
# retweeted_status.quoted_status.created_at                                                                     NaN
# retweeted_status.quoted_status.entities.hashtags                                                              NaN
# retweeted_status.quoted_status.entities.symbols                                                               NaN
# retweeted_status.quoted_status.entities.urls                                                                  NaN
# retweeted_status.quoted_status.entities.user_mentions                                                         NaN
# retweeted_status.quoted_status.favorite_count                                                                 NaN
# retweeted_status.quoted_status.favorited                                                                      NaN
# retweeted_status.quoted_status.geo                                                                            NaN
# retweeted_status.quoted_status.id                                                                             NaN
# retweeted_status.quoted_status.id_str                                                                         NaN
# retweeted_status.quoted_status.in_reply_to_screen_name                                                        NaN
# retweeted_status.quoted_status.in_reply_to_status_id                                                          NaN
# retweeted_status.quoted_status.in_reply_to_status_id_str                                                      NaN
# retweeted_status.quoted_status.in_reply_to_user_id                                                            NaN
# retweeted_status.quoted_status.in_reply_to_user_id_str                                                        NaN
# retweeted_status.quoted_status.is_quote_status                                                                NaN
# retweeted_status.quoted_status.lang                                                                           NaN
# retweeted_status.quoted_status.metadata.iso_language_code                                                     NaN
# retweeted_status.quoted_status.metadata.result_type                                                           NaN
# retweeted_status.quoted_status.place                                                                          NaN
# retweeted_status.quoted_status.possibly_sensitive                                                             NaN
# retweeted_status.quoted_status.retweet_count                                                                  NaN
# retweeted_status.quoted_status.retweeted                                                                      NaN
# retweeted_status.quoted_status.source                                                                         NaN
# retweeted_status.quoted_status.text                                                                           NaN
# retweeted_status.quoted_status.truncated                                                                      NaN
# retweeted_status.quoted_status.user.contributors_enabled                                                      NaN
# retweeted_status.quoted_status.user.created_at                                                                NaN
# retweeted_status.quoted_status.user.default_profile                                                           NaN
# retweeted_status.quoted_status.user.default_profile_image                                                     NaN
# retweeted_status.quoted_status.user.description                                                               NaN
# retweeted_status.quoted_status.user.entities.description.urls                                                 NaN
# retweeted_status.quoted_status.user.entities.url.urls                                                         NaN
# retweeted_status.quoted_status.user.favourites_count                                                          NaN
# retweeted_status.quoted_status.user.follow_request_sent                                                       NaN
# retweeted_status.quoted_status.user.followers_count                                                           NaN
# retweeted_status.quoted_status.user.following                                                                 NaN
# retweeted_status.quoted_status.user.friends_count                                                             NaN
# retweeted_status.quoted_status.user.geo_enabled                                                               NaN
# retweeted_status.quoted_status.user.has_extended_profile                                                      NaN
# retweeted_status.quoted_status.user.id                                                                        NaN
# retweeted_status.quoted_status.user.id_str                                                                    NaN
# retweeted_status.quoted_status.user.is_translation_enabled                                                    NaN
# retweeted_status.quoted_status.user.is_translator                                                             NaN
# retweeted_status.quoted_status.user.lang                                                                      NaN
# retweeted_status.quoted_status.user.listed_count                                                              NaN
# retweeted_status.quoted_status.user.location                                                                  NaN
# retweeted_status.quoted_status.user.name                                                                      NaN
# retweeted_status.quoted_status.user.notifications                                                             NaN
# retweeted_status.quoted_status.user.profile_background_color                                                  NaN
# retweeted_status.quoted_status.user.profile_background_image_url                                              NaN
# retweeted_status.quoted_status.user.profile_background_image_url_https                                        NaN
# retweeted_status.quoted_status.user.profile_background_tile                                                   NaN
# retweeted_status.quoted_status.user.profile_banner_url                                                        NaN
# retweeted_status.quoted_status.user.profile_image_url                                                         NaN
# retweeted_status.quoted_status.user.profile_image_url_https                                                   NaN
# retweeted_status.quoted_status.user.profile_link_color                                                        NaN
# retweeted_status.quoted_status.user.profile_sidebar_border_color                                              NaN
# retweeted_status.quoted_status.user.profile_sidebar_fill_color                                                NaN
# retweeted_status.quoted_status.user.profile_text_color                                                        NaN
# retweeted_status.quoted_status.user.profile_use_background_image                                              NaN
# retweeted_status.quoted_status.user.protected                                                                 NaN
# retweeted_status.quoted_status.user.screen_name                                                               NaN
# retweeted_status.quoted_status.user.statuses_count                                                            NaN
# retweeted_status.quoted_status.user.time_zone                                                                 NaN
# retweeted_status.quoted_status.user.translator_type                                                           NaN
# retweeted_status.quoted_status.user.url                                                                       NaN
# retweeted_status.quoted_status.user.utc_offset                                                                NaN
# retweeted_status.quoted_status.user.verified                                                                  NaN
# retweeted_status.quoted_status_id                                                                             NaN
# retweeted_status.quoted_status_id_str                                                                         NaN
# retweeted_status.retweet_count                                                                                NaN
# retweeted_status.retweeted                                                                                    NaN
# retweeted_status.source                                                                                       NaN
# retweeted_status.text                                                                                         NaN
# retweeted_status.truncated                                                                                    NaN
# retweeted_status.user.contributors_enabled                                                                    NaN
# retweeted_status.user.created_at                                                                              NaN
# retweeted_status.user.default_profile                                                                         NaN
# retweeted_status.user.default_profile_image                                                                   NaN
# retweeted_status.user.description                                                                             NaN
# retweeted_status.user.entities.description.urls                                                               NaN
# retweeted_status.user.entities.url.urls                                                                       NaN
# retweeted_status.user.favourites_count                                                                        NaN
# retweeted_status.user.follow_request_sent                                                                     NaN
# retweeted_status.user.followers_count                                                                         NaN
# retweeted_status.user.following                                                                               NaN
# retweeted_status.user.friends_count                                                                           NaN
# retweeted_status.user.geo_enabled                                                                             NaN
# retweeted_status.user.has_extended_profile                                                                    NaN
# retweeted_status.user.id                                                                                      NaN
# retweeted_status.user.id_str                                                                                  NaN
# retweeted_status.user.is_translation_enabled                                                                  NaN
# retweeted_status.user.is_translator                                                                           NaN
# retweeted_status.user.lang                                                                                    NaN
# retweeted_status.user.listed_count                                                                            NaN
# retweeted_status.user.location                                                                                NaN
# retweeted_status.user.name                                                                                    NaN
# retweeted_status.user.notifications                                                                           NaN
# retweeted_status.user.profile_background_color                                                                NaN
# retweeted_status.user.profile_background_image_url                                                            NaN
# retweeted_status.user.profile_background_image_url_https                                                      NaN
# retweeted_status.user.profile_background_tile                                                                 NaN
# retweeted_status.user.profile_banner_url                                                                      NaN
# retweeted_status.user.profile_image_url                                                                       NaN
# retweeted_status.user.profile_image_url_https                                                                 NaN
# retweeted_status.user.profile_link_color                                                                      NaN
# retweeted_status.user.profile_sidebar_border_color                                                            NaN
# retweeted_status.user.profile_sidebar_fill_color                                                              NaN
# retweeted_status.user.profile_text_color                                                                      NaN
# retweeted_status.user.profile_use_background_image                                                            NaN
# retweeted_status.user.protected                                                                               NaN
# retweeted_status.user.screen_name                                                                             NaN
# retweeted_status.user.statuses_count                                                                          NaN
# retweeted_status.user.time_zone                                                                               NaN
# retweeted_status.user.translator_type                                                                         NaN
# retweeted_status.user.url                                                                                     NaN
# retweeted_status.user.utc_offset                                                                              NaN
# retweeted_status.user.verified                                                                                NaN
# source                                                                    <a href="http://twitter.com/download...
# stock                                                                                                        GNUS
# text                                                                      I think it’s an elevator down to 1.8...
# truncated                                                                                                   False
# user.contributors_enabled                                                                                   False
# user.created_at                                                                    Sat Feb 02 07:39:11 +0000 2019
# user.default_profile                                                                                         True
# user.default_profile_image                                                                                  False
# user.description                                                          Follow Me For Stock Related News & U...
# user.entities.description.urls                                                                                 []
# user.entities.url.urls                                                                                        NaN
# user.favourites_count                                                                                        1088
# user.follow_request_sent                                                                                     None
# user.followers_count                                                                                           33
# user.following                                                                                               None
# user.friends_count                                                                                             27
# user.geo_enabled                                                                                            False
# user.has_extended_profile                                                                                   False
# user.id                                                                                                1.0916e+18
# user.id_str                                                                                   1091601911558623232
# user.is_translation_enabled                                                                                 False
# user.is_translator                                                                                          False
# user.lang                                                                                                    None
# user.listed_count                                                                                               0
# user.location                                                                                                  🇺🇸
# user.name                                                                                           Critical Edge
# user.notifications                                                                                           None
# user.profile_background_color                                                                              F5F8FA
# user.profile_background_image_url                                                                            None
# user.profile_background_image_url_https                                                                      None
# user.profile_background_tile                                                                                False
# user.profile_banner_url                                                   https://pbs.twimg.com/profile_banner...
# user.profile_image_url                                                    http://pbs.twimg.com/profile_images/...
# user.profile_image_url_https                                              https://pbs.twimg.com/profile_images...
# user.profile_link_color                                                                                    1DA1F2
# user.profile_sidebar_border_color                                                                          C0DEED
# user.profile_sidebar_fill_color                                                                            DDEEF6
# user.profile_text_color                                                                                    333333
# user.profile_use_background_image                                                                            True
# user.protected                                                                                              False
# user.screen_name                                                                                     EdgeCritical
# user.statuses_count                                                                                          1047
# user.time_zone                                                                                               None
# user.translator_type                                                                                         none
# user.url                                                                                                     None
# user.utc_offset                                                                                              None
# user.verified                                                                                               False
# Name: Fri Mar 19 19:09:42 +0000 2021, dtype: object

# %%
test_df.iloc[2]
# Out:
# contributors                                                                                                 None
# coordinates                                                                                                  None
# entities.hashtags                                                         [{'text': 'StocksToBuy', 'indices': ...
# entities.media                                                                                                NaN
# entities.symbols                                                          [{'text': 'gnus', 'indices': [25, 30]}]
# entities.urls                                                             [{'url': 'https://t.co/yH2pxCZhcE', ...
# entities.user_mentions                                                                                         []
# extended_entities.media                                                                                       NaN
# favorite_count                                                                                                  0
# favorited                                                                                                   False
# geo                                                                                                          None
# id                                                                                                    1.37219e+18
# id_str                                                                                        1372186031253037057
# in_reply_to_screen_name                                                                                      None
# in_reply_to_status_id                                                                                         NaN
# in_reply_to_status_id_str                                                                                    None
# in_reply_to_user_id                                                                                           NaN
# in_reply_to_user_id_str                                                                                      None
# is_quote_status                                                                                             False
# lang                                                                                                           en
# metadata.iso_language_code                                                                                     en
# metadata.result_type                                                                                       recent
# place                                                                                                        None
# place.bounding_box.coordinates                                                                                NaN
# place.bounding_box.type                                                                                       NaN
# place.contained_within                                                                                        NaN
# place.country                                                                                                 NaN
# place.country_code                                                                                            NaN
# place.full_name                                                                                               NaN
# place.id                                                                                                      NaN
# place.name                                                                                                    NaN
# place.place_type                                                                                              NaN
# place.url                                                                                                     NaN
# possibly_sensitive                                                                                          False
# quoted_status.contributors                                                                                    NaN
# quoted_status.coordinates                                                                                     NaN
# quoted_status.created_at                                                                                      NaN
# quoted_status.entities.hashtags                                                                               NaN
# quoted_status.entities.symbols                                                                                NaN
# quoted_status.entities.urls                                                                                   NaN
# quoted_status.entities.user_mentions                                                                          NaN
# quoted_status.favorite_count                                                                                  NaN
# quoted_status.favorited                                                                                       NaN
# quoted_status.geo                                                                                             NaN
# quoted_status.id                                                                                              NaN
# quoted_status.id_str                                                                                          NaN
# quoted_status.in_reply_to_screen_name                                                                         NaN
# quoted_status.in_reply_to_status_id                                                                           NaN
# quoted_status.in_reply_to_status_id_str                                                                       NaN
# quoted_status.in_reply_to_user_id                                                                             NaN
# quoted_status.in_reply_to_user_id_str                                                                         NaN
# quoted_status.is_quote_status                                                                                 NaN
# quoted_status.lang                                                                                            NaN
# quoted_status.metadata.iso_language_code                                                                      NaN
# quoted_status.metadata.result_type                                                                            NaN
# quoted_status.place                                                                                           NaN
# quoted_status.possibly_sensitive                                                                              NaN
# quoted_status.retweet_count                                                                                   NaN
# quoted_status.retweeted                                                                                       NaN
# quoted_status.source                                                                                          NaN
# quoted_status.text                                                                                            NaN
# quoted_status.truncated                                                                                       NaN
# quoted_status.user.contributors_enabled                                                                       NaN
# quoted_status.user.created_at                                                                                 NaN
# quoted_status.user.default_profile                                                                            NaN
# quoted_status.user.default_profile_image                                                                      NaN
# quoted_status.user.description                                                                                NaN
# quoted_status.user.entities.description.urls                                                                  NaN
# quoted_status.user.entities.url.urls                                                                          NaN
# quoted_status.user.favourites_count                                                                           NaN
# quoted_status.user.follow_request_sent                                                                        NaN
# quoted_status.user.followers_count                                                                            NaN
# quoted_status.user.following                                                                                  NaN
# quoted_status.user.friends_count                                                                              NaN
# quoted_status.user.geo_enabled                                                                                NaN
# quoted_status.user.has_extended_profile                                                                       NaN
# quoted_status.user.id                                                                                         NaN
# quoted_status.user.id_str                                                                                     NaN
# quoted_status.user.is_translation_enabled                                                                     NaN
# quoted_status.user.is_translator                                                                              NaN
# quoted_status.user.lang                                                                                       NaN
# quoted_status.user.listed_count                                                                               NaN
# quoted_status.user.location                                                                                   NaN
# quoted_status.user.name                                                                                       NaN
# quoted_status.user.notifications                                                                              NaN
# quoted_status.user.profile_background_color                                                                   NaN
# quoted_status.user.profile_background_image_url                                                               NaN
# quoted_status.user.profile_background_image_url_https                                                         NaN
# quoted_status.user.profile_background_tile                                                                    NaN
# quoted_status.user.profile_banner_url                                                                         NaN
# quoted_status.user.profile_image_url                                                                          NaN
# quoted_status.user.profile_image_url_https                                                                    NaN
# quoted_status.user.profile_link_color                                                                         NaN
# quoted_status.user.profile_sidebar_border_color                                                               NaN
# quoted_status.user.profile_sidebar_fill_color                                                                 NaN
# quoted_status.user.profile_text_color                                                                         NaN
# quoted_status.user.profile_use_background_image                                                               NaN
# quoted_status.user.protected                                                                                  NaN
# quoted_status.user.screen_name                                                                                NaN
# quoted_status.user.statuses_count                                                                             NaN
# quoted_status.user.time_zone                                                                                  NaN
# quoted_status.user.translator_type                                                                            NaN
# quoted_status.user.url                                                                                        NaN
# quoted_status.user.utc_offset                                                                                 NaN
# quoted_status.user.verified                                                                                   NaN
# quoted_status_id                                                                                              NaN
# quoted_status_id_str                                                                                          NaN
# retweet_count                                                                                                   0
# retweeted                                                                                                   False
# retweeted_status.contributors                                                                                 NaN
# retweeted_status.coordinates                                                                                  NaN
# retweeted_status.created_at                                                                                   NaN
# retweeted_status.entities.hashtags                                                                            NaN
# retweeted_status.entities.media                                                                               NaN
# retweeted_status.entities.symbols                                                                             NaN
# retweeted_status.entities.urls                                                                                NaN
# retweeted_status.entities.user_mentions                                                                       NaN
# retweeted_status.extended_entities.media                                                                      NaN
# retweeted_status.favorite_count                                                                               NaN
# retweeted_status.favorited                                                                                    NaN
# retweeted_status.geo                                                                                          NaN
# retweeted_status.id                                                                                           NaN
# retweeted_status.id_str                                                                                       NaN
# retweeted_status.in_reply_to_screen_name                                                                      NaN
# retweeted_status.in_reply_to_status_id                                                                        NaN
# retweeted_status.in_reply_to_status_id_str                                                                    NaN
# retweeted_status.in_reply_to_user_id                                                                          NaN
# retweeted_status.in_reply_to_user_id_str                                                                      NaN
# retweeted_status.is_quote_status                                                                              NaN
# retweeted_status.lang                                                                                         NaN
# retweeted_status.metadata.iso_language_code                                                                   NaN
# retweeted_status.metadata.result_type                                                                         NaN
# retweeted_status.place                                                                                        NaN
# retweeted_status.possibly_sensitive                                                                           NaN
# retweeted_status.quoted_status.contributors                                                                   NaN
# retweeted_status.quoted_status.coordinates                                                                    NaN
# retweeted_status.quoted_status.created_at                                                                     NaN
# retweeted_status.quoted_status.entities.hashtags                                                              NaN
# retweeted_status.quoted_status.entities.symbols                                                               NaN
# retweeted_status.quoted_status.entities.urls                                                                  NaN
# retweeted_status.quoted_status.entities.user_mentions                                                         NaN
# retweeted_status.quoted_status.favorite_count                                                                 NaN
# retweeted_status.quoted_status.favorited                                                                      NaN
# retweeted_status.quoted_status.geo                                                                            NaN
# retweeted_status.quoted_status.id                                                                             NaN
# retweeted_status.quoted_status.id_str                                                                         NaN
# retweeted_status.quoted_status.in_reply_to_screen_name                                                        NaN
# retweeted_status.quoted_status.in_reply_to_status_id                                                          NaN
# retweeted_status.quoted_status.in_reply_to_status_id_str                                                      NaN
# retweeted_status.quoted_status.in_reply_to_user_id                                                            NaN
# retweeted_status.quoted_status.in_reply_to_user_id_str                                                        NaN
# retweeted_status.quoted_status.is_quote_status                                                                NaN
# retweeted_status.quoted_status.lang                                                                           NaN
# retweeted_status.quoted_status.metadata.iso_language_code                                                     NaN
# retweeted_status.quoted_status.metadata.result_type                                                           NaN
# retweeted_status.quoted_status.place                                                                          NaN
# retweeted_status.quoted_status.possibly_sensitive                                                             NaN
# retweeted_status.quoted_status.retweet_count                                                                  NaN
# retweeted_status.quoted_status.retweeted                                                                      NaN
# retweeted_status.quoted_status.source                                                                         NaN
# retweeted_status.quoted_status.text                                                                           NaN
# retweeted_status.quoted_status.truncated                                                                      NaN
# retweeted_status.quoted_status.user.contributors_enabled                                                      NaN
# retweeted_status.quoted_status.user.created_at                                                                NaN
# retweeted_status.quoted_status.user.default_profile                                                           NaN
# retweeted_status.quoted_status.user.default_profile_image                                                     NaN
# retweeted_status.quoted_status.user.description                                                               NaN
# retweeted_status.quoted_status.user.entities.description.urls                                                 NaN
# retweeted_status.quoted_status.user.entities.url.urls                                                         NaN
# retweeted_status.quoted_status.user.favourites_count                                                          NaN
# retweeted_status.quoted_status.user.follow_request_sent                                                       NaN
# retweeted_status.quoted_status.user.followers_count                                                           NaN
# retweeted_status.quoted_status.user.following                                                                 NaN
# retweeted_status.quoted_status.user.friends_count                                                             NaN
# retweeted_status.quoted_status.user.geo_enabled                                                               NaN
# retweeted_status.quoted_status.user.has_extended_profile                                                      NaN
# retweeted_status.quoted_status.user.id                                                                        NaN
# retweeted_status.quoted_status.user.id_str                                                                    NaN
# retweeted_status.quoted_status.user.is_translation_enabled                                                    NaN
# retweeted_status.quoted_status.user.is_translator                                                             NaN
# retweeted_status.quoted_status.user.lang                                                                      NaN
# retweeted_status.quoted_status.user.listed_count                                                              NaN
# retweeted_status.quoted_status.user.location                                                                  NaN
# retweeted_status.quoted_status.user.name                                                                      NaN
# retweeted_status.quoted_status.user.notifications                                                             NaN
# retweeted_status.quoted_status.user.profile_background_color                                                  NaN
# retweeted_status.quoted_status.user.profile_background_image_url                                              NaN
# retweeted_status.quoted_status.user.profile_background_image_url_https                                        NaN
# retweeted_status.quoted_status.user.profile_background_tile                                                   NaN
# retweeted_status.quoted_status.user.profile_banner_url                                                        NaN
# retweeted_status.quoted_status.user.profile_image_url                                                         NaN
# retweeted_status.quoted_status.user.profile_image_url_https                                                   NaN
# retweeted_status.quoted_status.user.profile_link_color                                                        NaN
# retweeted_status.quoted_status.user.profile_sidebar_border_color                                              NaN
# retweeted_status.quoted_status.user.profile_sidebar_fill_color                                                NaN
# retweeted_status.quoted_status.user.profile_text_color                                                        NaN
# retweeted_status.quoted_status.user.profile_use_background_image                                              NaN
# retweeted_status.quoted_status.user.protected                                                                 NaN
# retweeted_status.quoted_status.user.screen_name                                                               NaN
# retweeted_status.quoted_status.user.statuses_count                                                            NaN
# retweeted_status.quoted_status.user.time_zone                                                                 NaN
# retweeted_status.quoted_status.user.translator_type                                                           NaN
# retweeted_status.quoted_status.user.url                                                                       NaN
# retweeted_status.quoted_status.user.utc_offset                                                                NaN
# retweeted_status.quoted_status.user.verified                                                                  NaN
# retweeted_status.quoted_status_id                                                                             NaN
# retweeted_status.quoted_status_id_str                                                                         NaN
# retweeted_status.retweet_count                                                                                NaN
# retweeted_status.retweeted                                                                                    NaN
# retweeted_status.source                                                                                       NaN
# retweeted_status.text                                                                                         NaN
# retweeted_status.truncated                                                                                    NaN
# retweeted_status.user.contributors_enabled                                                                    NaN
# retweeted_status.user.created_at                                                                              NaN
# retweeted_status.user.default_profile                                                                         NaN
# retweeted_status.user.default_profile_image                                                                   NaN
# retweeted_status.user.description                                                                             NaN
# retweeted_status.user.entities.description.urls                                                               NaN
# retweeted_status.user.entities.url.urls                                                                       NaN
# retweeted_status.user.favourites_count                                                                        NaN
# retweeted_status.user.follow_request_sent                                                                     NaN
# retweeted_status.user.followers_count                                                                         NaN
# retweeted_status.user.following                                                                               NaN
# retweeted_status.user.friends_count                                                                           NaN
# retweeted_status.user.geo_enabled                                                                             NaN
# retweeted_status.user.has_extended_profile                                                                    NaN
# retweeted_status.user.id                                                                                      NaN
# retweeted_status.user.id_str                                                                                  NaN
# retweeted_status.user.is_translation_enabled                                                                  NaN
# retweeted_status.user.is_translator                                                                           NaN
# retweeted_status.user.lang                                                                                    NaN
# retweeted_status.user.listed_count                                                                            NaN
# retweeted_status.user.location                                                                                NaN
# retweeted_status.user.name                                                                                    NaN
# retweeted_status.user.notifications                                                                           NaN
# retweeted_status.user.profile_background_color                                                                NaN
# retweeted_status.user.profile_background_image_url                                                            NaN
# retweeted_status.user.profile_background_image_url_https                                                      NaN
# retweeted_status.user.profile_background_tile                                                                 NaN
# retweeted_status.user.profile_banner_url                                                                      NaN
# retweeted_status.user.profile_image_url                                                                       NaN
# retweeted_status.user.profile_image_url_https                                                                 NaN
# retweeted_status.user.profile_link_color                                                                      NaN
# retweeted_status.user.profile_sidebar_border_color                                                            NaN
# retweeted_status.user.profile_sidebar_fill_color                                                              NaN
# retweeted_status.user.profile_text_color                                                                      NaN
# retweeted_status.user.profile_use_background_image                                                            NaN
# retweeted_status.user.protected                                                                               NaN
# retweeted_status.user.screen_name                                                                             NaN
# retweeted_status.user.statuses_count                                                                          NaN
# retweeted_status.user.time_zone                                                                               NaN
# retweeted_status.user.translator_type                                                                         NaN
# retweeted_status.user.url                                                                                     NaN
# retweeted_status.user.utc_offset                                                                              NaN
# retweeted_status.user.verified                                                                                NaN
# source                                                                    <a href="http://twitter.com/download...
# stock                                                                                                        GNUS
# text                                                                      https://t.co/yH2pxCZhcE\n\n$gnus wil...
# truncated                                                                                                   False
# user.contributors_enabled                                                                                   False
# user.created_at                                                                    Wed Oct 12 11:26:54 +0000 2011
# user.default_profile                                                                                         True
# user.default_profile_image                                                                                  False
# user.description                                                          Here for the money. $idex $visl $tsl...
# user.entities.description.urls                                                                                 []
# user.entities.url.urls                                                                                        NaN
# user.favourites_count                                                                                        1237
# user.follow_request_sent                                                                                     None
# user.followers_count                                                                                          126
# user.following                                                                                               None
# user.friends_count                                                                                            154
# user.geo_enabled                                                                                            False
# user.has_extended_profile                                                                                   False
# user.id                                                                                               3.89412e+08
# user.id_str                                                                                             389412069
# user.is_translation_enabled                                                                                 False
# user.is_translator                                                                                          False
# user.lang                                                                                                    None
# user.listed_count                                                                                               1
# user.location                                                                                       Delaware, USA
# user.name                                                                                           Scott Johnson
# user.notifications                                                                                           None
# user.profile_background_color                                                                              C0DEED
# user.profile_background_image_url                                         http://abs.twimg.com/images/themes/t...
# user.profile_background_image_url_https                                   https://abs.twimg.com/images/themes/...
# user.profile_background_tile                                                                                False
# user.profile_banner_url                                                   https://pbs.twimg.com/profile_banner...
# user.profile_image_url                                                    http://pbs.twimg.com/profile_images/...
# user.profile_image_url_https                                              https://pbs.twimg.com/profile_images...
# user.profile_link_color                                                                                    1DA1F2
# user.profile_sidebar_border_color                                                                          C0DEED
# user.profile_sidebar_fill_color                                                                            DDEEF6
# user.profile_text_color                                                                                    333333
# user.profile_use_background_image                                                                            True
# user.protected                                                                                              False
# user.screen_name                                                                                       LiVVinLife
# user.statuses_count                                                                                          1541
# user.time_zone                                                                                               None
# user.translator_type                                                                                         none
# user.url                                                                                                     None
# user.utc_offset                                                                                              None
# user.verified                                                                                               False
# Name: Wed Mar 17 14:00:18 +0000 2021, dtype: object

# %%
test_df[test_df['retweet_count'] > 100].iloc[0]
# Out:
# contributors                                                                                                 None
# coordinates                                                                                                  None
# entities.hashtags                                                                                              []
# entities.media                                                                                                NaN
# entities.symbols                                                          [{'text': 'GME', 'indices': [41, 45]...
# entities.urls                                                                                                  []
# entities.user_mentions                                                    [{'screen_name': 'ihors3', 'name': '...
# extended_entities.media                                                                                       NaN
# favorite_count                                                                                                  0
# favorited                                                                                                   False
# geo                                                                                                          None
# id                                                                                                    1.37269e+18
# id_str                                                                                        1372689505312989189
# in_reply_to_screen_name                                                                                      None
# in_reply_to_status_id                                                                                         NaN
# in_reply_to_status_id_str                                                                                    None
# in_reply_to_user_id                                                                                           NaN
# in_reply_to_user_id_str                                                                                      None
# is_quote_status                                                                                             False
# lang                                                                                                           en
# metadata.iso_language_code                                                                                     en
# metadata.result_type                                                                                       recent
# place                                                                                                         NaN
# place.bounding_box.coordinates                                                                                NaN
# place.bounding_box.type                                                                                       NaN
# place.contained_within                                                                                        NaN
# place.country                                                                                                 NaN
# place.country_code                                                                                            NaN
# place.full_name                                                                                               NaN
# place.id                                                                                                      NaN
# place.name                                                                                                    NaN
# place.place_type                                                                                              NaN
# place.url                                                                                                     NaN
# possibly_sensitive                                                                                            NaN
# quoted_status.contributors                                                                                    NaN
# quoted_status.coordinates                                                                                     NaN
# quoted_status.created_at                                                                                      NaN
# quoted_status.entities.hashtags                                                                               NaN
# quoted_status.entities.symbols                                                                                NaN
# quoted_status.entities.urls                                                                                   NaN
# quoted_status.entities.user_mentions                                                                          NaN
# quoted_status.favorite_count                                                                                  NaN
# quoted_status.favorited                                                                                       NaN
# quoted_status.geo                                                                                             NaN
# quoted_status.id                                                                                              NaN
# quoted_status.id_str                                                                                          NaN
# quoted_status.in_reply_to_screen_name                                                                         NaN
# quoted_status.in_reply_to_status_id                                                                           NaN
# quoted_status.in_reply_to_status_id_str                                                                       NaN
# quoted_status.in_reply_to_user_id                                                                             NaN
# quoted_status.in_reply_to_user_id_str                                                                         NaN
# quoted_status.is_quote_status                                                                                 NaN
# quoted_status.lang                                                                                            NaN
# quoted_status.metadata.iso_language_code                                                                      NaN
# quoted_status.metadata.result_type                                                                            NaN
# quoted_status.place                                                                                           NaN
# quoted_status.possibly_sensitive                                                                              NaN
# quoted_status.retweet_count                                                                                   NaN
# quoted_status.retweeted                                                                                       NaN
# quoted_status.source                                                                                          NaN
# quoted_status.text                                                                                            NaN
# quoted_status.truncated                                                                                       NaN
# quoted_status.user.contributors_enabled                                                                       NaN
# quoted_status.user.created_at                                                                                 NaN
# quoted_status.user.default_profile                                                                            NaN
# quoted_status.user.default_profile_image                                                                      NaN
# quoted_status.user.description                                                                                NaN
# quoted_status.user.entities.description.urls                                                                  NaN
# quoted_status.user.entities.url.urls                                                                          NaN
# quoted_status.user.favourites_count                                                                           NaN
# quoted_status.user.follow_request_sent                                                                        NaN
# quoted_status.user.followers_count                                                                            NaN
# quoted_status.user.following                                                                                  NaN
# quoted_status.user.friends_count                                                                              NaN
# quoted_status.user.geo_enabled                                                                                NaN
# quoted_status.user.has_extended_profile                                                                       NaN
# quoted_status.user.id                                                                                         NaN
# quoted_status.user.id_str                                                                                     NaN
# quoted_status.user.is_translation_enabled                                                                     NaN
# quoted_status.user.is_translator                                                                              NaN
# quoted_status.user.lang                                                                                       NaN
# quoted_status.user.listed_count                                                                               NaN
# quoted_status.user.location                                                                                   NaN
# quoted_status.user.name                                                                                       NaN
# quoted_status.user.notifications                                                                              NaN
# quoted_status.user.profile_background_color                                                                   NaN
# quoted_status.user.profile_background_image_url                                                               NaN
# quoted_status.user.profile_background_image_url_https                                                         NaN
# quoted_status.user.profile_background_tile                                                                    NaN
# quoted_status.user.profile_banner_url                                                                         NaN
# quoted_status.user.profile_image_url                                                                          NaN
# quoted_status.user.profile_image_url_https                                                                    NaN
# quoted_status.user.profile_link_color                                                                         NaN
# quoted_status.user.profile_sidebar_border_color                                                               NaN
# quoted_status.user.profile_sidebar_fill_color                                                                 NaN
# quoted_status.user.profile_text_color                                                                         NaN
# quoted_status.user.profile_use_background_image                                                               NaN
# quoted_status.user.protected                                                                                  NaN
# quoted_status.user.screen_name                                                                                NaN
# quoted_status.user.statuses_count                                                                             NaN
# quoted_status.user.time_zone                                                                                  NaN
# quoted_status.user.translator_type                                                                            NaN
# quoted_status.user.url                                                                                        NaN
# quoted_status.user.utc_offset                                                                                 NaN
# quoted_status.user.verified                                                                                   NaN
# quoted_status_id                                                                                              NaN
# quoted_status_id_str                                                                                          NaN
# retweet_count                                                                                                 129
# retweeted                                                                                                   False
# retweeted_status.contributors                                                                                 NaN
# retweeted_status.coordinates                                                                                  NaN
# retweeted_status.created_at                                                        Fri Mar 12 18:02:21 +0000 2021
# retweeted_status.entities.hashtags                                                                             []
# retweeted_status.entities.media                                                                               NaN
# retweeted_status.entities.symbols                                         [{'text': 'GME', 'indices': [29, 33]...
# retweeted_status.entities.urls                                            [{'url': 'https://t.co/rzJ2SBCbtN', ...
# retweeted_status.entities.user_mentions                                                                        []
# retweeted_status.extended_entities.media                                                                      NaN
# retweeted_status.favorite_count                                                                               493
# retweeted_status.favorited                                                                                  False
# retweeted_status.geo                                                                                          NaN
# retweeted_status.id                                                                                   1.37044e+18
# retweeted_status.id_str                                                                       1370435007622316037
# retweeted_status.in_reply_to_screen_name                                                                     None
# retweeted_status.in_reply_to_status_id                                                                        NaN
# retweeted_status.in_reply_to_status_id_str                                                                   None
# retweeted_status.in_reply_to_user_id                                                                          NaN
# retweeted_status.in_reply_to_user_id_str                                                                     None
# retweeted_status.is_quote_status                                                                            False
# retweeted_status.lang                                                                                          en
# retweeted_status.metadata.iso_language_code                                                                    en
# retweeted_status.metadata.result_type                                                                      recent
# retweeted_status.place                                                                                        NaN
# retweeted_status.possibly_sensitive                                                                           NaN
# retweeted_status.quoted_status.contributors                                                                   NaN
# retweeted_status.quoted_status.coordinates                                                                    NaN
# retweeted_status.quoted_status.created_at                                                                     NaN
# retweeted_status.quoted_status.entities.hashtags                                                              NaN
# retweeted_status.quoted_status.entities.symbols                                                               NaN
# retweeted_status.quoted_status.entities.urls                                                                  NaN
# retweeted_status.quoted_status.entities.user_mentions                                                         NaN
# retweeted_status.quoted_status.favorite_count                                                                 NaN
# retweeted_status.quoted_status.favorited                                                                      NaN
# retweeted_status.quoted_status.geo                                                                            NaN
# retweeted_status.quoted_status.id                                                                             NaN
# retweeted_status.quoted_status.id_str                                                                         NaN
# retweeted_status.quoted_status.in_reply_to_screen_name                                                        NaN
# retweeted_status.quoted_status.in_reply_to_status_id                                                          NaN
# retweeted_status.quoted_status.in_reply_to_status_id_str                                                      NaN
# retweeted_status.quoted_status.in_reply_to_user_id                                                            NaN
# retweeted_status.quoted_status.in_reply_to_user_id_str                                                        NaN
# retweeted_status.quoted_status.is_quote_status                                                                NaN
# retweeted_status.quoted_status.lang                                                                           NaN
# retweeted_status.quoted_status.metadata.iso_language_code                                                     NaN
# retweeted_status.quoted_status.metadata.result_type                                                           NaN
# retweeted_status.quoted_status.place                                                                          NaN
# retweeted_status.quoted_status.possibly_sensitive                                                             NaN
# retweeted_status.quoted_status.retweet_count                                                                  NaN
# retweeted_status.quoted_status.retweeted                                                                      NaN
# retweeted_status.quoted_status.source                                                                         NaN
# retweeted_status.quoted_status.text                                                                           NaN
# retweeted_status.quoted_status.truncated                                                                      NaN
# retweeted_status.quoted_status.user.contributors_enabled                                                      NaN
# retweeted_status.quoted_status.user.created_at                                                                NaN
# retweeted_status.quoted_status.user.default_profile                                                           NaN
# retweeted_status.quoted_status.user.default_profile_image                                                     NaN
# retweeted_status.quoted_status.user.description                                                               NaN
# retweeted_status.quoted_status.user.entities.description.urls                                                 NaN
# retweeted_status.quoted_status.user.entities.url.urls                                                         NaN
# retweeted_status.quoted_status.user.favourites_count                                                          NaN
# retweeted_status.quoted_status.user.follow_request_sent                                                       NaN
# retweeted_status.quoted_status.user.followers_count                                                           NaN
# retweeted_status.quoted_status.user.following                                                                 NaN
# retweeted_status.quoted_status.user.friends_count                                                             NaN
# retweeted_status.quoted_status.user.geo_enabled                                                               NaN
# retweeted_status.quoted_status.user.has_extended_profile                                                      NaN
# retweeted_status.quoted_status.user.id                                                                        NaN
# retweeted_status.quoted_status.user.id_str                                                                    NaN
# retweeted_status.quoted_status.user.is_translation_enabled                                                    NaN
# retweeted_status.quoted_status.user.is_translator                                                             NaN
# retweeted_status.quoted_status.user.lang                                                                      NaN
# retweeted_status.quoted_status.user.listed_count                                                              NaN
# retweeted_status.quoted_status.user.location                                                                  NaN
# retweeted_status.quoted_status.user.name                                                                      NaN
# retweeted_status.quoted_status.user.notifications                                                             NaN
# retweeted_status.quoted_status.user.profile_background_color                                                  NaN
# retweeted_status.quoted_status.user.profile_background_image_url                                              NaN
# retweeted_status.quoted_status.user.profile_background_image_url_https                                        NaN
# retweeted_status.quoted_status.user.profile_background_tile                                                   NaN
# retweeted_status.quoted_status.user.profile_banner_url                                                        NaN
# retweeted_status.quoted_status.user.profile_image_url                                                         NaN
# retweeted_status.quoted_status.user.profile_image_url_https                                                   NaN
# retweeted_status.quoted_status.user.profile_link_color                                                        NaN
# retweeted_status.quoted_status.user.profile_sidebar_border_color                                              NaN
# retweeted_status.quoted_status.user.profile_sidebar_fill_color                                                NaN
# retweeted_status.quoted_status.user.profile_text_color                                                        NaN
# retweeted_status.quoted_status.user.profile_use_background_image                                              NaN
# retweeted_status.quoted_status.user.protected                                                                 NaN
# retweeted_status.quoted_status.user.screen_name                                                               NaN
# retweeted_status.quoted_status.user.statuses_count                                                            NaN
# retweeted_status.quoted_status.user.time_zone                                                                 NaN
# retweeted_status.quoted_status.user.translator_type                                                           NaN
# retweeted_status.quoted_status.user.url                                                                       NaN
# retweeted_status.quoted_status.user.utc_offset                                                                NaN
# retweeted_status.quoted_status.user.verified                                                                  NaN
# retweeted_status.quoted_status_id                                                                             NaN
# retweeted_status.quoted_status_id_str                                                                         NaN
# retweeted_status.retweet_count                                                                                129
# retweeted_status.retweeted                                                                                  False
# retweeted_status.source                                                   <a href="https://mobile.twitter.com"...
# retweeted_status.text                                                     Let me correct my typo: both $GME an...
# retweeted_status.truncated                                                                                   True
# retweeted_status.user.contributors_enabled                                                                  False
# retweeted_status.user.created_at                                                   Tue Feb 23 15:33:29 +0000 2016
# retweeted_status.user.default_profile                                                                       False
# retweeted_status.user.default_profile_image                                                                 False
# retweeted_status.user.description                                         Managing Director of Predictive Anal...
# retweeted_status.user.entities.description.urls                                                                []
# retweeted_status.user.entities.url.urls                                   [{'url': 'https://t.co/OHyNlxdFFC', ...
# retweeted_status.user.favourites_count                                                                       7447
# retweeted_status.user.follow_request_sent                                                                     NaN
# retweeted_status.user.followers_count                                                                       45276
# retweeted_status.user.following                                                                               NaN
# retweeted_status.user.friends_count                                                                          4579
# retweeted_status.user.geo_enabled                                                                            True
# retweeted_status.user.has_extended_profile                                                                  False
# retweeted_status.user.id                                                                              7.02154e+17
# retweeted_status.user.id_str                                                                   702154317596336128
# retweeted_status.user.is_translation_enabled                                                                False
# retweeted_status.user.is_translator                                                                         False
# retweeted_status.user.lang                                                                                    NaN
# retweeted_status.user.listed_count                                                                            526
# retweeted_status.user.location                                                                       New York, NY
# retweeted_status.user.name                                                                        Ihor Dusaniwsky
# retweeted_status.user.notifications                                                                           NaN
# retweeted_status.user.profile_background_color                                                             000000
# retweeted_status.user.profile_background_image_url                        http://abs.twimg.com/images/themes/t...
# retweeted_status.user.profile_background_image_url_https                  https://abs.twimg.com/images/themes/...
# retweeted_status.user.profile_background_tile                                                               False
# retweeted_status.user.profile_banner_url                                  https://pbs.twimg.com/profile_banner...
# retweeted_status.user.profile_image_url                                   http://pbs.twimg.com/profile_images/...
# retweeted_status.user.profile_image_url_https                             https://pbs.twimg.com/profile_images...
# retweeted_status.user.profile_link_color                                                                   1B95E0
# retweeted_status.user.profile_sidebar_border_color                                                         000000
# retweeted_status.user.profile_sidebar_fill_color                                                           000000
# retweeted_status.user.profile_text_color                                                                   000000
# retweeted_status.user.profile_use_background_image                                                          False
# retweeted_status.user.protected                                                                             False
# retweeted_status.user.screen_name                                                                          ihors3
# retweeted_status.user.statuses_count                                                                         6825
# retweeted_status.user.time_zone                                                                               NaN
# retweeted_status.user.translator_type                                                                        none
# retweeted_status.user.url                                                                 https://t.co/OHyNlxdFFC
# retweeted_status.user.utc_offset                                                                              NaN
# retweeted_status.user.verified                                                                               True
# source                                                                    <a href="http://twitter.com/download...
# stock                                                                                                         GME
# text                                                                      RT @ihors3: Let me correct my typo: ...
# truncated                                                                                                   False
# user.contributors_enabled                                                                                   False
# user.created_at                                                                    Sat Jan 16 11:51:47 +0000 2021
# user.default_profile                                                                                         True
# user.default_profile_image                                                                                  False
# user.description                                                          If you believe in a cause, be willin...
# user.entities.description.urls                                                                                 []
# user.entities.url.urls                                                                                        NaN
# user.favourites_count                                                                                         251
# user.follow_request_sent                                                                                     None
# user.followers_count                                                                                            8
# user.following                                                                                               None
# user.friends_count                                                                                            107
# user.geo_enabled                                                                                             True
# user.has_extended_profile                                                                                    True
# user.id                                                                                               1.35041e+18
# user.id_str                                                                                   1350410372629540864
# user.is_translation_enabled                                                                                 False
# user.is_translator                                                                                          False
# user.lang                                                                                                    None
# user.listed_count                                                                                               0
# user.location                                                                                       United States
# user.name                                                                                             fux_Coivd20
# user.notifications                                                                                           None
# user.profile_background_color                                                                              F5F8FA
# user.profile_background_image_url                                                                            None
# user.profile_background_image_url_https                                                                      None
# user.profile_background_tile                                                                                False
# user.profile_banner_url                                                   https://pbs.twimg.com/profile_banner...
# user.profile_image_url                                                    http://pbs.twimg.com/profile_images/...
# user.profile_image_url_https                                              https://pbs.twimg.com/profile_images...
# user.profile_link_color                                                                                    1DA1F2
# user.profile_sidebar_border_color                                                                          C0DEED
# user.profile_sidebar_fill_color                                                                            DDEEF6
# user.profile_text_color                                                                                    333333
# user.profile_use_background_image                                                                            True
# user.protected                                                                                              False
# user.screen_name                                                                                          coivd20
# user.statuses_count                                                                                           233
# user.time_zone                                                                                               None
# user.translator_type                                                                                         none
# user.url                                                                                                     None
# user.utc_offset                                                                                              None
# user.verified                                                                                               False
# Name: Thu Mar 18 23:20:56 +0000 2021, dtype: object

# %%
test_df[test_df['user.followers_count'] > 10000].iloc[0]
# Out:
# contributors                                                                                                 None
# coordinates                                                                                                  None
# entities.hashtags                                                                                              []
# entities.media                                                                                                NaN
# entities.symbols                                                          [{'text': 'XSPA', 'indices': [76, 81]}]
# entities.urls                                                                                                  []
# entities.user_mentions                                                    [{'screen_name': 'DansGamePoker', 'n...
# extended_entities.media                                                                                       NaN
# favorite_count                                                                                                  0
# favorited                                                                                                   False
# geo                                                                                                          None
# id                                                                                                    1.37183e+18
# id_str                                                                                        1371831195927973894
# in_reply_to_screen_name                                                                                      None
# in_reply_to_status_id                                                                                        None
# in_reply_to_status_id_str                                                                                    None
# in_reply_to_user_id                                                                                          None
# in_reply_to_user_id_str                                                                                      None
# is_quote_status                                                                                             False
# lang                                                                                                           en
# metadata.iso_language_code                                                                                     en
# metadata.result_type                                                                                       recent
# place                                                                                                        None
# place.bounding_box.coordinates                                                                                NaN
# place.bounding_box.type                                                                                       NaN
# place.contained_within                                                                                        NaN
# place.country                                                                                                 NaN
# place.country_code                                                                                            NaN
# place.full_name                                                                                               NaN
# place.id                                                                                                      NaN
# place.name                                                                                                    NaN
# place.place_type                                                                                              NaN
# place.url                                                                                                     NaN
# possibly_sensitive                                                                                            NaN
# quoted_status.contributors                                                                                    NaN
# quoted_status.coordinates                                                                                     NaN
# quoted_status.created_at                                                                                      NaN
# quoted_status.entities.hashtags                                                                               NaN
# quoted_status.entities.symbols                                                                                NaN
# quoted_status.entities.urls                                                                                   NaN
# quoted_status.entities.user_mentions                                                                          NaN
# quoted_status.favorite_count                                                                                  NaN
# quoted_status.favorited                                                                                       NaN
# quoted_status.geo                                                                                             NaN
# quoted_status.id                                                                                              NaN
# quoted_status.id_str                                                                                          NaN
# quoted_status.in_reply_to_screen_name                                                                         NaN
# quoted_status.in_reply_to_status_id                                                                           NaN
# quoted_status.in_reply_to_status_id_str                                                                       NaN
# quoted_status.in_reply_to_user_id                                                                             NaN
# quoted_status.in_reply_to_user_id_str                                                                         NaN
# quoted_status.is_quote_status                                                                                 NaN
# quoted_status.lang                                                                                            NaN
# quoted_status.metadata.iso_language_code                                                                      NaN
# quoted_status.metadata.result_type                                                                            NaN
# quoted_status.place                                                                                           NaN
# quoted_status.possibly_sensitive                                                                              NaN
# quoted_status.retweet_count                                                                                   NaN
# quoted_status.retweeted                                                                                       NaN
# quoted_status.source                                                                                          NaN
# quoted_status.text                                                                                            NaN
# quoted_status.truncated                                                                                       NaN
# quoted_status.user.contributors_enabled                                                                       NaN
# quoted_status.user.created_at                                                                                 NaN
# quoted_status.user.default_profile                                                                            NaN
# quoted_status.user.default_profile_image                                                                      NaN
# quoted_status.user.description                                                                                NaN
# quoted_status.user.entities.description.urls                                                                  NaN
# quoted_status.user.entities.url.urls                                                                          NaN
# quoted_status.user.favourites_count                                                                           NaN
# quoted_status.user.follow_request_sent                                                                        NaN
# quoted_status.user.followers_count                                                                            NaN
# quoted_status.user.following                                                                                  NaN
# quoted_status.user.friends_count                                                                              NaN
# quoted_status.user.geo_enabled                                                                                NaN
# quoted_status.user.has_extended_profile                                                                       NaN
# quoted_status.user.id                                                                                         NaN
# quoted_status.user.id_str                                                                                     NaN
# quoted_status.user.is_translation_enabled                                                                     NaN
# quoted_status.user.is_translator                                                                              NaN
# quoted_status.user.lang                                                                                       NaN
# quoted_status.user.listed_count                                                                               NaN
# quoted_status.user.location                                                                                   NaN
# quoted_status.user.name                                                                                       NaN
# quoted_status.user.notifications                                                                              NaN
# quoted_status.user.profile_background_color                                                                   NaN
# quoted_status.user.profile_background_image_url                                                               NaN
# quoted_status.user.profile_background_image_url_https                                                         NaN
# quoted_status.user.profile_background_tile                                                                    NaN
# quoted_status.user.profile_banner_url                                                                         NaN
# quoted_status.user.profile_image_url                                                                          NaN
# quoted_status.user.profile_image_url_https                                                                    NaN
# quoted_status.user.profile_link_color                                                                         NaN
# quoted_status.user.profile_sidebar_border_color                                                               NaN
# quoted_status.user.profile_sidebar_fill_color                                                                 NaN
# quoted_status.user.profile_text_color                                                                         NaN
# quoted_status.user.profile_use_background_image                                                               NaN
# quoted_status.user.protected                                                                                  NaN
# quoted_status.user.screen_name                                                                                NaN
# quoted_status.user.statuses_count                                                                             NaN
# quoted_status.user.time_zone                                                                                  NaN
# quoted_status.user.translator_type                                                                            NaN
# quoted_status.user.url                                                                                        NaN
# quoted_status.user.utc_offset                                                                                 NaN
# quoted_status.user.verified                                                                                   NaN
# quoted_status_id                                                                                              NaN
# quoted_status_id_str                                                                                          NaN
# retweet_count                                                                                                   3
# retweeted                                                                                                   False
# retweeted_status.contributors                                                                                 NaN
# retweeted_status.coordinates                                                                                  NaN
# retweeted_status.created_at                                                        Thu Jun 04 17:46:26 +0000 2020
# retweeted_status.entities.hashtags                                                                             []
# retweeted_status.entities.media                                                                               NaN
# retweeted_status.entities.symbols                                         [{'text': 'XSPA', 'indices': [57, 62]}]
# retweeted_status.entities.urls                                            [{'url': 'https://t.co/laLYH2k1SA', ...
# retweeted_status.entities.user_mentions                                                                        []
# retweeted_status.extended_entities.media                                                                      NaN
# retweeted_status.favorite_count                                                                                26
# retweeted_status.favorited                                                                                  False
# retweeted_status.geo                                                                                          NaN
# retweeted_status.id                                                                                    1.2686e+18
# retweeted_status.id_str                                                                       1268600008636616712
# retweeted_status.in_reply_to_screen_name                                                                      NaN
# retweeted_status.in_reply_to_status_id                                                                        NaN
# retweeted_status.in_reply_to_status_id_str                                                                    NaN
# retweeted_status.in_reply_to_user_id                                                                          NaN
# retweeted_status.in_reply_to_user_id_str                                                                      NaN
# retweeted_status.is_quote_status                                                                            False
# retweeted_status.lang                                                                                          en
# retweeted_status.metadata.iso_language_code                                                                    en
# retweeted_status.metadata.result_type                                                                      recent
# retweeted_status.place                                                                                        NaN
# retweeted_status.possibly_sensitive                                                                         False
# retweeted_status.quoted_status.contributors                                                                   NaN
# retweeted_status.quoted_status.coordinates                                                                    NaN
# retweeted_status.quoted_status.created_at                                                                     NaN
# retweeted_status.quoted_status.entities.hashtags                                                              NaN
# retweeted_status.quoted_status.entities.symbols                                                               NaN
# retweeted_status.quoted_status.entities.urls                                                                  NaN
# retweeted_status.quoted_status.entities.user_mentions                                                         NaN
# retweeted_status.quoted_status.favorite_count                                                                 NaN
# retweeted_status.quoted_status.favorited                                                                      NaN
# retweeted_status.quoted_status.geo                                                                            NaN
# retweeted_status.quoted_status.id                                                                             NaN
# retweeted_status.quoted_status.id_str                                                                         NaN
# retweeted_status.quoted_status.in_reply_to_screen_name                                                        NaN
# retweeted_status.quoted_status.in_reply_to_status_id                                                          NaN
# retweeted_status.quoted_status.in_reply_to_status_id_str                                                      NaN
# retweeted_status.quoted_status.in_reply_to_user_id                                                            NaN
# retweeted_status.quoted_status.in_reply_to_user_id_str                                                        NaN
# retweeted_status.quoted_status.is_quote_status                                                                NaN
# retweeted_status.quoted_status.lang                                                                           NaN
# retweeted_status.quoted_status.metadata.iso_language_code                                                     NaN
# retweeted_status.quoted_status.metadata.result_type                                                           NaN
# retweeted_status.quoted_status.place                                                                          NaN
# retweeted_status.quoted_status.possibly_sensitive                                                             NaN
# retweeted_status.quoted_status.retweet_count                                                                  NaN
# retweeted_status.quoted_status.retweeted                                                                      NaN
# retweeted_status.quoted_status.source                                                                         NaN
# retweeted_status.quoted_status.text                                                                           NaN
# retweeted_status.quoted_status.truncated                                                                      NaN
# retweeted_status.quoted_status.user.contributors_enabled                                                      NaN
# retweeted_status.quoted_status.user.created_at                                                                NaN
# retweeted_status.quoted_status.user.default_profile                                                           NaN
# retweeted_status.quoted_status.user.default_profile_image                                                     NaN
# retweeted_status.quoted_status.user.description                                                               NaN
# retweeted_status.quoted_status.user.entities.description.urls                                                 NaN
# retweeted_status.quoted_status.user.entities.url.urls                                                         NaN
# retweeted_status.quoted_status.user.favourites_count                                                          NaN
# retweeted_status.quoted_status.user.follow_request_sent                                                       NaN
# retweeted_status.quoted_status.user.followers_count                                                           NaN
# retweeted_status.quoted_status.user.following                                                                 NaN
# retweeted_status.quoted_status.user.friends_count                                                             NaN
# retweeted_status.quoted_status.user.geo_enabled                                                               NaN
# retweeted_status.quoted_status.user.has_extended_profile                                                      NaN
# retweeted_status.quoted_status.user.id                                                                        NaN
# retweeted_status.quoted_status.user.id_str                                                                    NaN
# retweeted_status.quoted_status.user.is_translation_enabled                                                    NaN
# retweeted_status.quoted_status.user.is_translator                                                             NaN
# retweeted_status.quoted_status.user.lang                                                                      NaN
# retweeted_status.quoted_status.user.listed_count                                                              NaN
# retweeted_status.quoted_status.user.location                                                                  NaN
# retweeted_status.quoted_status.user.name                                                                      NaN
# retweeted_status.quoted_status.user.notifications                                                             NaN
# retweeted_status.quoted_status.user.profile_background_color                                                  NaN
# retweeted_status.quoted_status.user.profile_background_image_url                                              NaN
# retweeted_status.quoted_status.user.profile_background_image_url_https                                        NaN
# retweeted_status.quoted_status.user.profile_background_tile                                                   NaN
# retweeted_status.quoted_status.user.profile_banner_url                                                        NaN
# retweeted_status.quoted_status.user.profile_image_url                                                         NaN
# retweeted_status.quoted_status.user.profile_image_url_https                                                   NaN
# retweeted_status.quoted_status.user.profile_link_color                                                        NaN
# retweeted_status.quoted_status.user.profile_sidebar_border_color                                              NaN
# retweeted_status.quoted_status.user.profile_sidebar_fill_color                                                NaN
# retweeted_status.quoted_status.user.profile_text_color                                                        NaN
# retweeted_status.quoted_status.user.profile_use_background_image                                              NaN
# retweeted_status.quoted_status.user.protected                                                                 NaN
# retweeted_status.quoted_status.user.screen_name                                                               NaN
# retweeted_status.quoted_status.user.statuses_count                                                            NaN
# retweeted_status.quoted_status.user.time_zone                                                                 NaN
# retweeted_status.quoted_status.user.translator_type                                                           NaN
# retweeted_status.quoted_status.user.url                                                                       NaN
# retweeted_status.quoted_status.user.utc_offset                                                                NaN
# retweeted_status.quoted_status.user.verified                                                                  NaN
# retweeted_status.quoted_status_id                                                                             NaN
# retweeted_status.quoted_status_id_str                                                                         NaN
# retweeted_status.retweet_count                                                                                  3
# retweeted_status.retweeted                                                                                  False
# retweeted_status.source                                                   <a href="https://mobile.twitter.com"...
# retweeted_status.text                                                     I like having precision. 10 second l...
# retweeted_status.truncated                                                                                   True
# retweeted_status.user.contributors_enabled                                                                  False
# retweeted_status.user.created_at                                                   Tue Mar 15 05:05:04 +0000 2016
# retweeted_status.user.default_profile                                                                       False
# retweeted_status.user.default_profile_image                                                                 False
# retweeted_status.user.description                                         I will never message you/manage mone...
# retweeted_status.user.entities.description.urls                           [{'url': 'https://t.co/KHqzZqqE3p', ...
# retweeted_status.user.entities.url.urls                                   [{'url': 'https://t.co/sNAeVA8scZ', ...
# retweeted_status.user.favourites_count                                                                      12775
# retweeted_status.user.follow_request_sent                                                                     NaN
# retweeted_status.user.followers_count                                                                       10788
# retweeted_status.user.following                                                                               NaN
# retweeted_status.user.friends_count                                                                            72
# retweeted_status.user.geo_enabled                                                                            True
# retweeted_status.user.has_extended_profile                                                                  False
# retweeted_status.user.id                                                                              7.09606e+17
# retweeted_status.user.id_str                                                                   709606315513872388
# retweeted_status.user.is_translation_enabled                                                                False
# retweeted_status.user.is_translator                                                                         False
# retweeted_status.user.lang                                                                                    NaN
# retweeted_status.user.listed_count                                                                             85
# retweeted_status.user.location
# retweeted_status.user.name                                                                              Dan Irish
# retweeted_status.user.notifications                                                                           NaN
# retweeted_status.user.profile_background_color                                                             000000
# retweeted_status.user.profile_background_image_url                        http://abs.twimg.com/images/themes/t...
# retweeted_status.user.profile_background_image_url_https                  https://abs.twimg.com/images/themes/...
# retweeted_status.user.profile_background_tile                                                               False
# retweeted_status.user.profile_banner_url                                  https://pbs.twimg.com/profile_banner...
# retweeted_status.user.profile_image_url                                   http://pbs.twimg.com/profile_images/...
# retweeted_status.user.profile_image_url_https                             https://pbs.twimg.com/profile_images...
# retweeted_status.user.profile_link_color                                                                   1B95E0
# retweeted_status.user.profile_sidebar_border_color                                                         000000
# retweeted_status.user.profile_sidebar_fill_color                                                           000000
# retweeted_status.user.profile_text_color                                                                   000000
# retweeted_status.user.profile_use_background_image                                                          False
# retweeted_status.user.protected                                                                             False
# retweeted_status.user.screen_name                                                                   DansGamePoker
# retweeted_status.user.statuses_count                                                                         2306
# retweeted_status.user.time_zone                                                                               NaN
# retweeted_status.user.translator_type                                                                        none
# retweeted_status.user.url                                                                 https://t.co/sNAeVA8scZ
# retweeted_status.user.utc_offset                                                                              NaN
# retweeted_status.user.verified                                                                              False
# source                                                                    <a href="http://twitter.com/download...
# stock                                                                                                        XSPA
# text                                                                      RT @DansGamePoker: I like having pre...
# truncated                                                                                                   False
# user.contributors_enabled                                                                                   False
# user.created_at                                                                    Fri Nov 18 22:52:32 +0000 2016
# user.default_profile                                                                                         True
# user.default_profile_image                                                                                  False
# user.description                                                          25 years in markets. Combine technic...
# user.entities.description.urls                                                                                 []
# user.entities.url.urls                                                    [{'url': 'https://t.co/zvMGpuIea5', ...
# user.favourites_count                                                                                       21442
# user.follow_request_sent                                                                                     None
# user.followers_count                                                                                        30146
# user.following                                                                                               None
# user.friends_count                                                                                            176
# user.geo_enabled                                                                                             True
# user.has_extended_profile                                                                                    True
# user.id                                                                                               7.99747e+17
# user.id_str                                                                                    799747145993625600
# user.is_translation_enabled                                                                                 False
# user.is_translator                                                                                          False
# user.lang                                                                                                    None
# user.listed_count                                                                                              93
# user.location                                                                                     My Free Charts:
# user.name                                                                                            Macro Charts
# user.notifications                                                                                           None
# user.profile_background_color                                                                              F5F8FA
# user.profile_background_image_url                                                                            None
# user.profile_background_image_url_https                                                                      None
# user.profile_background_tile                                                                                False
# user.profile_banner_url                                                   https://pbs.twimg.com/profile_banner...
# user.profile_image_url                                                    http://pbs.twimg.com/profile_images/...
# user.profile_image_url_https                                              https://pbs.twimg.com/profile_images...
# user.profile_link_color                                                                                    1DA1F2
# user.profile_sidebar_border_color                                                                          C0DEED
# user.profile_sidebar_fill_color                                                                            DDEEF6
# user.profile_text_color                                                                                    333333
# user.profile_use_background_image                                                                            True
# user.protected                                                                                              False
# user.screen_name                                                                                     MaccroCharts
# user.statuses_count                                                                                          3521
# user.time_zone                                                                                               None
# user.translator_type                                                                                         none
# user.url                                                                                  https://t.co/zvMGpuIea5
# user.utc_offset                                                                                              None
# user.verified                                                                                               False
# Name: Tue Mar 16 14:30:19 +0000 2021, dtype: object

# %%
test_df[test_df['retweeted'] == False].iloc[0]
# Out:
# contributors                                                                                                 None
# coordinates                                                                                                  None
# entities.hashtags                                                                                              []
# entities.media                                                                                                NaN
# entities.symbols                                                          [{'text': 'gnus', 'indices': [75, 80]}]
# entities.urls                                                                                                  []
# entities.user_mentions                                                                                         []
# extended_entities.media                                                                                       NaN
# favorite_count                                                                                                  0
# favorited                                                                                                   False
# geo                                                                                                          None
# id                                                                                                    1.37299e+18
# id_str                                                                                        1372988670337245194
# in_reply_to_screen_name                                                                              EdgeCritical
# in_reply_to_status_id                                                                                 1.37299e+18
# in_reply_to_status_id_str                                                                     1372986739984306180
# in_reply_to_user_id                                                                                    1.0916e+18
# in_reply_to_user_id_str                                                                       1091601911558623232
# is_quote_status                                                                                             False
# lang                                                                                                           en
# metadata.iso_language_code                                                                                     en
# metadata.result_type                                                                                       recent
# place                                                                                                        None
# place.bounding_box.coordinates                                                                                NaN
# place.bounding_box.type                                                                                       NaN
# place.contained_within                                                                                        NaN
# place.country                                                                                                 NaN
# place.country_code                                                                                            NaN
# place.full_name                                                                                               NaN
# place.id                                                                                                      NaN
# place.name                                                                                                    NaN
# place.place_type                                                                                              NaN
# place.url                                                                                                     NaN
# possibly_sensitive                                                                                            NaN
# quoted_status.contributors                                                                                    NaN
# quoted_status.coordinates                                                                                     NaN
# quoted_status.created_at                                                                                      NaN
# quoted_status.entities.hashtags                                                                               NaN
# quoted_status.entities.symbols                                                                                NaN
# quoted_status.entities.urls                                                                                   NaN
# quoted_status.entities.user_mentions                                                                          NaN
# quoted_status.favorite_count                                                                                  NaN
# quoted_status.favorited                                                                                       NaN
# quoted_status.geo                                                                                             NaN
# quoted_status.id                                                                                              NaN
# quoted_status.id_str                                                                                          NaN
# quoted_status.in_reply_to_screen_name                                                                         NaN
# quoted_status.in_reply_to_status_id                                                                           NaN
# quoted_status.in_reply_to_status_id_str                                                                       NaN
# quoted_status.in_reply_to_user_id                                                                             NaN
# quoted_status.in_reply_to_user_id_str                                                                         NaN
# quoted_status.is_quote_status                                                                                 NaN
# quoted_status.lang                                                                                            NaN
# quoted_status.metadata.iso_language_code                                                                      NaN
# quoted_status.metadata.result_type                                                                            NaN
# quoted_status.place                                                                                           NaN
# quoted_status.possibly_sensitive                                                                              NaN
# quoted_status.retweet_count                                                                                   NaN
# quoted_status.retweeted                                                                                       NaN
# quoted_status.source                                                                                          NaN
# quoted_status.text                                                                                            NaN
# quoted_status.truncated                                                                                       NaN
# quoted_status.user.contributors_enabled                                                                       NaN
# quoted_status.user.created_at                                                                                 NaN
# quoted_status.user.default_profile                                                                            NaN
# quoted_status.user.default_profile_image                                                                      NaN
# quoted_status.user.description                                                                                NaN
# quoted_status.user.entities.description.urls                                                                  NaN
# quoted_status.user.entities.url.urls                                                                          NaN
# quoted_status.user.favourites_count                                                                           NaN
# quoted_status.user.follow_request_sent                                                                        NaN
# quoted_status.user.followers_count                                                                            NaN
# quoted_status.user.following                                                                                  NaN
# quoted_status.user.friends_count                                                                              NaN
# quoted_status.user.geo_enabled                                                                                NaN
# quoted_status.user.has_extended_profile                                                                       NaN
# quoted_status.user.id                                                                                         NaN
# quoted_status.user.id_str                                                                                     NaN
# quoted_status.user.is_translation_enabled                                                                     NaN
# quoted_status.user.is_translator                                                                              NaN
# quoted_status.user.lang                                                                                       NaN
# quoted_status.user.listed_count                                                                               NaN
# quoted_status.user.location                                                                                   NaN
# quoted_status.user.name                                                                                       NaN
# quoted_status.user.notifications                                                                              NaN
# quoted_status.user.profile_background_color                                                                   NaN
# quoted_status.user.profile_background_image_url                                                               NaN
# quoted_status.user.profile_background_image_url_https                                                         NaN
# quoted_status.user.profile_background_tile                                                                    NaN
# quoted_status.user.profile_banner_url                                                                         NaN
# quoted_status.user.profile_image_url                                                                          NaN
# quoted_status.user.profile_image_url_https                                                                    NaN
# quoted_status.user.profile_link_color                                                                         NaN
# quoted_status.user.profile_sidebar_border_color                                                               NaN
# quoted_status.user.profile_sidebar_fill_color                                                                 NaN
# quoted_status.user.profile_text_color                                                                         NaN
# quoted_status.user.profile_use_background_image                                                               NaN
# quoted_status.user.protected                                                                                  NaN
# quoted_status.user.screen_name                                                                                NaN
# quoted_status.user.statuses_count                                                                             NaN
# quoted_status.user.time_zone                                                                                  NaN
# quoted_status.user.translator_type                                                                            NaN
# quoted_status.user.url                                                                                        NaN
# quoted_status.user.utc_offset                                                                                 NaN
# quoted_status.user.verified                                                                                   NaN
# quoted_status_id                                                                                              NaN
# quoted_status_id_str                                                                                          NaN
# retweet_count                                                                                                   0
# retweeted                                                                                                   False
# retweeted_status.contributors                                                                                 NaN
# retweeted_status.coordinates                                                                                  NaN
# retweeted_status.created_at                                                                                   NaN
# retweeted_status.entities.hashtags                                                                            NaN
# retweeted_status.entities.media                                                                               NaN
# retweeted_status.entities.symbols                                                                             NaN
# retweeted_status.entities.urls                                                                                NaN
# retweeted_status.entities.user_mentions                                                                       NaN
# retweeted_status.extended_entities.media                                                                      NaN
# retweeted_status.favorite_count                                                                               NaN
# retweeted_status.favorited                                                                                    NaN
# retweeted_status.geo                                                                                          NaN
# retweeted_status.id                                                                                           NaN
# retweeted_status.id_str                                                                                       NaN
# retweeted_status.in_reply_to_screen_name                                                                      NaN
# retweeted_status.in_reply_to_status_id                                                                        NaN
# retweeted_status.in_reply_to_status_id_str                                                                    NaN
# retweeted_status.in_reply_to_user_id                                                                          NaN
# retweeted_status.in_reply_to_user_id_str                                                                      NaN
# retweeted_status.is_quote_status                                                                              NaN
# retweeted_status.lang                                                                                         NaN
# retweeted_status.metadata.iso_language_code                                                                   NaN
# retweeted_status.metadata.result_type                                                                         NaN
# retweeted_status.place                                                                                        NaN
# retweeted_status.possibly_sensitive                                                                           NaN
# retweeted_status.quoted_status.contributors                                                                   NaN
# retweeted_status.quoted_status.coordinates                                                                    NaN
# retweeted_status.quoted_status.created_at                                                                     NaN
# retweeted_status.quoted_status.entities.hashtags                                                              NaN
# retweeted_status.quoted_status.entities.symbols                                                               NaN
# retweeted_status.quoted_status.entities.urls                                                                  NaN
# retweeted_status.quoted_status.entities.user_mentions                                                         NaN
# retweeted_status.quoted_status.favorite_count                                                                 NaN
# retweeted_status.quoted_status.favorited                                                                      NaN
# retweeted_status.quoted_status.geo                                                                            NaN
# retweeted_status.quoted_status.id                                                                             NaN
# retweeted_status.quoted_status.id_str                                                                         NaN
# retweeted_status.quoted_status.in_reply_to_screen_name                                                        NaN
# retweeted_status.quoted_status.in_reply_to_status_id                                                          NaN
# retweeted_status.quoted_status.in_reply_to_status_id_str                                                      NaN
# retweeted_status.quoted_status.in_reply_to_user_id                                                            NaN
# retweeted_status.quoted_status.in_reply_to_user_id_str                                                        NaN
# retweeted_status.quoted_status.is_quote_status                                                                NaN
# retweeted_status.quoted_status.lang                                                                           NaN
# retweeted_status.quoted_status.metadata.iso_language_code                                                     NaN
# retweeted_status.quoted_status.metadata.result_type                                                           NaN
# retweeted_status.quoted_status.place                                                                          NaN
# retweeted_status.quoted_status.possibly_sensitive                                                             NaN
# retweeted_status.quoted_status.retweet_count                                                                  NaN
# retweeted_status.quoted_status.retweeted                                                                      NaN
# retweeted_status.quoted_status.source                                                                         NaN
# retweeted_status.quoted_status.text                                                                           NaN
# retweeted_status.quoted_status.truncated                                                                      NaN
# retweeted_status.quoted_status.user.contributors_enabled                                                      NaN
# retweeted_status.quoted_status.user.created_at                                                                NaN
# retweeted_status.quoted_status.user.default_profile                                                           NaN
# retweeted_status.quoted_status.user.default_profile_image                                                     NaN
# retweeted_status.quoted_status.user.description                                                               NaN
# retweeted_status.quoted_status.user.entities.description.urls                                                 NaN
# retweeted_status.quoted_status.user.entities.url.urls                                                         NaN
# retweeted_status.quoted_status.user.favourites_count                                                          NaN
# retweeted_status.quoted_status.user.follow_request_sent                                                       NaN
# retweeted_status.quoted_status.user.followers_count                                                           NaN
# retweeted_status.quoted_status.user.following                                                                 NaN
# retweeted_status.quoted_status.user.friends_count                                                             NaN
# retweeted_status.quoted_status.user.geo_enabled                                                               NaN
# retweeted_status.quoted_status.user.has_extended_profile                                                      NaN
# retweeted_status.quoted_status.user.id                                                                        NaN
# retweeted_status.quoted_status.user.id_str                                                                    NaN
# retweeted_status.quoted_status.user.is_translation_enabled                                                    NaN
# retweeted_status.quoted_status.user.is_translator                                                             NaN
# retweeted_status.quoted_status.user.lang                                                                      NaN
# retweeted_status.quoted_status.user.listed_count                                                              NaN
# retweeted_status.quoted_status.user.location                                                                  NaN
# retweeted_status.quoted_status.user.name                                                                      NaN
# retweeted_status.quoted_status.user.notifications                                                             NaN
# retweeted_status.quoted_status.user.profile_background_color                                                  NaN
# retweeted_status.quoted_status.user.profile_background_image_url                                              NaN
# retweeted_status.quoted_status.user.profile_background_image_url_https                                        NaN
# retweeted_status.quoted_status.user.profile_background_tile                                                   NaN
# retweeted_status.quoted_status.user.profile_banner_url                                                        NaN
# retweeted_status.quoted_status.user.profile_image_url                                                         NaN
# retweeted_status.quoted_status.user.profile_image_url_https                                                   NaN
# retweeted_status.quoted_status.user.profile_link_color                                                        NaN
# retweeted_status.quoted_status.user.profile_sidebar_border_color                                              NaN
# retweeted_status.quoted_status.user.profile_sidebar_fill_color                                                NaN
# retweeted_status.quoted_status.user.profile_text_color                                                        NaN
# retweeted_status.quoted_status.user.profile_use_background_image                                              NaN
# retweeted_status.quoted_status.user.protected                                                                 NaN
# retweeted_status.quoted_status.user.screen_name                                                               NaN
# retweeted_status.quoted_status.user.statuses_count                                                            NaN
# retweeted_status.quoted_status.user.time_zone                                                                 NaN
# retweeted_status.quoted_status.user.translator_type                                                           NaN
# retweeted_status.quoted_status.user.url                                                                       NaN
# retweeted_status.quoted_status.user.utc_offset                                                                NaN
# retweeted_status.quoted_status.user.verified                                                                  NaN
# retweeted_status.quoted_status_id                                                                             NaN
# retweeted_status.quoted_status_id_str                                                                         NaN
# retweeted_status.retweet_count                                                                                NaN
# retweeted_status.retweeted                                                                                    NaN
# retweeted_status.source                                                                                       NaN
# retweeted_status.text                                                                                         NaN
# retweeted_status.truncated                                                                                    NaN
# retweeted_status.user.contributors_enabled                                                                    NaN
# retweeted_status.user.created_at                                                                              NaN
# retweeted_status.user.default_profile                                                                         NaN
# retweeted_status.user.default_profile_image                                                                   NaN
# retweeted_status.user.description                                                                             NaN
# retweeted_status.user.entities.description.urls                                                               NaN
# retweeted_status.user.entities.url.urls                                                                       NaN
# retweeted_status.user.favourites_count                                                                        NaN
# retweeted_status.user.follow_request_sent                                                                     NaN
# retweeted_status.user.followers_count                                                                         NaN
# retweeted_status.user.following                                                                               NaN
# retweeted_status.user.friends_count                                                                           NaN
# retweeted_status.user.geo_enabled                                                                             NaN
# retweeted_status.user.has_extended_profile                                                                    NaN
# retweeted_status.user.id                                                                                      NaN
# retweeted_status.user.id_str                                                                                  NaN
# retweeted_status.user.is_translation_enabled                                                                  NaN
# retweeted_status.user.is_translator                                                                           NaN
# retweeted_status.user.lang                                                                                    NaN
# retweeted_status.user.listed_count                                                                            NaN
# retweeted_status.user.location                                                                                NaN
# retweeted_status.user.name                                                                                    NaN
# retweeted_status.user.notifications                                                                           NaN
# retweeted_status.user.profile_background_color                                                                NaN
# retweeted_status.user.profile_background_image_url                                                            NaN
# retweeted_status.user.profile_background_image_url_https                                                      NaN
# retweeted_status.user.profile_background_tile                                                                 NaN
# retweeted_status.user.profile_banner_url                                                                      NaN
# retweeted_status.user.profile_image_url                                                                       NaN
# retweeted_status.user.profile_image_url_https                                                                 NaN
# retweeted_status.user.profile_link_color                                                                      NaN
# retweeted_status.user.profile_sidebar_border_color                                                            NaN
# retweeted_status.user.profile_sidebar_fill_color                                                              NaN
# retweeted_status.user.profile_text_color                                                                      NaN
# retweeted_status.user.profile_use_background_image                                                            NaN
# retweeted_status.user.protected                                                                               NaN
# retweeted_status.user.screen_name                                                                             NaN
# retweeted_status.user.statuses_count                                                                          NaN
# retweeted_status.user.time_zone                                                                               NaN
# retweeted_status.user.translator_type                                                                         NaN
# retweeted_status.user.url                                                                                     NaN
# retweeted_status.user.utc_offset                                                                              NaN
# retweeted_status.user.verified                                                                                NaN
# source                                                                    <a href="http://twitter.com/download...
# stock                                                                                                        GNUS
# text                                                                      I think it’s an elevator down to 1.8...
# truncated                                                                                                   False
# user.contributors_enabled                                                                                   False
# user.created_at                                                                    Sat Feb 02 07:39:11 +0000 2019
# user.default_profile                                                                                         True
# user.default_profile_image                                                                                  False
# user.description                                                          Follow Me For Stock Related News & U...
# user.entities.description.urls                                                                                 []
# user.entities.url.urls                                                                                        NaN
# user.favourites_count                                                                                        1088
# user.follow_request_sent                                                                                     None
# user.followers_count                                                                                           33
# user.following                                                                                               None
# user.friends_count                                                                                             27
# user.geo_enabled                                                                                            False
# user.has_extended_profile                                                                                   False
# user.id                                                                                                1.0916e+18
# user.id_str                                                                                   1091601911558623232
# user.is_translation_enabled                                                                                 False
# user.is_translator                                                                                          False
# user.lang                                                                                                    None
# user.listed_count                                                                                               0
# user.location                                                                                                  🇺🇸
# user.name                                                                                           Critical Edge
# user.notifications                                                                                           None
# user.profile_background_color                                                                              F5F8FA
# user.profile_background_image_url                                                                            None
# user.profile_background_image_url_https                                                                      None
# user.profile_background_tile                                                                                False
# user.profile_banner_url                                                   https://pbs.twimg.com/profile_banner...
# user.profile_image_url                                                    http://pbs.twimg.com/profile_images/...
# user.profile_image_url_https                                              https://pbs.twimg.com/profile_images...
# user.profile_link_color                                                                                    1DA1F2
# user.profile_sidebar_border_color                                                                          C0DEED
# user.profile_sidebar_fill_color                                                                            DDEEF6
# user.profile_text_color                                                                                    333333
# user.profile_use_background_image                                                                            True
# user.protected                                                                                              False
# user.screen_name                                                                                     EdgeCritical
# user.statuses_count                                                                                          1047
# user.time_zone                                                                                               None
# user.translator_type                                                                                         none
# user.url                                                                                                     None
# user.utc_offset                                                                                              None
# user.verified                                                                                               False
# Name: Fri Mar 19 19:09:42 +0000 2021, dtype: object

# %%
# Test 
test_list = twitter_data.get_stock_tweets_list('GNUS', '2021-2-22')

# %%
print(len(test_list))
# Out:
# 1054

# %%
start_date = dt.date(year=2021, month=2, day=22)
end_date = dt.date(year=2021, month=3, day=23)
print(start_date)
print(end_date)
# Out:
# 2021-02-22
# 2021-03-23

# %%
# Test 
test_list_dt = twitter_data.get_stock_tweets_list('GNUS', start_date)

# %%
print(len(test_list_dt))
# Out:
# 1055

# %%
start_date = dt.date(year=2021, month=2, day=22)
end_date = dt.date(year=2021, month=2, day=28)
print(start_date)
print(end_date)
# Out:
# 2021-02-22
# 2021-02-28

# %%
GME_df = twitter_data.generate_df(['GME'], start_date, end_date)
# Out:
# 2021-02-22
# 2021-02-28
# (0, 1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-31f66d17d825> in <module>
# ----> 1 GME_df = twitter_data.generate_df(['GME'], start_date, end_date)
#
# ~\Documents\BU\CS_506\final_project\CS506Spring2021Repository\gilgo_padavick_final_project\code\data_aquisition\twitter_data.py in generate_df(stocks, start_date, end_date)
#      26         data = data.append(stock_data)
#      27     print(data.shape)
# ---> 28     data = data.set_index('created_at')
#      29     return data
#      30
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['created_at'] are in the columns"

# %%
# Test 
test_list_dt = twitter_data.get_stock_tweets_list('GME', '2021-02-22', '2021-02-28')
# Out:
# 2021-02-22
# 2021-02-28

# %%
print(len(test_list_dt))
# Out:
# 0

# %%
def get_stock_tweets_list(stock, start_date, end_date=None):
    searched_tweets = [status for status in tweepy.Cursor(api.search, q="${}".format(stock), since=start_date, until=end_date).items()]
    return searched_tweets

# %%
def generate_df(stocks, start_date, end_date):
    data = pd.DataFrame()
    for stock in stocks:
        tweets = get_stock_tweets_list(stock, start_date, end_date)
        json_data = [tweet._json for tweet in tweets]
        stock_data = pd.io.json.json_normalize(json_data)
        stock_data['stock'] = stock
        data = data.append(stock_data)
    print(data.shape)
    data = data.set_index('created_at')
    return data

# %%
GME_df = generate_df(['GME'], start_date, end_date)
# Out:
# (0, 1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-87021bd30cf4> in <module>
# ----> 1 GME_df = generate_df(['GME'], start_date, end_date)
#
# <ipython-input-7-445e8cbb6bbe> in generate_df(stocks, start_date, end_date)
#       8         data = data.append(stock_data)
#       9     print(data.shape)
# ---> 10     data = data.set_index('created_at')
#      11     return data
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['created_at'] are in the columns"
