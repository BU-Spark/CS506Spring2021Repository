# %% [markdown]
# # Here we conducted some preliminary analysis of our final dataset.
#
# ### This analysis was not used directly in our final conclusions/report, but was instead an initial look at the discrepencies in our dataset. After executing this code, we were able to identify flaws in our data and then address these issues with our PM & client.
#
# ### Additionally, we found better approaches to get the same information, like total amounts contributed by each individ

# %%
import pandas as pd

# %%
df = pd.read_csv('mergedEARNINGS.csv')
df = df.drop(['Unnamed: 0'],axis=1)
df
# Out:
#                    Name            Rank   Race    Year        CaseID  \
# 0      joseph abasciano  Police Officer  White  2011.0  IAD2011-0182
# 1      joseph abasciano  Police Officer  White  2011.0  IAD2011-0182
# 2      joseph abasciano  Police Officer  White  2011.0  IAD2011-0182
# 3      joseph abasciano  Police Officer  White  2011.0  IAD2011-0182
# 4      joseph abasciano  Police Officer  White  2013.0  IAD2013-0019
# ...                 ...             ...    ...     ...           ...
# 8816    vladimir xavier  Police Officer  Black  2012.0  IAD2012-0009
# 8817    vladimir xavier  Police Officer  Black  2014.0  IAD2014-0255
# 8818  anthony d ierardi        Sergeant  White  2017.0  IAD2017-0154
# 8819     robert m zingg       Detective  White  2011.0  IAD2011-0553
# 8820     robert m zingg       Detective  White  2012.0  IAD2012-0039
#
#             TypeOfMisconduct                   Allegation        Finding  \
# ...

# %% [markdown]
# ## This was an attempt to find total sums of the amounts contributed by each individual. In our final deliverable (deliverable5) folder, you can find a better execution of this in visualizations.ipynb.

# %%
s = df.groupby('Name')['Amount'].sum()
s.sum
# Out:
# <bound method Series.sum of Name
# adrian pinto             500.0
# adrian s worrell        3150.0
# agnaldo p monteiro     15000.0
# alberto santiago        1250.0
# alexis herrera-brea        0.0
#                         ...
# william leo parlon     13512.0
# william r hubbard       6000.0
# winifred cotter        21100.0
# winston deleon          1250.0
# ydritzabel oller        1000.0
# Name: Amount, Length: 412, dtype: float64>

# %%
df[['Name','Amount']]
# Out:
#                    Name  Amount
# 0      joseph abasciano   64.35
# 1      joseph abasciano   99.71
# 2      joseph abasciano   64.35
# 3      joseph abasciano   99.71
# 4      joseph abasciano   64.35
# ...                 ...     ...
# 8816    vladimir xavier   20.00
# 8817    vladimir xavier   20.00
# 8818  anthony d ierardi  500.00
# 8819     robert m zingg  500.00
# 8820     robert m zingg  500.00
#
# [8821 rows x 2 columns]

# %%
unique = df.drop_duplicates(subset = ["Name"])
unique
# Out:
#                      Name            Rank      Race    Year        CaseID  \
# 0        joseph abasciano  Police Officer     White  2011.0  IAD2011-0182
# 60            cesar abreu  Police Officer  Hispanic  2011.0  IAD2011-0548
# 90           luis m anjos  Police Officer     Black  2013.0  IAD2013-0019
# 130     christopher adams  Police Officer     White  2019.0  IAD2019-0207
# 134   christopher p adams  Police Officer     White  2011.0  IAD2011-0568
# ...                   ...             ...       ...     ...           ...
# 8772     dante b williams       Detective  Hispanic  2012.0  IAD2012-0239
# 8802      fred r williams      Lieutenant     White  2012.0  IAD2012-0224
# 8815      vladimir xavier  Police Officer     Black  2012.0  IAD2012-0009
# 8818    anthony d ierardi        Sergeant     White  2017.0  IAD2017-0154
# 8819       robert m zingg       Detective     White  2011.0  IAD2011-0553
#
#             TypeOfMisconduct                   Allegation        Finding  \
# ...

# %%
unique.shape
# Out:
# (1439, 31)

# %%
s0 =df['Amount'].sum()
s0
# Out:
# 2431566.42

# %%
all_contributions = pd.read_csv('processedPoliceContributions.csv')
all_contributions = all_contributions.drop(['Unnamed: 0'],axis=1)
all_contributions
# Out:
#                     Address  Amount  CPF ID            City  \
# 0                22 WEST ST   100.0   13237   NEWTON CORNER
# 1               71 GROVE CR   100.0   13284       BRAINTREE
# 2             Ricca Farm Rd   200.0   15274       Billerica
# 3             8 Skipper Way   200.0   10419      Gloucester
# 4          156 Chuckles Way   100.0   14944  Marstons Mills
# ...                     ...     ...     ...             ...
# 10362           214 Read St   250.0   13597      Fall River
# 10363  20 Old Ironsides Way    25.0   16314     Charlestown
# 10364       14 Brierwood Rd   500.0   15960       Braintree
# 10365    24 Washburn Ave #1   100.0   13645       Cambridge
# 10366       30 Aldie Street   125.0   13645         Allston
#
#               Contributor       Date    Datetime                    Employer  \
# 0      allan l ciccone jr   1/7/2010  2010-01-07            TOWN OF SHERBORN
# 1         michael linskey  1/10/2010  2010-01-10                         NaN
# ...

# %%
all_contributions['Employer'] = all_contributions['Employer'].str.lower()
all_contributions['Occupation'] = all_contributions['Occupation'].str.lower()

# %%
all_contributions
# Out:
#        Unnamed: 0               Address  Amount  CPF ID            City  \
# 0               0            22 WEST ST   100.0   13237   NEWTON CORNER
# 1               1           71 GROVE CR   100.0   13284       BRAINTREE
# 2               2         Ricca Farm Rd   200.0   15274       Billerica
# 3               3         8 Skipper Way   200.0   10419      Gloucester
# 4               4      156 Chuckles Way   100.0   14944  Marstons Mills
# ...           ...                   ...     ...     ...             ...
# 10362       10363           214 Read St   250.0   13597      Fall River
# 10363       10364  20 Old Ironsides Way    25.0   16314     Charlestown
# 10364       10365       14 Brierwood Rd   500.0   15960       Braintree
# 10365       10366    24 Washburn Ave #1   100.0   13645       Cambridge
# 10366       10367       30 Aldie Street   125.0   13645         Allston
#
#               Contributor       Date    Datetime                    Employer  \
# ...

# %%
all_contributions.Occupation.unique()
# Out:
# array(['police officer', 'boston city police officer',
#        'retired police officer', 'police', 'chief of police',
#        'retired brockton police lt.', 'police officer 2011 ret 25',
#        'police chief', 'police officer/candidate', 'police sargeant',
#        'policeman', 'police sergeant', 'state police officer',
#        'state police', 'cheif police officer', 'retired state police',
#        'campus police officer', 'police sgt. (ret. quincy police dept.)',
#        'police office', 'police officer srgt.', 'police prosecutor',
#        'chief police', 'aux police chief', 'boston police dept.',
#        'sergeant mass state police', 'police lt',
#        'retired police captain', 'campus police', 'police captian',
#        'police commissioner', 'boston police officer',
#        'retired police chief town of sandwich', 'police officer, area b.',
#        'police sgt.', 'police officer/attorney', 'police dept',
#        'police officer ', 'retired chief of police',
# ...

# %%
# pol_only = all_contributions[all_contributions['DEPARTMENT_NAME'].str.contains('police', case=False, na=False)]]

# %%
bos_cont = all_contributions[all_contributions['Employer'].str.contains("boston",na = False)| all_contributions['Occupation'].str.contains('boston',na = False)]

# %%
bos_cont
# Out:
#                      Address  Amount  CPF ID          City  \
# 1                71 GROVE CR   100.0   13284     BRAINTREE
# 9      433 W Roxbury Parkway   100.0   13014        Dedham
# 12          9 Oakland Avenue   100.0   13014        Quincy
# 24          8 Berwick Street   250.0   13878  West Roxbury
# 28         38 Riverside Ave.   100.0   13729        Quincy
# ...                      ...     ...     ...           ...
# 10352        7 Glenburnie Rd   100.0   13173  West Roxbury
# 10357         651 Walpole St   250.0   13173       Norwood
# 10360        8 Eastbourne St   100.0   14092    Roslindale
# 10363   20 Old Ironsides Way    25.0   16314   Charlestown
# 10366        30 Aldie Street   125.0   13645       Allston
#
#               Contributor        Date    Datetime  \
# 1         michael linskey   1/10/2010  2010-01-10
# 9          brendan kelley   1/29/2010  2010-01-29
# 12          gerard bailey   1/31/2010  2010-01-31
# 24         james b conley    2/8/2010  2010-02-08
# ...

# %%
s_all = bos_cont['Amount'].dropna().sum()
s_all
# Out:
# 823368.2

# %%
bos_cont.shape
# Out:
# (3276, 19)

# %%
print('total contributions by all boston police', s_all)
print('contributions by indicted boston police',s0)
print('difference:',s_all - s0)
# Out:
# total contributions by all boston police 823368.2
# contributions by indicted boston police 2431566.42
# difference: -1608198.22
