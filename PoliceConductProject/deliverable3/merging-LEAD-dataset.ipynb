# %%
import pandas as pd
import numpy as np

# %%
final = pd.read_csv("filtered.csv")
lead = pd.read_csv("LEAD BPD cleaned.csv")

# %%
final
# Out:
#         Unnamed: 0              Name            Rank   Race  Year  \
# 0              216  joseph abasciano  Police Officer  White  2011
# 1              218  joseph abasciano  Police Officer  White  2011
# 2              476  joseph abasciano  Police Officer  White  2011
# 3              478  joseph abasciano  Police Officer  White  2011
# 4              736  joseph abasciano  Police Officer  White  2013
# ...            ...               ...             ...    ...   ...
# 101342     3833497      tommy t yung  Police Officer  Asian  2019
# 101343     3833504      tommy t yung  Police Officer  Asian  2019
# 101344     3833505      tommy t yung  Police Officer  Asian  2019
# 101345     3833506      tommy t yung  Police Officer  Asian  2019
# 101346     3833511      tommy t yung  Police Officer  Asian  2019
#
#               CaseID   TypeOfMisconduct Outcome               Address  Amount  \
# 0       IAD2011-0182  Citizen complaint     NaN  19 Grew Hill Rd, # 1   250.0
# 1       IAD2011-0182  Citizen complaint     NaN  19 Grew Hill Rd, # 1   400.0
# 2       IAD2011-0182  Citizen complaint     NaN  19 Grew Hill Rd, # 1   250.0
# 3       IAD2011-0182  Citizen complaint     NaN  19 Grew Hill Rd, # 1   400.0
# 4       IAD2013-0019  Citizen complaint     NaN  19 Grew Hill Rd, # 1   250.0
# ...              ...                ...     ...                   ...     ...
# 101342  IAD2019-0294  Citizen complaint     NaN   16 Saint Brendan Rd   250.0
# 101343  IAD2019-0294  Citizen complaint     NaN   16 Saint Brendan Rd   500.0
# 101344  IAD2019-0294  Citizen complaint     NaN   16 Saint Brendan Rd   500.0
# 101345  IAD2019-0294  Citizen complaint     NaN   16 Saint Brendan Rd   200.0
# 101346  IAD2019-0294  Citizen complaint     NaN   16 Saint Brendan Rd   500.0
#
#         ...  Principal Officer  \
# 0       ...                NaN
# 1       ...                NaN
# 2       ...                NaN
# 3       ...                NaN
# 4       ...                NaN
# ...     ...                ...
# 101342  ...                NaN
# 101343  ...                NaN
# 101344  ...                NaN
# 101345  ...                NaN
# 101346  ...                NaN
#
#                                                 Recipient  \
# 0                                        Walsh, Martin J.
# 1                                        Walsh, Martin J.
# 2                                        Walsh, Martin J.
# 3                                        Walsh, Martin J.
# 4                                        Walsh, Martin J.
# ...                                                   ...
# 101342                              Rosenberg, Stanley C.
# 101343  Committee for a Democratic Senate Pol Action C...
# 101344                                   Walsh, Martin J.
# 101345                                       Baker, Frank
# 101346  Committee for a Democratic Senate Pol Action C...
#
#        Record Type Description Record Type ID         Source Description  \
# 0                   Individual            201    10/15/13 Deposit Report
# 1                   Individual            201      4/3/18 Deposit Report
# 2                   Individual            201    10/15/13 Deposit Report
# 3                   Individual            201      4/3/18 Deposit Report
# 4                   Individual            201    10/15/13 Deposit Report
# ...                        ...            ...                        ...
# 101342              Individual            201  2017 Year-end Report (ND)
# 101343              Individual            201    11/13/18 Deposit Report
# 101344              Individual            201    11/28/18 Deposit Report
# 101345              Individual            201     12/4/18 Deposit Report
# 101346              Individual            201    12/27/19 Deposit Report
#
#        State Tender Type Description  Tender Type ID  \
# 0         MA             Credit Card               3
# 1         MA             Credit Card               3
# 2         MA             Credit Card               3
# 3         MA             Credit Card               3
# 4         MA             Credit Card               3
# ...      ...                     ...             ...
# 101342    MA           Not Specified               0
# 101343    MA                   Check               1
# 101344    MA                   Check               1
# 101345    MA                   Check               1
# 101346    MA                   Check               1
#
#                                         UUID         Zip
# 0       f9a7830b-7466-5bc5-906f-5e1662441640  02131-4910
# 1       05cd1387-8bd3-5359-a769-cfd038293138  02131-4910
# 2       f9a7830b-7466-5bc5-906f-5e1662441640  02131-4910
# 3       05cd1387-8bd3-5359-a769-cfd038293138  02131-4910
# 4       f9a7830b-7466-5bc5-906f-5e1662441640  02131-4910
# ...                                      ...         ...
# 101342  3a640963-a4ee-5ce7-a465-216fbecc2663  02124-5813
# 101343  0df2dbb8-d1cf-540d-9122-9656fa0a52fc  02124-5813
# 101344  f0d0099b-41c8-5926-af94-e93ae5aae94c  02124-5813
# 101345  c6f8321d-26da-5eee-bd80-5d7250e7f94c  02124-5813
# 101346  19347dab-d538-530c-a39c-34dcba807297  02124-5813
#
# [101347 rows x 27 columns]

# %%
lead
# Out:
#     INDEX                      NAME  DATE ADDED AGENCY  \
# 0       7          dorston bartlett   9/25/2020    BPD
# 1      12           leonard f brown   9/25/2020    BPD
# 2      13         grant e callender   9/25/2020    BPD
# 3      15              james carnes   9/25/2020    BPD
# 4      19               james clark   6/14/2017    BPD
# 5      21           domenic columbo   9/25/2020    BPD
# 6      22             kendra conway   9/25/2020    BPD
# 7      24        christopher curtis   9/25/2020    BPD
# 8      25            john danilecki   9/25/2020    BPD
# 9      27        mila depina-cooley   6/19/2017    BPD
# 10     28                edgar diaz   9/25/2020    BPD
# 11     29             henry doherty   9/25/2020    BPD
# 12     30           michael doherty   9/25/2020    BPD
# 13     31            david finnerty   9/25/2020    BPD
# 14     32         paul a fitzgerald   9/25/2020    BPD
# 15     36            sandro fonseca   9/25/2020    BPD
# 16     38            korey franklin   9/25/2020    BPD
# 17     49   anthony handleman-smith   9/25/2020    BPD
# 18     54       alexis herrera-brea   9/25/2020    BPD
# 19     55             jarrett hesse   9/25/2020    BPD
# 20     60          trent w. holland   9/25/2020    BPD
# 21     62             haseeb hosein   9/25/2020    BPD
# 22     73               jovan lacet   9/25/2020    BPD
# 23     75               diana lopez   9/25/2020    BPD
# 24     76          michael lopriore   9/25/2020    BPD
# 25     77              joseph lynch   9/25/2020    BPD
# 26     80      frederick g. marzano   9/25/2020    BPD
# 27     82       patrick j. mccarthy   9/25/2020    BPD
# 28     84       patricia mcgoldrick   9/25/2020    BPD
# 29     87  angela mitchell-williams   9/25/2020    BPD
# 30     88          richard moriarty   9/18/2018    BPD
# 31     91            michael murphy   9/25/2020    BPD
# 32     92                joseph nee   9/25/2020    BPD
# 33     93             ronald nelson   9/25/2020    BPD
# 34     94            gerard o'brien   9/25/2020    BPD
# 35     96               eddie odney   6/19/2017    BPD
# 36     97          dale t o'donnell   9/25/2020    BPD
# 37    100               kenny orcel   9/25/2020    BPD
# 38    103        junior a. phillips   9/25/2020    BPD
# 39    110      william j. robertson   9/25/2020    BPD
# 40    112              patrick rose    9/25/202    BPD
# 41    113       daniel j. rosenthal   9/25/2020    BPD
# 42    115         vaden scantlebury   9/25/2020    BPD
# 43    117          brian smigielski   10/5/2015    BPD
# 44    118                mel steele  10/17/2014    BPD
# 45    119           monicka stinson   9/25/2020    BPD
# 46    120           ryan p sullivan   9/25/2020    BPD
# 47    127          timothy torigian   9/25/2020    BPD
# 48    128            robert m tully   9/25/2020    BPD
# 49    129          robert twitchell   9/25/2020    BPD
# 50    130                royce veal   9/25/2020    BPD
# 51    131            emmet t. walsh   9/25/2020    BPD
# 52    132          robert g. warren   9/25/2020    BPD
# 53    134           william woodley   9/25/2020    BPD
#
#                             STATUS  \
# 0                         Indicted
# 1                        Sustained
# 2                        Sustained
# 3                         Indicted
# 4                   No Prosecution
# 5                         Indicted
# 6                         Indicted
# 7                         Indicted
# 8                           Public
# 9                         Indicted
# 10                       Sustained
# 11                        Indicted
# 12                      Conviction
# 13                        Indicted
# 14                       Sustained
# 15                            CWOF
# 16                        Indicted
# 17                       Sustained
# 18  Criminal Complaint - Arraigned
# 19                       Sustained
# 20                           Filed
# 21                       Sustained
# 22                      Terminated
# 23                        Indicted
# 24                            CWOF
# 25              Open Investigation
# 26                          Public
# 27                       Sustained
# 28                       Sustained
# 29                            CWOF
# 30                     Discredited
# 31                        Indicted
# 32                            CWOF
# 33                        Indicted
# 34                        Indicted
# 35                      Conviction
# 36                           Filed
# 37            Indicted (Nol Pros.)
# 38                       Sustained
# 39                       Sustained
# 40  Criminal Complaint - Arraigned
# 41                           Filed
# 42              Open Investigation
# 43                      Conviction
# 44                      Conviction
# 45                        Indicted
# 46                       Sustained
# 47                        Indicted
# 48                       Sustained
# 49                        Indicted
# 50                       Sustained
# 51                          Public
# 52                       Sustained
# 53                            CWOF
#
#                      INFORMATION REGARDING LEAD ENTRY
# 0   ABDW, False Police Report. Retired. SCDAO inve...
# 1   BPD internal investigation (conformance to law...
# 2   BPD internal investigation (conformance to law...
# 3   Conspiracy/embezzlement: Time & attendance. US...
# 4   Alleged Forgery/Uttering. Reported to BPD IAD ...
# 5   OUI-Serious Bodily Injury. SCDAO investigation...
# 6   Conspiracy/embezzlement: Time & attendance. US...
# 7   Witness intimidation, False Report, CORI Viola...
# 8   Open BPD Internal Affairs investigations. Bost...
# 9   Receiving stolen merchandise. SCDAO investigat...
# 10  BPD internal investigation (3 counts of confor...
# 11  Conspiracy/embezzlement: Time & attendance. US...
# 12  AB (2 counts), AB to Intimidate, Use without A...
# 13  Accessory After ABDW, Filing False Police Repo...
# 14  BPD internal investigation (conformance to law...
# 15  Assault with a dangerous weapon, carrying a fi...
# 16  Misleading Investigators. SCDAO investigation/...
# 17  BPD internal investigation (conformance to law...
# 18  ABDW Family Member. SCDAO investigation/prosec...
# 19  Resigned during the pendancy of a 2017 BPD int...
# 20  BPD internal investigation (allegation conform...
# 21  Internal Affairs investigation alleged corrupt...
# 22  Alleged perjury. BPD Spokesperson confirmed te...
# 23  Conspiracy/embezzlement: Time & attendance. US...
# 24  Larceny. SCDAO investigation/prosecution. CWOF...
# 25  Alleged racial slurs (09/13/2019 noise complai...
# 26  BPD internal investigation (conformance to law...
# 27  BPD internal investigation (conformance to law...
# 28  BPD internal investigation (conformance to law...
# 29  Improper firearm storage. SCDAO investigation/...
# 30  Motion To Suppress (Judge Mary Ames Suffolk Su...
# 31  Conspiracy/embezzlement: Time & attendance. US...
# 32  Larceny, money laundering. Joint investigation...
# 33  Conspiracy/embezzlement: Time & attendance. US...
# 34  Conspiracy/embezzlement: Time & attendance. US...
# 35  Access device fraud. USAO investigation/prosec...
# 36  BPD internal investigation (allegation conform...
# 37  Accessory After ABDW, Filing False Police Repo...
# 38  BPD internal investigation (conformance to law...
# 39  BPD internal investigation (conformance to law...
# 40  Aggravated Rape of Child, Rape of Child. SCDAO...
# 41  BPD internal investigation (allegation conform...
# 42  Alleged ABDW, Witness Intimidation, Perjury. S...
# 43  USAO investigation/prosecution. Guilty plea. S...
# 44  USAO investigation/prosecution. Guilty plea. S...
# 45  Witness intimidation. SCDAO investigation/pros...
# 46  BPD internal investigation (conformance to law...
# 47  Conspiracy/embezzlement: Time & attendance. US...
# 48  BPD internal investigation (conformance to law...
# 49  Conspiracy/embezzlement: Time & attendance. US...
# 50  BPD internal investigation (conformance to law...
# 51  BPD internal investigation (conformance to law...
# 52  BPD internal investigation (conformance to law...
# 53  Larceny: Time & attendance/overtime. SCDAO inv...

# %%
lead['NAME'].isin(final['Name']).value_counts()
# Out:
# False    41
# True     13
# Name: NAME, dtype: int64

# %%
final.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Rank', 'Race', 'Year', 'CaseID',
#        'TypeOfMisconduct', 'Outcome', 'Address', 'Amount', 'CPF ID', 'City',
#        'Contributor', 'Date', 'Datetime', 'Employer', 'Occupation',
#        'Principal Officer', 'Recipient', 'Record Type Description',
#        'Record Type ID', 'Source Description', 'State',
#        'Tender Type Description', 'Tender Type ID', 'UUID', 'Zip'],
#       dtype='object')

# %%
lead.columns
# Out:
# Index(['INDEX', 'NAME', 'DATE ADDED', 'AGENCY', 'STATUS',
#        'INFORMATION REGARDING LEAD ENTRY'],
#       dtype='object')

# %%
lead['Name'] = lead['NAME']
lead = lead.drop(['NAME'],axis=1)

# %%
df_merge = final.merge(lead,how='outer',on = 'Name')

# %%
df_merge
# Out:
#         Unnamed: 0              Name            Rank   Race    Year  \
# 0            216.0  joseph abasciano  Police Officer  White  2011.0
# 1            218.0  joseph abasciano  Police Officer  White  2011.0
# 2            476.0  joseph abasciano  Police Officer  White  2011.0
# 3            478.0  joseph abasciano  Police Officer  White  2011.0
# 4            736.0  joseph abasciano  Police Officer  White  2013.0
# ...            ...               ...             ...    ...     ...
# 101383         NaN  robert twitchell             NaN    NaN     NaN
# 101384         NaN        royce veal             NaN    NaN     NaN
# 101385         NaN    emmet t. walsh             NaN    NaN     NaN
# 101386         NaN  robert g. warren             NaN    NaN     NaN
# 101387         NaN   william woodley             NaN    NaN     NaN
#
#               CaseID   TypeOfMisconduct Outcome               Address  Amount  \
# 0       IAD2011-0182  Citizen complaint     NaN  19 Grew Hill Rd, # 1   250.0
# 1       IAD2011-0182  Citizen complaint     NaN  19 Grew Hill Rd, # 1   400.0
# 2       IAD2011-0182  Citizen complaint     NaN  19 Grew Hill Rd, # 1   250.0
# 3       IAD2011-0182  Citizen complaint     NaN  19 Grew Hill Rd, # 1   400.0
# 4       IAD2013-0019  Citizen complaint     NaN  19 Grew Hill Rd, # 1   250.0
# ...              ...                ...     ...                   ...     ...
# 101383           NaN                NaN     NaN                   NaN     NaN
# 101384           NaN                NaN     NaN                   NaN     NaN
# 101385           NaN                NaN     NaN                   NaN     NaN
# 101386           NaN                NaN     NaN                   NaN     NaN
# 101387           NaN                NaN     NaN                   NaN     NaN
#
#         ...  State Tender Type Description Tender Type ID  \
# 0       ...     MA             Credit Card            3.0
# 1       ...     MA             Credit Card            3.0
# 2       ...     MA             Credit Card            3.0
# 3       ...     MA             Credit Card            3.0
# 4       ...     MA             Credit Card            3.0
# ...     ...    ...                     ...            ...
# 101383  ...    NaN                     NaN            NaN
# 101384  ...    NaN                     NaN            NaN
# 101385  ...    NaN                     NaN            NaN
# 101386  ...    NaN                     NaN            NaN
# 101387  ...    NaN                     NaN            NaN
#
#                                         UUID         Zip  INDEX DATE ADDED  \
# 0       f9a7830b-7466-5bc5-906f-5e1662441640  02131-4910    NaN        NaN
# 1       05cd1387-8bd3-5359-a769-cfd038293138  02131-4910    NaN        NaN
# 2       f9a7830b-7466-5bc5-906f-5e1662441640  02131-4910    NaN        NaN
# 3       05cd1387-8bd3-5359-a769-cfd038293138  02131-4910    NaN        NaN
# 4       f9a7830b-7466-5bc5-906f-5e1662441640  02131-4910    NaN        NaN
# ...                                      ...         ...    ...        ...
# 101383                                   NaN         NaN  129.0  9/25/2020
# 101384                                   NaN         NaN  130.0  9/25/2020
# 101385                                   NaN         NaN  131.0  9/25/2020
# 101386                                   NaN         NaN  132.0  9/25/2020
# 101387                                   NaN         NaN  134.0  9/25/2020
#
#         AGENCY     STATUS                   INFORMATION REGARDING LEAD ENTRY
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
# ...        ...        ...                                                ...
# 101383     BPD   Indicted  Conspiracy/embezzlement: Time & attendance. US...
# 101384     BPD  Sustained  BPD internal investigation (conformance to law...
# 101385     BPD     Public  BPD internal investigation (conformance to law...
# 101386     BPD  Sustained  BPD internal investigation (conformance to law...
# 101387     BPD       CWOF  Larceny: Time & attendance/overtime. SCDAO inv...
#
# [101388 rows x 32 columns]

# %%
df_merge.to_csv("final_dataset.csv")
