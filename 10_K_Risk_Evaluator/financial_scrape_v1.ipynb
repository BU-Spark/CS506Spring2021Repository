# %% [markdown]
# # Scrape Financial Metrics
# ### This will output dataframes containing financial metrics

# %%
# import our libraries
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# define the base url needed to create the file url.
base_url = r"https://www.sec.gov"

# convert a normal url to a document url
normal_url = r"https://www.sec.gov/Archives/edgar/data/1265107/0001265107-19-000004.txt"
normal_url = normal_url.replace('-','').replace('.txt','/index.json')

# define a url that leads to a 10k document landing page
documents_url = r"https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/index.json"

# request the url and decode it.
content = requests.get(documents_url).json()

for file in content['directory']['item']:
    
    # Grab the filing summary and create a new url leading to the file so we can download it.
    if file['name'] == 'FilingSummary.xml':

        xml_summary = base_url + content['directory']['name'] + "/" + file['name']
        
        print('-' * 100)
        print('File Name: ' + file['name'])
        print('File Path: ' + xml_summary)
# Out:
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/FilingSummary.xml

# %%
print(xml_summary)
# Out:
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/FilingSummary.xml

# %% [markdown]
# # Grab XML SUM
# need to automate url

# %%
# define the base url needed to create the file url.
base_url = r"https://www.sec.gov"


# convert a normal url to a document url
#normal_url = r"https://www.sec.gov/Archives/edgar/data/1265107/0001265107-19-000004.txt"
normal_url = r"https://www.sec.gov/Archives/edgar/data/2488/0001628280-21-001185.txt"
#OG_url = r"https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/0001628280-21-001185.txt"
normal_url = normal_url.replace('-','').replace('.txt','/index.json')

# define a url that leads to a 10k document landing page
#documents_url = r"https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/index.json"
documents_url = normal_url
# request the url and decode it.
content = requests.get(documents_url).json()

for file in content['directory']['item']:

    
    # Grab the filing summary and create a new url leading to the file so we can download it.
    if file['name'] == 'FilingSummary.xml':

        xml_summary = base_url + content['directory']['name'] + "/" + file['name']
        print(xml_summary)
        
        print('-' * 100)
        print('File Name: ' + file['name'])
        print('File Path: ' + xml_summary)
# Out:
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/FilingSummary.xml
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/FilingSummary.xml

# %%
test_url = r"https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/0001628280-21-001185.txt"

# %%
base_url = xml_summary.replace('FilingSummary.xml', '')

# request and parse the content
content = requests.get(xml_summary).content
soup = BeautifulSoup(content, 'lxml') #format xml

# find the 'myreports' tag because this contains all the individual reports submitted.
reports = soup.find('myreports')

# I want a list to store all the individual components of the report, so create the master list.
master_reports = []

# loop through each report in the 'myreports' tag but avoid the last one as this will cause an error.
for report in reports.find_all('report')[:-1]:


    # let's create a dictionary to store all the different parts we need.
    report_dict = {}
    report_dict['name_short'] = report.shortname.text
    report_dict['name_long'] = report.longname.text
    report_dict['position'] = report.position.text
    report_dict['category'] = report.menucategory.text
    report_dict['url'] = base_url + report.htmlfilename.text

    # append the dictionary to the master list.
    master_reports.append(report_dict)

    # print the info to the user.
    print('-'*100)
    print(base_url + report.htmlfilename.text)
    print(report.longname.text)
    print(report.shortname.text)
    print(report.menucategory.text)
    print(report.position.text)
# Out:
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R1.htm
# 0001001 - Document - Cover Page
# Cover Page
# Cover
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R2.htm
# 1001002 - Statement - Consolidated Statements of Operations
# Consolidated Statements of Operations
# Statements
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R3.htm
# 1002003 - Statement - Consolidated Statements of Comprehensive Income
# Consolidated Statements of Comprehensive Income
# Statements
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R4.htm
# 1003004 - Statement - Consolidated Balance Sheets
# Consolidated Balance Sheets
# Statements
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R5.htm
# 1004005 - Statement - Consolidated Balance Sheets (Parenthetical)
# Consolidated Balance Sheets (Parenthetical)
# Statements
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R6.htm
# 1005006 - Statement - Consolidated Statements of Stockholders Equity
# Consolidated Statements of Stockholders Equity
# Statements
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R7.htm
# 1006007 - Statement - Consolidated Statements of Cash Flows
# Consolidated Statements of Cash Flows
# Statements
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R8.htm
# 2101101 - Disclosure - The Company
# The Company
# Notes
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R9.htm
# 2102102 - Disclosure - Summary of Significant Accounting Policies
# Summary of Significant Accounting Policies
# Notes
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R10.htm
# 2105103 - Disclosure - Supplemental Balance Sheet Information
# Supplemental Balance Sheet Information
# Notes
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R11.htm
# 2109104 - Disclosure - Related Parties - Equity Joint Ventures
# Related Parties - Equity Joint Ventures
# Notes
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R12.htm
# 2111105 - Disclosure - Goodwill
# Goodwill
# Notes
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R13.htm
# 2113106 - Disclosure - Debt and Revolving Credit Facility
# Debt and Revolving Credit Facility
# Notes
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R14.htm
# 2119107 - Disclosure - Financial Instruments
# Financial Instruments
# Notes
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R15.htm
# 2123108 - Disclosure - Accumulated Other Comprehensive Income (Loss)
# Accumulated Other Comprehensive Income (Loss)
# Notes
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R16.htm
# 2126109 - Disclosure - Concentrations of Credit and Operation Risk
# Concentrations of Credit and Operation Risk
# Notes
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R17.htm
# 2128110 - Disclosure - Earnings Per Share
# Earnings Per Share
# Notes
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R18.htm
# 2131111 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans
# Common Stock and Stock-Based Incentive Compensation Plans
# Notes
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R19.htm
# 2141112 - Disclosure - Retirement Benefit Plans
# Retirement Benefit Plans
# Notes
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R20.htm
# 2143113 - Disclosure - Income Taxes
# Income Taxes
# Notes
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R21.htm
# 2154114 - Disclosure - Segment Reporting
# Segment Reporting
# Notes
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R22.htm
# 2161115 - Disclosure - Other Expense, Net
# Other Expense, Net
# Notes
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R23.htm
# 2164116 - Disclosure - Commitments and Guarantees
# Commitments and Guarantees
# Notes
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R24.htm
# 2171117 - Disclosure - Contingencies
# Contingencies
# Notes
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R25.htm
# 2173118 - Disclosure - Pending Acquisition
# Pending Acquisition
# Notes
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R26.htm
# 2175119 - Disclosure - Supplementary Financial Information (unaudited)
# Supplementary Financial Information (unaudited)
# Notes
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R27.htm
# 2203201 - Disclosure - Summary of Significant Accounting Policies (Policies)
# Summary of Significant Accounting Policies (Policies)
# Policies
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R28.htm
# 2306301 - Disclosure - Supplemental Balance Sheet Information (Tables)
# Supplemental Balance Sheet Information (Tables)
# Tables
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R29.htm
# 2314302 - Disclosure - Debt and Revolving Credit Facility (Tables)
# Debt and Revolving Credit Facility (Tables)
# Tables
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R30.htm
# 2320303 - Disclosure - Financial Instruments (Tables)
# Financial Instruments (Tables)
# Tables
# 30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R31.htm
# 2324304 - Disclosure - Accumulated Other Comprehensive Income (Loss) (Tables)
# Accumulated Other Comprehensive Income (Loss) (Tables)
# Tables
# 31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R32.htm
# 2329305 - Disclosure - Earnings Per Share (Tables)
# Earnings Per Share (Tables)
# Tables
# 32
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R33.htm
# 2332306 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans (Tables)
# Common Stock and Stock-Based Incentive Compensation Plans (Tables)
# Tables
# 33
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R34.htm
# 2344307 - Disclosure - Income Taxes (Tables)
# Income Taxes (Tables)
# Tables
# 34
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R35.htm
# 2355308 - Disclosure - Segment Reporting (Tables)
# Segment Reporting (Tables)
# Tables
# 35
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R36.htm
# 2362309 - Disclosure - Other Expense, Net (Tables)
# Other Expense, Net (Tables)
# Tables
# 36
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R37.htm
# 2365310 - Disclosure - Commitments and Guarantees (Tables)
# Commitments and Guarantees (Tables)
# Tables
# 37
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R38.htm
# 2376311 - Disclosure - Supplementary Financial Information (unaudited) (Tables)
# Supplementary Financial Information (unaudited) (Tables)
# Tables
# 38
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R39.htm
# 2404401 - Disclosure - Summary of Significant Accounting Policies - Narrative (Details)
# Summary of Significant Accounting Policies - Narrative (Details)
# Details
# 39
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R40.htm
# 2407402 - Disclosure - Supplemental Balance Sheet Information (Details)
# Supplemental Balance Sheet Information (Details)
# Details
# 40
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R41.htm
# 2408403 - Disclosure - Supplemental Balance Sheet Information Remaining Performance Obligations (Details)
# Supplemental Balance Sheet Information Remaining Performance Obligations (Details)
# Details
# 41
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R42.htm
# 2410404 - Disclosure - Related Parties - Equity Joint Ventures (Details)
# Related Parties - Equity Joint Ventures (Details)
# Details
# 42
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R43.htm
# 2412405 - Disclosure - Goodwill (Details)
# Goodwill (Details)
# Details
# 43
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R44.htm
# 2415406 - Disclosure - Debt and Revolving Credit Facility -Summary of Debt and Other Obligations (Details)
# Debt and Revolving Credit Facility -Summary of Debt and Other Obligations (Details)
# Details
# 44
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R45.htm
# 2416407 - Disclosure - Debt and Revolving Credit Facility - Narrative (Details)
# Debt and Revolving Credit Facility - Narrative (Details)
# Details
# 45
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R46.htm
# 2417408 - Disclosure - Debt and Revolving Credit Facility - Interest Expense Recognized (Details)
# Debt and Revolving Credit Facility - Interest Expense Recognized (Details)
# Details
# 46
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R47.htm
# 2418409 - Disclosure - Debt and Revolving Credit Facility - Future Payments on Total Debt (Details)
# Debt and Revolving Credit Facility - Future Payments on Total Debt (Details)
# Details
# 47
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R48.htm
# 2421410 - Disclosure - Financial Instruments - Narrative (Details)
# Financial Instruments - Narrative (Details)
# Details
# 48
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R49.htm
# 2422411 - Disclosure - Financial Instruments - Financial Instruments Not Recorded at Fair value (Details)
# Financial Instruments - Financial Instruments Not Recorded at Fair value (Details)
# Details
# 49
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R50.htm
# 2425412 - Disclosure - Accumulated Other Comprehensive Income (Loss) (Details)
# Accumulated Other Comprehensive Income (Loss) (Details)
# Details
# 50
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R51.htm
# 2427413 - Disclosure - Concentrations of Credit and Operation Risk (Details)
# Concentrations of Credit and Operation Risk (Details)
# Details
# 51
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R52.htm
# 2430414 - Disclosure - Earnings Per Share (Details)
# Earnings Per Share (Details)
# Details
# 52
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R53.htm
# 2433415 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans - Common Stock Activities (Details)
# Common Stock and Stock-Based Incentive Compensation Plans - Common Stock Activities (Details)
# Details
# 53
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R54.htm
# 2434416 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans - Narrative (Details)
# Common Stock and Stock-Based Incentive Compensation Plans - Narrative (Details)
# Details
# 54
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R55.htm
# 2435417 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans - Allocation of Recognized Period Costs (Details)
# Common Stock and Stock-Based Incentive Compensation Plans - Allocation of Recognized Period Costs (Details)
# Details
# 55
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R56.htm
# 2436418 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans - Stock Option Valuation Assumptions (Details)
# Common Stock and Stock-Based Incentive Compensation Plans - Stock Option Valuation Assumptions (Details)
# Details
# 56
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R57.htm
# 2437419 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans - Weighted Average Valuation Assumptions for Stock Options (Details)
# Common Stock and Stock-Based Incentive Compensation Plans - Weighted Average Valuation Assumptions for Stock Options (Details)
# Details
# 57
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R58.htm
# 2438420 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans - Restricted Stock Units Activates and PRSUs (Details)
# Common Stock and Stock-Based Incentive Compensation Plans - Restricted Stock Units Activates and PRSUs (Details)
# Details
# 58
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R59.htm
# 2439421 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans - Weighted Average Valuation Assumptions for PRSUs (Details)
# Common Stock and Stock-Based Incentive Compensation Plans - Weighted Average Valuation Assumptions for PRSUs (Details)
# Details
# 59
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R60.htm
# 2440422 - Disclosure - Common Stock and Stock-Based Incentive Compensation Plans - Weighted Average Valuation Assumptions for ESPP (Details)
# Common Stock and Stock-Based Incentive Compensation Plans - Weighted Average Valuation Assumptions for ESPP (Details)
# Details
# 60
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R61.htm
# 2442423 - Disclosure - Retirement Benefit Plans (Details)
# Retirement Benefit Plans (Details)
# Details
# 61
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R62.htm
# 2445424 - Disclosure - Income Taxes - Schedule of Income (Loss) Before Income Tax (Details)
# Income Taxes - Schedule of Income (Loss) Before Income Tax (Details)
# Details
# 62
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R63.htm
# 2446425 - Disclosure - Income Taxes - Schedule of Provisions (Benefit) for Income Taxes (Details)
# Income Taxes - Schedule of Provisions (Benefit) for Income Taxes (Details)
# Details
# 63
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R64.htm
# 2447426 - Disclosure - Income Taxes - Schedule of Effective Income Tax Rate Reconciliation (Details)
# Income Taxes - Schedule of Effective Income Tax Rate Reconciliation (Details)
# Details
# 64
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R65.htm
# 2448427 - Disclosure - Income Taxes - Narrative (Details)
# Income Taxes - Narrative (Details)
# Details
# 65
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R66.htm
# 2449428 - Disclosure - Income Taxes - Schedule of Deferred Tax Assets and Liabilities (Details)
# Income Taxes - Schedule of Deferred Tax Assets and Liabilities (Details)
# Details
# 66
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R67.htm
# 2450429 - Disclosure - Income Taxes - Movement in Deferred Tax Valuation Allowance (Details)
# Income Taxes - Movement in Deferred Tax Valuation Allowance (Details)
# Details
# 67
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R68.htm
# 2451430 - Disclosure - Income Taxes - Schedule of Deferred Tax Assets and Liabilities, Current and Noncurrent (Details)
# Income Taxes - Schedule of Deferred Tax Assets and Liabilities, Current and Noncurrent (Details)
# Details
# 68
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R69.htm
# 2452431 - Disclosure - Income Taxes - Summary of Tax Attribute Carryforwards (Details)
# Income Taxes - Summary of Tax Attribute Carryforwards (Details)
# Details
# 69
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R70.htm
# 2453432 - Disclosure - Income Taxes - Schedule of Gross Unrecognized Tax Benefits (Details)
# Income Taxes - Schedule of Gross Unrecognized Tax Benefits (Details)
# Details
# 70
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R71.htm
# 2456433 - Disclosure - Segment Reporting - Summary of Operations by Segment (Details)
# Segment Reporting - Summary of Operations by Segment (Details)
# Details
# 71
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R72.htm
# 2457434 - Disclosure - Segment Reporting - Components of Other Operating Income (Loss) (Details)
# Segment Reporting - Components of Other Operating Income (Loss) (Details)
# Details
# 72
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R73.htm
# 2458435 - Disclosure - Segment Reporting - External Customers by Geographic Region (Details)
# Segment Reporting - External Customers by Geographic Region (Details)
# Details
# 73
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R74.htm
# 2459436 - Disclosure - Segment Reporting - Sales by Customer (Details)
# Segment Reporting - Sales by Customer (Details)
# Details
# 74
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R75.htm
# 2460437 - Disclosure - Segment Reporting - Property and Equipment, Net by Geographic Region (Details)
# Segment Reporting - Property and Equipment, Net by Geographic Region (Details)
# Details
# 75
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R76.htm
# 2463438 - Disclosure - Other Expense, Net (Details)
# Other Expense, Net (Details)
# Details
# 76
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R77.htm
# 2466439 - Disclosure - Commitments and Guarantees - Supplemental Information Related to Leases (Details)
# Commitments and Guarantees - Supplemental Information Related to Leases (Details)
# Details
# 77
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R78.htm
# 2467440 - Disclosure - Commitments and Guarantees - Operating Lease Obligations (Details)
# Commitments and Guarantees - Operating Lease Obligations (Details)
# Details
# 78
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R79.htm
# 2468441 - Disclosure - Commitments and Guarantees - Narrative (Details)
# Commitments and Guarantees - Narrative (Details)
# Details
# 79
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R80.htm
# 2469442 - Disclosure - Commitments and Guarantees - Unconditional Purchase Obligations (Details)
# Commitments and Guarantees - Unconditional Purchase Obligations (Details)
# Details
# 80
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R81.htm
# 2470443 - Disclosure - Commitments and Guarantees - Schedule of Changes in Product Warranty Liability (Details)
# Commitments and Guarantees - Schedule of Changes in Product Warranty Liability (Details)
# Details
# 81
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R82.htm
# 2472444 - Disclosure - Contingencies (Details)
# Contingencies (Details)
# Details
# 82
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R83.htm
# 2474445 - Disclosure - Pending Acquisition (Details)
# Pending Acquisition (Details)
# Details
# 83
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R84.htm
# 2477446 - Disclosure - Supplementary Financial Information (unaudited) (Details)
# Supplementary Financial Information (unaudited) (Details)
# Details
# 84
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R9999.htm
# Uncategorized Items - amd-20201226.htm
# Uncategorized Items - amd-20201226.htm
# Cover
# 85

# %%
# create the list to hold the statement urls
statements_url = []

for report_dict in master_reports:
    
    # define the statements we want to look for.
    item1 = r"Consolidated Balance Sheets"
    item2 = r"Consolidated Statements of Comprehensive Income"
    item3 = r"Consolidated Statements of Cash Flows"
    item4 = r"Consolidated Statements of Operations"
    
    # store them in a list.
    report_list = [item1, item2, item3, item4]
    
    # if the short name can be found in the report list.
    if report_dict['name_short'] in report_list:
        
        # print some info and store it in the statements url.
        print('-'*100)
        print(report_dict['name_short'])
        print(report_dict['url'])
        
        statements_url.append(report_dict['url'])
# Out:
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Operations
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R2.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Comprehensive Income
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R3.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Balance Sheets
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R4.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Cash Flows
# https://www.sec.gov/Archives/edgar/data/2488/000162828021001185/R7.htm

# %% [markdown]
# # Scraping Financial Statements

# %%
# let's assume we want all the statements in a single data set.
statements_data = []

# loop through each statement url
for statement in statements_url:

    # define a dictionary that will store the different parts of the statement.
    statement_data = {}
    statement_data['headers'] = []
    statement_data['sections'] = []
    statement_data['data'] = []
    
    # request the statement file content
    content = requests.get(statement).content
    report_soup = BeautifulSoup(content, 'html')

    # find all the rows, figure out what type of row it is, parse the elements, and store in the statement file list.
    for index, row in enumerate(report_soup.table.find_all('tr')):
        
        # first let's get all the elements.
        cols = row.find_all('td')
        
        # if it's a regular row and not a section or a table header
        if (len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0): 
            reg_row = [ele.text.strip() for ele in cols]
            statement_data['data'].append(reg_row)
            
        # if it's a regular row and a section but not a table header
        elif (len(row.find_all('th')) == 0 and len(row.find_all('strong')) != 0):
            sec_row = cols[0].text.strip()
            statement_data['sections'].append(sec_row)
            
        # finally if it's not any of those it must be a header
        elif (len(row.find_all('th')) != 0):            
            hed_row = [ele.text.strip() for ele in row.find_all('th')]
            statement_data['headers'].append(hed_row)
            
        else:            
            print('We encountered an error.')

    # append it to the master list.
    statements_data.append(statement_data)

# %% [markdown]
# # Converting to DF

# %%
def produce_df(i):
    # Grab the proper components
    income_header =  statements_data[i]['headers'][1]
    income_data = statements_data[i]['data']

    # Put the data in a DataFrame
    income_df = pd.DataFrame(income_data)


    # Define the Index column, rename it, and we need to make sure to drop the old column once we reindex.
    income_df.index = income_df[0] #first col

    income_df.index.name = 'Category'
    income_df = income_df.drop(0, axis = 1) #drop col names


    # Get rid of the '$', '(', ')', and convert the '' to NaNs.
    income_df = income_df.replace('[\$,)]','', regex=True )\
                         .replace( '[(]','-', regex=True)\
                         .replace( '', 'NaN', regex=True)


    # # convert string to float
    income_df = income_df.astype(float)

    # # Change the column headers
    income_df.columns = income_header



    # show the df
    return income_df

    # # drop the data in a CSV file if needed.
    # # income_df.to_csv('income_state.csv')

# %%
produce_df(0)
# Out:
#                                                     Dec. 26, 2020  \
# Category
# Net revenue                                               9763.00
# Cost of sales                                             5416.00
# Gross profit                                              4347.00
# Research and development                                  1983.00
# Marketing, general and administrative                      995.00
# Operating income                                          1369.00
# Interest expense                                           -47.00
# Other expense, net                                         -47.00
# Income before income taxes and equity income (l...        1275.00
# Income tax provision (benefit)                           -1210.00
# Equity income (loss) in investee                             5.00
# Net income                                                2490.00
# Basic (in usd per share)                                     2.10
# Diluted (in usd per share)                                   2.06
# Basic (in shares)                                         1184.00
# Diluted (in shares)                                       1207.00
#
#                                                     Dec. 28, 2019  \
# Category
# Net revenue                                               6731.00
# Cost of sales                                             3863.00
# Gross profit                                              2868.00
# Research and development                                  1547.00
# Marketing, general and administrative                      750.00
# Operating income                                           631.00
# Interest expense                                           -94.00
# Other expense, net                                        -165.00
# Income before income taxes and equity income (l...         372.00
# Income tax provision (benefit)                              31.00
# Equity income (loss) in investee                             0.00
# Net income                                                 341.00
# Basic (in usd per share)                                     0.31
# Diluted (in usd per share)                                   0.30
# Basic (in shares)                                         1091.00
# Diluted (in shares)                                       1120.00
#
#                                                     Dec. 29, 2018
# Category
# Net revenue                                               6475.00
# Cost of sales                                             4028.00
# Gross profit                                              2447.00
# Research and development                                  1434.00
# Marketing, general and administrative                      562.00
# Operating income                                           451.00
# Interest expense                                          -121.00
# Other expense, net                                           0.00
# Income before income taxes and equity income (l...         330.00
# Income tax provision (benefit)                              -9.00
# Equity income (loss) in investee                            -2.00
# Net income                                                 337.00
# Basic (in usd per share)                                     0.34
# Diluted (in usd per share)                                   0.32
# Basic (in shares)                                          982.00
# Diluted (in shares)                                       1064.00

# %%
produce_df(1)
# Out:
#                                                     Dec. 26, 2020  \
# Category
# Net income                                                 2490.0
# Net change in unrealized gains (losses) on cash...           17.0
# Total comprehensive income                                 2507.0
# Cumulative Effect, Period of Adoption, Adjustme...            NaN
# Total comprehensive income                                    0.0
#
#                                                     Dec. 28, 2019  \
# Category
# Net income                                                  341.0
# Net change in unrealized gains (losses) on cash...            8.0
# Total comprehensive income                                  349.0
# Cumulative Effect, Period of Adoption, Adjustme...            NaN
# Total comprehensive income                                    0.0
#
#                                                     Dec. 29, 2018
# Category
# Net income                                                  337.0
# Net change in unrealized gains (losses) on cash...          -14.0
# Total comprehensive income                                  325.0
# Cumulative Effect, Period of Adoption, Adjustme...            NaN
# Total comprehensive income                                    2.0

# %%
produce_df(3)
# Out:
#                                                     Dec. 26, 2020  \
# Category
# Net income                                                 2490.0
# Depreciation and amortization                               312.0
# Stock-based compensation                                    274.0
# Amortization of debt discount and issuance costs             14.0
# Amortization of operating lease right-of-use as...           42.0
# Loss on debt redemption, repurchase and conversion           54.0
# Loss on sale/disposal of property and equipment              33.0
# Impairment of technology licenses                             0.0
# Deferred income taxes                                     -1223.0
# Other                                                         6.0
# Accounts receivable, net                                   -219.0
# Inventories                                                -417.0
# Receivables from related parties                             10.0
# Prepaid expenses and other assets                          -231.0
# Payables to related parties                                -135.0
# Accounts payable                                           -513.0
# Accrued liabilities and other                               574.0
# Net cash provided by operating activities                  1071.0
# Purchases of property and equipment                        -294.0
# Payments to Acquire Short-term Investments                 -850.0
# Proceeds from maturity of short-term investments            192.0
# Collection of deferred proceeds on sale of rece...            0.0
# Other                                                         0.0
# Net cash used in investing activities                      -952.0
# Proceeds from short-term borrowings                         200.0
# Repayments and extinguishment of debt                       200.0
# Proceeds from Warrant Exercises                               0.0
# Proceeds from sales of common stock through emp...           85.0
# Common stock repurchases for tax withholding on...          -78.0
# Other                                                        -1.0
# Net cash provided by financing activities                     6.0
# Net increase (decrease) in cash and cash equiva...          125.0
# Cash, cash equivalents and restricted cash at b...         1470.0
# Cash, cash equivalents and restricted cash at e...         1595.0
# Interest                                                     31.0
# Income taxes, net of refund                                   8.0
# Purchases of property and equipment, accrued bu...           31.0
# Issuance of common stock to settle convertible ...          217.0
# Transfer of assets for the acquisition of prope...          111.0
# Issuance of treasury stock to partially settle ...            0.0
# Deferred proceeds on sale of receivable                       0.0
# Right-of-Use Asset Obtained in Exchange for Ope...           45.0
# Total cash, cash equivalents, and restricted cash          1595.0
#
#                                                     Dec. 28, 2019  \
# Category
# Net income                                                  341.0
# Depreciation and amortization                               222.0
# Stock-based compensation                                    197.0
# Amortization of debt discount and issuance costs             30.0
# Amortization of operating lease right-of-use as...           36.0
# Loss on debt redemption, repurchase and conversion          176.0
# Loss on sale/disposal of property and equipment              42.0
# Impairment of technology licenses                             0.0
# Deferred income taxes                                        -7.0
# Other                                                        -2.0
# Accounts receivable, net                                   -623.0
# Inventories                                                -137.0
# Receivables from related parties                             14.0
# Prepaid expenses and other assets                          -176.0
# Payables to related parties                                   7.0
# Accounts payable                                            153.0
# Accrued liabilities and other                               220.0
# Net cash provided by operating activities                   493.0
# Purchases of property and equipment                        -217.0
# Payments to Acquire Short-term Investments                 -284.0
# Proceeds from maturity of short-term investments            325.0
# Collection of deferred proceeds on sale of rece...           25.0
# Other                                                         2.0
# Net cash used in investing activities                      -149.0
# Proceeds from short-term borrowings                           0.0
# Repayments and extinguishment of debt                       473.0
# Proceeds from Warrant Exercises                             449.0
# Proceeds from sales of common stock through emp...           74.0
# Common stock repurchases for tax withholding on...           -6.0
# Other                                                        -1.0
# Net cash provided by financing activities                    43.0
# Net increase (decrease) in cash and cash equiva...          387.0
# Cash, cash equivalents and restricted cash at b...         1083.0
# Cash, cash equivalents and restricted cash at e...         1470.0
# Interest                                                     67.0
# Income taxes, net of refund                                  -4.0
# Purchases of property and equipment, accrued bu...           65.0
# Issuance of common stock to settle convertible ...          377.0
# Transfer of assets for the acquisition of prope...          115.0
# Issuance of treasury stock to partially settle ...            7.0
# Deferred proceeds on sale of receivable                       0.0
# Right-of-Use Asset Obtained in Exchange for Ope...           22.0
# Total cash, cash equivalents, and restricted cash          1083.0
#
#                                                     Dec. 29, 2018
# Category
# Net income                                                  337.0
# Depreciation and amortization                               170.0
# Stock-based compensation                                    137.0
# Amortization of debt discount and issuance costs             38.0
# Amortization of operating lease right-of-use as...            0.0
# Loss on debt redemption, repurchase and conversion           12.0
# Loss on sale/disposal of property and equipment              27.0
# Impairment of technology licenses                            45.0
# Deferred income taxes                                        -4.0
# Other                                                        -1.0
# Accounts receivable, net                                   -806.0
# Inventories                                                -151.0
# Receivables from related parties                            -28.0
# Prepaid expenses and other assets                           -70.0
# Payables to related parties                                  35.0
# Accounts payable                                            212.0
# Accrued liabilities and other                                81.0
# Net cash provided by operating activities                    34.0
# Purchases of property and equipment                        -163.0
# Payments to Acquire Short-term Investments                 -123.0
# Proceeds from maturity of short-term investments             45.0
# Collection of deferred proceeds on sale of rece...           71.0
# Other                                                         0.0
# Net cash used in investing activities                      -170.0
# Proceeds from short-term borrowings                           0.0
# Repayments and extinguishment of debt                        41.0
# Proceeds from Warrant Exercises                               0.0
# Proceeds from sales of common stock through emp...           70.0
# Common stock repurchases for tax withholding on...           -6.0
# Other                                                         5.0
# Net cash provided by financing activities                    28.0
# Net increase (decrease) in cash and cash equiva...         -108.0
# Cash, cash equivalents and restricted cash at b...         1191.0
# Cash, cash equivalents and restricted cash at e...         1083.0
# Interest                                                     79.0
# Income taxes, net of refund                                  -8.0
# Purchases of property and equipment, accrued bu...           49.0
# Issuance of common stock to settle convertible ...            0.0
# Transfer of assets for the acquisition of prope...           28.0
# Issuance of treasury stock to partially settle ...          141.0
# Deferred proceeds on sale of receivable                      25.0
# Right-of-Use Asset Obtained in Exchange for Ope...            0.0
# Total cash, cash equivalents, and restricted cash          1191.0
