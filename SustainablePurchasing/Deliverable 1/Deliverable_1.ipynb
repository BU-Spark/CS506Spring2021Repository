# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/Shareddrives/Spark! and Sustainable Purchasing/WB Mason Toner and Coffee Purchases_no pricing.xlsx')
df
# Out:
#       Requisition ID Requisitioning Date  ... Part - Supplier Part Number Category
# 0             PR8853          2020-09-08  ...                  HEWN9K27AN    Toner
# 1            PR32062          2021-01-05  ...                  HEWCH563WN    Toner
# 2            PR12682          2020-09-24  ...                  HEWL0R46AN    Toner
# 3            PR31013          2020-12-21  ...                  HEWC2P04AN    Toner
# 4            PR28465          2020-12-09  ...                  HEW3JA03AN    Toner
# ...              ...                 ...  ...                         ...      ...
# 61425       SH221840          2016-01-20  ...                   PEE501619   Coffee
# 61426       SH221840          2016-01-20  ...                    NES35010   Coffee
# 61427       SH231825          2016-03-01  ...                 DXE5310DXPK   Coffee
# 61428       SH221840          2016-01-20  ...                    MWH04648   Coffee
# 61429        PR28548          2020-12-09  ...                Unclassified   Coffee
#
# [61430 rows x 7 columns]

# %%
df.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#        Requisition ID  Requisitioning Date  ... Part - Supplier Part Number Category
# count           61430                61430  ...                       61430    61430
# unique          23858                 1153  ...                        1545        2
# top          SH312986  2019-11-07 00:00:00  ...                     GMT6520   Coffee
# freq               44                  154  ...                        2534    45202
# first             NaN  2016-01-06 00:00:00  ...                         NaN      NaN
# last              NaN  2021-02-17 00:00:00  ...                         NaN      NaN
#
# [6 rows x 7 columns]

# %%
coffee_req, toner_req = df[df.Category=='Coffee'], df[df.Category=='Toner']
coffee_req[:10], toner_req[:10]
# Out:
# (      Requisition ID Requisitioning Date  ... Part - Supplier Part Number Category
#  16228        PR11073          2020-09-17  ...                     GMT0845   Coffee
#  16229        PR40425          2021-02-09  ...                     GMT9737   Coffee
#  16230         PR1339          2020-08-06  ...                     GMT6542   Coffee
#  16231        PR22264          2020-11-10  ...                     GMT6663   Coffee
#  16232        PR22264          2020-11-10  ...                     GMT6694   Coffee
#  16233        PR16970          2020-10-15  ...                     GMT1252   Coffee
#  16234         PR9555          2020-09-10  ...                     GMT6080   Coffee
#  16235        PR37626          2021-01-28  ...                     GMT6003   Coffee
#  16236        PR10565          2020-09-15  ...                     GMT6999   Coffee
#  16237        PR17274          2020-10-16  ...                     GMT6792   Coffee
#
#  [10 rows x 7 columns],
#    Requisition ID Requisitioning Date  ... Part - Supplier Part Number Category
#  0         PR8853          2020-09-08  ...                  HEWN9K27AN    Toner
#  1        PR32062          2021-01-05  ...                  HEWCH563WN    Toner
#  2        PR12682          2020-09-24  ...                  HEWL0R46AN    Toner
#  3        PR31013          2020-12-21  ...                  HEWC2P04AN    Toner
#  4        PR28465          2020-12-09  ...                  HEW3JA03AN    Toner
#  5        PR22162          2020-11-10  ...                  HEWCN045AN    Toner
#  6        PR37770          2021-01-28  ...                  HEWCC644WN    Toner
#  7        PR25272          2020-11-23  ...                  HEWL0R46AN    Toner
#  8     PR24179-V2          2020-11-18  ...                  HEWC2P05AN    Toner
#  9        PR22042          2020-11-09  ...                 CNM2075C006    Toner
#
#  [10 rows x 7 columns])

# %%
coffee_req_cat = coffee_req['Description'].str.split(',', expand=True)
coffee_req_cat[0].unique(), coffee_req_cat[1].unique(), coffee_req_cat[2].unique()
# Out:
# (array(['Original Blend K-Cup Pods', 'French Roast K-Cup Pods',
#         'C-74465683|5882001041|Brazil Minas Naturais K-Cup Pods', ...,
#         'C-20475400|5730635348|Hot Cups', 'C-19649044|5727246212|Coffee',
#         'The Keurig Machine in the Research Office appears to be broken'],
#        dtype=object),
#  array([' 24/BX', ' 22/BX', ' Medium Roast', ' K-Cup Pods', ' 70/BX',
#         ' Sumatra', ' Dark Roast', ' 24/Box', ' Light Roast', ' Tea',
#         ' Peppermint Bark', " Dukale's Blend", ' Caramel Hideaway',
#         ' 196/CT', ' 8 Compartments', ' Assorted Flavors', ' 96/CT',
#         ' Raspberry Chocolate Truffle', ' 22/Box', ' Lemon',
#         ' Raspberry Chocolate Lava', ' For Coffee Brewer', ' Caramel',
#         ' Vanilla Hazelnut Decaf', ' 20/BX', None, ' 96/Carton', ' 2/BX',
#         ' Arabica', ' 24/ Box', ' Peach', ' Vanilla Hazelnut',
#         ' Raspberry', ' Decaf', ' Decaf Green Tea', ' 9/BX', ' Big Bang',
#         ' 4 Compartments', ' Coffee Bean', ' Paper',
#         ' 0.38 oz. Single-Serve Cups', ' Regular Ground',
#         ' 11 oz. Canister', ' 22 oz. Canister', ' Breakfast Blend',
#         ' French Roast', ' Regular House Blend', ' Pike Place', ' 160/PK',
#         ' Coffee', ' 5 1/2" Long', ' 12 oz. Reclosable Canister',
#         ' Cold Brew Coffee', ' Decaffeinated Ground Coffee',
#         ' Caramel Vanilla', ' Donut Shop', ' French Vanilla',
#         ' 11 oz. Canisters', ' 16 oz. Canisters', ' Dark Magic',
#         ' Kona Blend', ' Colombian Decaf', ' Hazelnut', ' Guatemala',
#         ' 0.3 oz. Single-Serve Cups', ' Colombian', ' Morning Blend',
#         ' Classic Bold', ' Vienna Espresso', ' 100% Colombian',
#         ' Hazelnut Decaf', ' 25/BX', ' Pumpkin Spice', ' Dulce De Leche',
#         ' 1.5 L Pump Bottle', ' 0.44 oz. Single-Serve Cups',
#         ' 18 1/4 x 6 5/8 x 9 7/8', ' Singles', ' Level 4',
#         ' Signature-Level 3', ' 2.2 oz. bags', ' Cafe Verona', ' Original',
#         ' Ground', ' Fractional Packs', ' Full City',
#         ' Breakfast Blend Decaf', ' Vienna', ' 10 to 12-Cups',
#         ' Sugar Free', ' Cinnamon Vanilla', ' Coffee Design',
#         ' House Blend', ' Fits 36 Pods', ' Classic Roast Ground',
#         ' 16 oz Canister', ' 12-Cups', ' 5 2/5 x 11 x 12 3/5',
#         " Major Dickason's Blend", ' 1.5 Gallon Urn Style', ' 2.2oz',
#         ' Salted Caramel Chocolate', ' Mini Cups',
#         ' Decaf Pike Place Roast', ' 8/10-Cup Size', ' Chocolate Espresso',
#         ' Chocolate Coconut Cake', ' Caf Mocha', ' Cinnamon Coffee',
#         ' 12-Cup Size', ' 2.2lb Bag', ' .375oz', ' Verona', ' 100 Count',
#         ' Espresso', ' Special House Blend', ' .44 oz.', ' 2 Ounces',
#         ' Privateer Dark', " Dunkin' Turbo", ' Colombia Las Hermosas',
#         ' 25 Pods/Box', ' Simply Smooth', ' Brown', ' 2.2 oz.',
#         ' 1.75 oz.', ' 1.5oz', ' 100% Colombian Regular', " Dunkin' Dark",
#         ' Vienna Coffee House', ' Pike Place Decaf', ' Veranda Blend',
#         ' Fits 72 Pods', ' Caf Domingo', ' Vernanda Blend', ' 2.5 oz.',
#         ' Fair Trade Organic House Blend', ' 7 1/2" Long', ' Whole Bean',
#         ' Italian Sweet Creme', ' Vermont Country Blend', ' 3g Packets',
#         ' 2.8g Packets', ' Naturally Decaffeinated', ' Colombian Blend',
#         ' 14 oz.', " Dunkin' Decaf", ' Black Gold', ' 15 oz. Canister',
#         ' Colombia Luminosa', ' Jamaican Me Crazy', ' Classic Roast',
#         ' 100% Colombian Decaf', ' Regular', ' 1.5 Gallon Brewer',
#         ' 12 oz. Reclosable Canisters', ' Decaf Signature-Level 3',
#         ' Country Roast', ' 25 Per Box', ' 16/Box',
#         ' Breakfast Blend-Level 2', ' Fits 26 Pods', ' Espresso Roast',
#         ' Get Up Stand Up', ' Fraction Pack',
#         ' 13 23/50 x 12 87/100 x 2 18/25', ' 12 oz', ' 12oz Bottle',
#         ' 12 Cup', ' 12 Cups', ' Hazelnut Creme', ' 2.5oz', ' Red/White',
#         ' 3-Gallon Urn Style', ' 16 oz. Bottle', ' Premium Blend',
#         ' Sweetened Original', ' Pike Place Roast', ' Pre-Measured',
#         ' Vanilla Caramel', ' French Vanilla Flavor .375 oz.',
#         ' 6 Gallon Urn Style', ' 42/CT', ' 2.2 OZ', ' 7 oz Bottle',
#         ' 100% Colombian Supremo', ' Firefly Decaf',
#         ' Donut Shop Original', ' Original Blend', ' 12 oz. Canister',
#         ' Classic Roast Decaffeinated', ' Ultimate Roast',
#         ' Swiss Hazelnut Coffee', ' 100% Colombian Coffee', ' Black Silk',
#         ' Natural Cinnamon', ' Caf Domingo Blend', ' Insulated',
#         ' Black Mesh', ' 10.2 oz. Canister', ' 10 Gallon Urn Style',
#         ' Smooth AND Rich Ground Coffee', ' Colombian Supremo',
#         '24 x 11 4/5 x 12 1/2', ' Black', ' Reserve', ' Maple Glazed',
#         ' Double Caff', ' 3/25oz', 'KCUP', ' 16oz', ' Sumatra Reserve',
#         ' 35.3 oz. Tub', ' 0.1oz Stick', ' Lantern Glow', ' Pioneer Blend',
#         ' Simmer Down Swiss Water Decaf', ' 16/BX', 'Trailblazer',
#         ' Half Caff', ' French Caramel',
#         ' and Michael Khoury will be submitting a service call on my behalf.'],
#        dtype=object),
#  array([None, ' 4 BX/CT', ' 24/BX', ' Green', ' 22/BX', ' Mild Roast',
#         ' English Breakfast', ' Lemon Ginger', ' 24/Box', ' White',
#         ' 22/Box', ' 24/Bx', ' K-Cup', ' 4 Boxes/Carton', ' 8 oz.',
#         ' 12oz', ' 180/CT', ' 50/BX', ' 30.6 oz Canister', ' Ground',
#         ' 2.5oz Packet', ' 180/CS', ' 12 oz.', ' 360/CS', ' Woodgrain',
#         ' 9 oz.', ' 29.3 oz Can', ' 15/BX', ' Medium', ' 12/CS',
#         ' 8 oz Can', ' 8/CT', ' 18 oz.', ' 18/Box', ' Medium Roast',
#         ' Light', ' Dark Roast', ' Light Roast', ' 15/Box', ' 25/BX',
#         ' Black', ' 10oz', ' 16oz', ' Dark', ' Original', ' 2 1/2 Packet',
#         ' 2 oz Packet', ' 100/CT', ' 0.38 oz. Mini Cup', ' 8oz',
#         ' Traditional Roast', ' 2.25oz.', ' 2.5oz', ' 384/CS', ' 2.75 oz.',
#         ' 0.375 oz Mini Cups', ' 1000/CT', ' 2.5 oz Frack Pack',
#         ' Whole Bean', ' 12 1/2"w x 13 1/4"d x 3 1/8"h', ' 30.5 oz. Can',
#         ' 8/Carton', ' 2.5oz Bag', ' 2.5 oz. Frack Pack', ' 500/Carton',
#         ' 100/Carton', ' .44 oz Liquid', ' French Vanilla', ' 1 lb Bag',
#         ' 100/Pack', ' 200/CS', ' 0.375 oz Cups', ' 1000/Carton',
#         ' Vacuum-Packed', ' 180/Carton', ' 16 oz.', ' 3/BX',
#         ' French Roast', ' 18/Carton', ' Pike Place Decaf', ' 48/BX',
#         ' 42/Case', ' .44 oz Cups', ' 0.39 oz.', ' 11 oz. Bag',
#         ' 31.1 oz Canister', ' 200/Carton', ' 384/CT', ' Decaf', ' 50/CT',
#         ' 42/CS', ' Single Cup', ' 42/Carton', ' 2.5 lbs', ' 1 lb. Bag',
#         ' 2 1/2 oz Packet', ' 12 3/4"w x 12 1/2" x 5"h', ' 50/Carton',
#         ' 0.375 oz Mini-Cups', ' 25.1 oz.', ' Breakfast Blend',
#         ' 22.6 oz.', ' 0.4375 oz Cup', ' 4BX/CT', ' 31oz Can',
#         ' Medium-Dark', ' 18.4 oz. Bag', ' 2 oz. Bag', ' House Blend',
#         ' 250/Pack', ' 20 oz. Bag', ' Dark Roast Ground',
#         ' Hawaiian Islands Blend', ' 34.5oz Can', ' 500/Pack',
#         ' 10 oz Can', ' 3/PK', ' 384/Carton', ' .44 oz. Cups',
#         ' Vanilla Caramel', ' 14 3/4 x 13 1/4 x 2 3/4', ' 12 oz Bag',
#         ' 8 oz Bag', ' Gourmet Supreme', ' 10 oz Brick Pack',
#         ' 1.5oz Pack', ' Coffee Haze', ' 21oz Pump Bottle', ' 500/CT',
#         ' 1000 Filters/Carton', ' Caramel Drizzle', ' Plastic',
#         ' 252/Carton', ' 2.5 oz Pack', ' Morning Caf', ' 16oz Jar',
#         ' 12 to 15 Cups', ' 5 lb.', ' 6 oz.', ' 1500mL Pump Dispenser',
#         ' 1500mL Pump Bottle', ' 1.5 oz.', ' 10 oz. Squat',
#         ' 200 Creamers/Carton', ' 250/Carton', ' 1.5 oz Pack',
#         ' 42 Per Case', ' 2.5 oz.', ' 0.3 oz.', ' 12 oz. Bag', ' 20oz',
#         ' .44oz Cup', ' Bold', ' .375 oz.', ' 24.2 oz. Canister', ' 10 oz',
#         ' 2.25 oz.', ' Satin Finish', ' 5 2/5"w x 12 3/5"d x 11"h',
#         ' 24.2 oz Canister', ' 2 oz Pack', ' 200/CT', ' 8.46-Ounce',
#         ' Mini Cups', ' 192/CT', ' 7.76 x 15.98 x 5 1/4', ' Italian Roast',
#         ' STARBUCKS PIKE PLACE DECAF', ' 18 oz. Bag', ' 5/Box',
#         ' Light Roast Ground', ' Medium Roast Ground', ' 0.375 oz.',
#         ' Colombia', ' Stick Packets', ' Medium Dark Roast Ground',
#         ' 1.62 oz Squeeze Bottle', ' 25.4 oz Canister', ' 12/Box',
#         ' 0.75 oz', ' 12 oz Canister', ' 4/CT'], dtype=object))

# %%
toner_req_cat = toner_req['Description'].str.split(',', expand=True)
toner_req_cat[0].unique(), toner_req_cat[1].unique(), toner_req_cat[2].unique()
# Out:
# (array(['952 Ink Cartridges - Cyan', '61XL Ink Cartridge',
#         '63 Ink Cartridges - Black', ..., 'C-29404873|5772035762|130A',
#         'C-22196188|5738506362|X264H11G High-Yield Toner',
#         'C-19635261|5727182732|HP 78A'], dtype=object),
#  array([' Magenta', ' Black (CH563WN)', ' Tri-color', ' Black (C2P04AN)',
#         ' Black (3JA03AN)', ' Black (CN045AN)', ' Tri-color (CC644WN)',
#         ' Black (C2P05AN)', ' Black', ' Black (F6U19AN)', ' Paper',
#         ' Black (T6M14AN)', ' Black (3YM56AN)', ' Black (N9K04AN)',
#         ' Black (F6U64AN)', ' Tri-color (N9J89AN)', ' Black (N9J90AN)',
#         ' 2 Cartridges (3YN96AN)', ' Black (F6U62AN)',
#         ' Tri-color (F6U63AN)', ' Tri-color (N9K03AN)', ' Black (CH561WN)',
#         ' Black (F6U15AN)', ' 2 Cartridges (3JB40AN)',
#         ' Tri-color (CH562WN)',
#         ' (C9370A) Photo Black Original Ink Cartridge', ' Black (3YL65AN)',
#         None, ' Magenta (CN055AN)', ' Black (CN049AN)', ' Cyan (CN054AN)',
#         ' (C9449A) Photo Black Original Ink Cartridge', ' Black (CN053AN)',
#         ' Yellow (CN056AN)', ' (C9374A) Gray Original Ink Cartridge',
#         ' (C9372A) Magenta Original Ink Cartridge',
#         ' (C9373A) Yellow Original Ink Cartridge',
#         ' (C9403A) Matte Black Original Ink Cartridge', ' Black (C8767WN)',
#         ' Cyan (L0S61AN)', ' Yellow (L0S67AN)', ' Magenta (L0S64AN)',
#         ' Tri-color (F6U61AN)', ' Black (N9K02AN)', ' Tri-color (N9K01AN)',
#         ' Magenta (CN047AN)', ' Cyan (CN046AN)', ' Yellow (CN048AN)',
#         ' 2 Cartridges (3YP22AN)', ' Tri-color (C2P06AN)',
#         ' Tri-color (CC656AN)', ' Black (CB336WN)', ' Black (CC641WN)',
#         ' Black (CC640WN)', ' Tri-color (C2P07AN)', ' Black (C4906AN)',
#         ' Cyan', ' Black (CC654AN)', ' 2 Cartridges (L0S28AN)',
#         ' Black (L0R39AN)', ' 2 Cartridges (3YP21AN)', ' Black (CN057AN)',
#         ' (C4912A) Magenta Original Ink Cartridge',
#         ' (N9H64FN) 2-pack Black/Tri-Color Original Ink Cartridges',
#         ' (CN069FN) 2-pack Black/Tri-color Original Ink Cartridges',
#         ' (CR314FN) 3-pack Cyan/Magenta/Yellow Original Ink Cartridges',
#         ' (C8766WN) Tri-color Original Ink Cartridge',
#         ' (CN045AN) High Yield Black Original Ink Cartridge',
#         ' (F6U62AN) Black Original Ink Cartridge',
#         ' (C8765WN) Black Original Ink Cartridge',
#         ' (C2P07AN) High Yield Tri-color Original Ink Cartridge',
#         ' (CB324WN) High Yield Magenta Original Ink Cartridge', ' 8oz',
#         ' (CD973AN) High Yield Magenta Original Ink Cartridge',
#         ' (C2P05AN) High Yield Black Original Ink Cartridge',
#         ' (CN060AN) Yellow Original Ink Cartridge',
#         ' (CN059AN) Magenta Original Ink Cartridge',
#         ' (CB322WN) High Yield Photo Black Original Ink Cartridge',
#         ' (CD974AN) High Yield Yellow Original Ink Cartridge',
#         ' (CD972AN) High Yield Cyan Original Ink Cartridge',
#         ' (CH561WN) Black Original Ink Cartridge', ' Assorted Inks',
#         ' (CN065FN) 3-pack Cyan/Magenta/Yellow Original Ink Cartridges',
#         ' (C8721WN) Black Original Ink Cartridge',
#         ' (C8773WN) Yellow Original Ink Cartridge',
#         ' (C8772WN) Magenta Original Ink Cartridge',
#         ' (C8771WN) Cyan Original Ink Cartridge', ' 1',
#         ' (CC644WN) High Yield Tri-color Original Ink Cartridge',
#         ' L0S67AN High Yield Yellow Original Ink Cartridge', ' 2',
#         ' (CN684WN) High Yield Black Original Ink Cartridge',
#         ' L0S61AN High Yield Cyan Original Ink Cartridge',
#         ' (CN049AN) Black Original Ink Cartridge',
#         ' (CN052AN) Yellow Original Ink Cartridge',
#         ' (CN050AN) Cyan Original Ink Cartridge',
#         ' (CC640WN) Black Original Ink Cartridge',
#         ' (CN051AN) Magenta Original Ink Cartridge',
#         ' (CN047AN) High Yield Magenta Original Ink Cartridge', ' White',
#         ' (CN048AN) High Yield Yellow Original Ink Cartridge',
#         ' (CN046AN) High Yield Cyan Original Ink Cartridge',
#         ' (CB325WN) High Yield Yellow Original Ink Cartridge',
#         ' 3 3/5 x 6 1/2"', ' 6oz',
#         ' (CC641WN) High Yield Black Original Ink Cartridge',
#         ' (C9371A) Cyan Original Ink Cartridge', ' 20lb',
#         ' (CB327FN) Black / 95',
#         ' (F6U61AN) Tri-Color Original Ink Cartridge',
#         ' (C4913A) Yellow Original Ink Cartridge',
#         ' (51645A) Black Original Ink Cartridge',
#         ' (C4906AN) High Yield Black Original Ink Cartridge',
#         ' (C2P04AN) Black Original Ink Cartridge',
#         ' (CB323WN) High Yield Cyan Original Ink Cartridge',
#         ' (L0R46AN) 2-pack Black/Tri-Color Original Ink Cartridges',
#         ' (C6578DN) Tri-Color Original Ink Cartridge',
#         ' (CB320WN) Yellow Original Ink Cartridge',
#         ' (CB318WN) Cyan Original Ink Cartridge',
#         ' (CN054AN) High Yield Cyan Original Ink Cartridge',
#         ' (CN053AN) High Yield Black Original Ink Cartridge',
#         ' (C2P23AN) High Yield Black Original Ink Cartridge',
#         ' (CN055AN) High Yield Magenta Original Ink Cartridge',
#         ' (CN056AN) High Yield Yellow Original Ink Cartridge',
#         ' (CZ074FN) 2-pack Tri-color Original Ink Cartridges',
#         ' Fits 12-16oz Paper Hot Cups',
#         ' (L0S28AN) 2-pack Black Original Ink Cartridge',
#         ' (CZ071FN) 2-pack Black Original Ink Cartridges',
#         ' (C2P06AN) Tri-color Original Ink Cartridge',
#         ' (CC653AN) Black Original Ink Cartridge',
#         ' (C9361WN) Tri-color Original Ink Cartridge',
#         ' (C9364WN) Black Original Ink Cartridge', ' (C9353FN) Black / 97',
#         ' (CN058AN) Cyan Original Ink Cartridge',
#         ' (C8731WN) High Yield Magenta Original Ink Cartridge',
#         ' (CH563WN) High Yield Black Original Ink Cartridge',
#         ' (CH564WN) High Yield Tri-color Original Ink Cartridge',
#         ' (CZ131A) Magenta Original Ink Cartridge',
#         ' (CZ133A) Black Original Ink Cartridge',
#         ' (CZ132A) Yellow Original Ink Cartridge',
#         ' (C9396AN) High Yield Black Original Ink Cartridge',
#         ' (CZ130A) Cyan Original Ink Cartridge', ' Pink Grapefruit',
#         ' (C8767WN) Black Original Ink Cartridge',
#         ' (CH568A) Yellow Original Ink Cartridge',
#         ' (3YP00AN) 3-Pack Cyan/Magenta/Yellow Original Ink Cartridge',
#         ' (CH566A) Cyan Original Ink Cartridge',
#         ' (CC643WN) Tri-color Original Ink Cartridge',
#         ' (CH565A) Black Original Ink Cartridge',
#         ' (3JA03AN) High Yield Black Original Ink Cartridge',
#         ' (CH567A) Magenta Original Ink Cartridge',
#         ' (F6U64AN) High Yield Black Original Ink Cartridge', ' 12/14 oz',
#         ' (CD975AN) High Yield Black Original Ink Cartridge',
#         ' (CB337WN) Tri-color Original Ink Cartridge',
#         '(CB335WN) Black Original Ink Cartridge',
#         ' (C4902AN) Black Original Ink Cartridge',
#         ' (CH562WN) Tri-color Original Ink Cartridge', ' 12oz',
#         ' (C9509FN) Black / 22', ' (CN057AN) Black Original Ink Cartridge',
#         ' (C6656AN) Black Original Ink Cartridge',
#         ' (CN628AM) High Yield Yellow Original Ink Cartridge',
#         ' (CN626AM) High Yield Cyan Original Ink Cartridge',
#         ' (CN627AM) High Yield Magenta Original Ink Cartridge',
#         ' (C4911A) Cyan Original Ink Cartridge',
#         ' (CN625AM) High Yield Black Original Ink Cartridge',
#         ' (CB336WN) High Yield Black Original Ink Cartridge',
#         ' (C9454A) Yellow Original Ink Cartridge',
#         ' (C9453A) Magenta Original Ink Cartridge',
#         ' (C9452A) Cyan Original Ink Cartridge',
#         ' (C9451A) Light Gray Original Ink Cartridge',
#         ' (C9448A) Matte Black Original Ink Cartridge',
#         ' (CC635A) Black Original Ink Cartridge',
#         ' (C4871A) Black Original Ink Cartridge',
#         ' (C4904AN) Magenta Original Ink Cartridge',
#         ' (C4903AN) Cyan Original Ink Cartridge',
#         ' (C4905AN) Yellow Original Ink Cartridge',
#         ' (CR259FN) 2-pack Black/Tri-Color Original Ink Cartridges',
#         ' 400 Pg-Yld', ' (C8727AN) Black Original Ink Cartridge', ' 16oz',
#         ' (C2P51FN) 2-pack Black Original Ink Cartridges',
#         ' (CC659FN) Black / 75',
#         ' (C9363WN) Tri-color Original Ink Cartridge',
#         ' (C9387AN) Magenta Original Ink Cartridge',
#         ' (CB338WN) High Yield Tri-color Original Ink Cartridge',
#         ' (C9385AN) Black Original Ink Cartridge',
#         ' (C9388AN) Yellow Original Ink Cartridge',
#         ' (C9386AN) Cyan Original Ink Cartridge',
#         ' (CZ073FN) 2-pack Black Original Ink Cartridges',
#         ' 3-pack Cyan/Magenta/Yellow Original Ink Cartridges',
#         ' (C8730WN) High Yield Cyan Original Ink Cartridge',
#         ' (C2P26AN) High Yield Yellow Original Ink Cartridge',
#         ' (C2P25AN) High Yield Magenta Original Ink Cartridge',
#         ' (C2P24AN) High Yield Cyan Original Ink Cartridge', ' 28 x 22',
#         ' (CB319WN) Magenta Original Ink Cartridge',
#         ' (CB317WN) Photo Black Original Ink Cartridge',
#         ' (CB316WN) Black Original Ink Cartridge',
#         ' (CN633A) Photo Black Original Ink Cartridge',
#         ' (C2P22AN) Yellow Original Ink Cartridge',
#         ' (C2P19AN) Black Original Ink Cartridge',
#         ' (C2P21AN) Magenta Original Ink Cartridge',
#         ' (C2P20AN) Cyan Original Ink Cartridge',
#         ' (C6657AN) Tri-color Original Ink Cartridge',
#         ' (C8728AN) Tri-color Original Ink Cartridge',
#         ' (CH634AN) Cyan Original Ink Cartridge',
#         ' (CH636AN) Yellow Original Ink Cartridge',
#         ' (CD971AN) Black Original Ink Cartridge',
#         ' (C6578AN) High Yield Tri-Color Original Ink Cartridge',
#         ' (CH635AN) Magenta Original Ink Cartridge',
#         ' (C9393AN) High Yield Yellow Original Ink Cartridge',
#         ' Fits 8oz Hot Drink Cups',
#         ' (F6U63AN) High Yield Tri-Color Original Ink Cartridge',
#         ' (C8774WN) Light Cyan Original Ink Cartridge',
#         ' (C8775WN) Light Magenta Original Ink Cartridge',
#         ' (C6614D) Large Black Original Ink Cartridge',
#         ' (C9351AN) Black Original Ink Cartridge',
#         ' (CN621AM) Black Original Ink Cartridge',
#         ' (C9352AN) Tri-color Original Ink Cartridge',
#         ' (C6625A) Tri-color Original Ink Cartridge',
#         ' (C6615DN) Black Original Ink Cartridge',
#         ' (C9353FN) Black / HP 97',
#         ' (CZ075FN) 2-pack Black Original Ink Cartridges',
#         ' (CC656AN) Tri-color Original Ink Cartridge', ' Crisp Clean',
#         ' (N9H63FN) 2-pack Black/Tri-Color Original Ink Cartridges',
#         ' (C4844A) Black Original Ink Cartridge',
#         ' (CC654AN) High Yield Black Original Ink Cartridge',
#         ' (B6Y21A) Photo Black Original Ink Cartridge',
#         ' (B6Y22A) Light Gray Original Ink Cartridge', ' High-Yield',
#         ' 13 1/2 x 20', ' Black (CN684WN)', ' Magenta (T6L90AN)',
#         ' Tri-color (CH564WN)', ' (L0S27AN) Black Original Ink Cartridge',
#         ' Drink Jar', ' Fits 12-16oz (Large) Paper Hot Cups',
#         ' (C9455A) Light Magenta Original Ink Cartridge', ' 12 AND 16oz',
#         ' (CN624AM) Yellow Original Ink Cartridge',
#         ' (CN623AM) Magenta Original Ink Cartridge',
#         ' (CN622AM) Cyan Original Ink Cartridge',
#         ' (C1823D) Tri-color Original Ink Cartridge',
#         ' (N9J90AN) Black Original Ink Cartridge', ' 2/Pk', ' 2 oz.',
#         ' (C9390A) Light Cyan Original Ink Cartridge',
#         ' (B6Y17A) Magenta Original Ink Cartridge',
#         ' (B6Y19A) Light Magenta Original Ink Cartridge',
#         ' (CE037A) Matte Black Original Ink Cartridge',
#         ' (C9391AN) High Yield Cyan Original Ink Cartridge',
#         ' (B6Y20A) Light Cyan Original Ink Cartridge',
#         ' (B6Y18A) Yellow Original Ink Cartridge',
#         ' (C9392AN) High Yield Magenta Original Ink Cartridge',
#         ' (B6Y16A) Chromatic Red Original Ink Cartridge',
#         ' (C8732WN) High Yield Yellow Original Ink Cartridge',
#         ' (C4908AN) High Yield Magenta Original Ink Cartridge', ' 10oz',
#         ' Black High Yield', ' Replacement for HP 508A (CF360A)',
#         ' Yellow', ' Replacement for Brother TN450',
#         ' (CF362A) Yellow Original LaserJet Toner Cartridge',
#         ' Replacement for HP 64AM (CC364AM)', ' 6000 Page-Yield',
#         ' (CE410X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' Magenta High Yield', ' Yellow High Yield', ' Cyan High Yield',
#         ' 14400 Page-Yield', ' Replacement for HP 26X (CF226X)',
#         ' Replacement for Dell B2360 (3319803)', ' 43000 Page-Yield',
#         ' (CF353A) Magenta Original LaserJet Toner Cartridge',
#         ' Replacement for HP 508X (CF363X)',
#         ' Replacement for HP 87A (CF287A)', ' Super High-Yield Toner',
#         ' 3000 Page-Yield', ' (CE254A) Toner Collection Unit',
#         ' Standard-Yield', ' CF-280X', ' 20000 Page-Yield',
#         ' (CB542A) Yellow Original LaserJet Toner Cartridge',
#         ' (CE410A) Black Original LaserJet Toner Cartridge',
#         ' (CE278A) Black Original LaserJet Toner Cartridge',
#         ' (CF382A) Yellow Original LaserJet Toner Cartridge',
#         ' (CF383A) Magenta Original LaserJet Toner Cartridge',
#         ' (CE251A) Cyan Original LaserJet Toner Cartridge',
#         ' (Q2612A) Black Original LaserJet Toner Cartridge',
#         ' (CB541A) Cyan Original LaserJet Toner Cartridge',
#         ' (CE250X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CF381A) Cyan Original LaserJet Toner Cartridge',
#         ' (CF360A) Black Original LaserJet Toner Cartridge',
#         ' (CF380A) Black Original LaserJet Toner Cartridge',
#         ' (CE400A) Black Original LaserJet Toner Cartridge',
#         ' (CF461X) Cyan Original LaserJet Toner Cartridge',
#         ' (CE260A) Black Original LaserJet Toner Cartridge',
#         ' 4000 Page-Yield',
#         ' (CE390A) Black Original LaserJet Toner Cartridge', ' 2/BX',
#         ' 17200 Page-Yield',
#         ' (CF370A-M) 3-pk Cyan/Magenta/Yellow Original LaserJet Toner Cartridges',
#         ' (CE505A) Black Original LaserJet Toner Cartridge',
#         ' (CC364A) Black Original LaserJet Toner Cartridge',
#         ' (CB540A) Black Original LaserJet Toner Cartridge',
#         ' (CE253A) Magenta Original LaserJet Toner Cartridge',
#         ' (CB543A) Magenta Original LaserJet Toner Cartridge',
#         ' (CE252A) Yellow Original LaserJet Toner Cartridge',
#         ' (CF400X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CF360X) High Yield Black Original LaserJet Toner Cartridge',
#         ' 24000 Page-Yield',
#         ' (CF460X) Black Original LaserJet Toner Cartridge',
#         ' (CF440A-M) 3-pk Cyan/Magenta/Yellow Original LaserJet Toner Cartridges',
#         ' (CF500A) Black Original LaserJet Toner Cartridge',
#         ' (Q5952A) Yellow Original LaserJet Toner Cartridge', ' 3',
#         ' (CC364X) High Yield Black Original LaserJet Toner Cartridge',
#         ' 9', ' (Q6470A) Black Original LaserJet Toner Cartridge',
#         ' (CC531A) Cyan Original LaserJet Toner Cartridge', ' 18',
#         ' (CC532A) Yellow Original LaserJet Toner Cartridge',
#         ' (CE412A) Yellow Original LaserJet Toner Cartridge',
#         ' (CE413A) Magenta Original LaserJet Toner Cartridge',
#         ' (CC533A) Magenta Original LaserJet Toner Cartridge', ' 6',
#         ' (CE505D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' (CE411A) Cyan Original LaserJet Toner Cartridge',
#         ' (CF280A) Black Original LaserJet Toner Cartridge',
#         ' (CF280X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CC530A) Black Original LaserJet Toner Cartridge',
#         ' (CF410X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' (CF501A) Cyan Original LaserJet Toner Cartridge',
#         ' (CF502A) Yellow Original LaserJet Toner Cartridge',
#         ' (CF503A) Magenta Original LaserJet Toner Cartridge',
#         ' (CF403A) Magenta Original LaserJet Toner Cartridge',
#         ' (CF213A) Magenta Original LaserJet Toner Cartridge',
#         ' (CF340A) 3-pack Cyan/Magenta/Yellow Original LaserJet Toner Cartridges',
#         ' (CF363A) Magenta Original LaserJet Toner Cartridge',
#         ' (CF401A) Cyan Original LaserJet Toner Cartridge',
#         ' (CC530A-D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' (CF211A) Cyan Original LaserJet Toner Cartridge',
#         ' (CE255X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (Q7553A) Black Original LaserJet Toner Cartridge',
#         ' (CE278D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' (CB436D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' (CF402A) Yellow Original LaserJet Toner Cartridge',
#         ' (CF212A) Yellow Original LaserJet Toner Cartridge',
#         ' (CF331A) Cyan Original LaserJet Toner Cartridge',
#         ' (CF380X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CF283A) Black Original LaserJet Toner Cartridge',
#         ' (CF210A) Black Original LaserJet Toner Cartridge',
#         ' (CE390X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CF320A) Black Original LaserJet Toner Cartridge',
#         ' (CF510A) Black Original LaserJet Toner Cartridge',
#         ' (CE410X) High Yield Black Original LaserJet Toner Cartridge',
#         ' Cyan/Magenta/Yellow',
#         ' (CF226X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' (CF362X) High Yield Yellow Original LaserJet Toner Cartridge',
#         ' (CE285D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' (CF400A) Black Original LaserJet Toner Cartridge',
#         ' (CF363X) High Yield Magenta Original LaserJet Toner Cartridge',
#         ' 2500 Page-Yield',
#         ' (CF351A) Cyan Original LaserJet Toner Cartridge',
#         ' (CE270A) Black Original LaserJet Toner Cartridge',
#         ' (Q5949A) Black Original LaserJet Toner Cartridge',
#         ' (CE255A) Black Original LaserJet Toner Cartridge',
#         ' (CE261A) Cyan Original LaserJet Toner Cartridge',
#         ' (CF361X) High Yield Cyan Original LaserJet Toner Cartridge',
#         ' (CB400A) Black Original LaserJet Toner Cartridge',
#         ' (Q5942X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' (CE262A) Yellow Original LaserJet Toner Cartridge',
#         ' (CF332A) Yellow Original LaserJet Toner Cartridge',
#         ' (CF333A) Magenta Original LaserJet Toner Cartridge',
#         ' 10000 Page-Yield',
#         ' (C8543X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CE263A) Magenta Original LaserJet Toner Cartridge',
#         ' (Q5942X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CE260X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CE400X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (Q5950A) Black Original LaserJet Toner Cartridge',
#         ' (CF281A) Black Original LaserJet Toner Cartridge',
#         ' (CF280X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' 9000 Page-Yield', ' Return Program', ' 1500 Page-Yield',
#         ' (CF281X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (Q7551X) High Yield Black Original LaserJet Toner Cartridge',
#         'Yellow',
#         ' (CF500X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CE505X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' (CF330X) High Yield Black Original LaserJet Toner Cartridge',
#         ' 3100 Page-Yield',
#         ' (CE312A) Yellow Original LaserJet Toner Cartridge',
#         ' (C7115X) High Yield Black Original LaserJet Toner Cartridge',
#         ' 1000 Page-Yield',
#         ' (CE255X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' 8000 Page-Yield', ' 4100 Page-Yield',
#         ' (Q6473A) Magenta Original LaserJet Toner Cartridge',
#         ' 23000 Page-Yield', ' 5',
#         ' (CF402X) High Yield Yellow Original LaserJet Toner Cartridge',
#         ' (CE285A) Black Original LaserJet Toner Cartridge',
#         ' (CF401X) High Yield Cyan Original LaserJet Toner Cartridge',
#         ' (CF403X) High Yield Magenta Original LaserJet Toner Cartridge',
#         ' (CE265A) Toner Collection Unit',
#         ' (CF410AQ) 4-Pack Black; Cyan; Magenta; Yellow Original LaserJet Toner Cartridges',
#         ' 7000 Page-Yield', ' 17800 Page-Yield', ' 19800 Page-Yield',
#         ' (CF350A) Black Original LaserJet Toner Cartridge',
#         ' 25000 Page-Yield',
#         ' (CF352A) Yellow Original LaserJet Toner Cartridge',
#         ' 20K Page Yield',
#         ' (CE390X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' (CE250A) Black Original LaserJet Toner Cartridge',
#         ' (Q5949X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CE320A-D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' (Q5942A) Black Original LaserJet Toner Cartridge',
#         ' (CE505X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CE271A) Cyan Original LaserJet Toner Cartridge',
#         ' (CB436A) Black Original LaserJet Toner Cartridge',
#         ' (Q5951A) Cyan Original LaserJet Toner Cartridge',
#         ' (CB401A) Cyan Original LaserJet Toner Cartridge',
#         ' (Q2610A) Black Original LaserJet Toner Cartridge',
#         ' 5000 Page-Yield',
#         ' (Q6472A) Yellow Original LaserJet Toner Cartridge',
#         ' 17200  Page-Yield', ' 3500 Page-Yield',
#         ' (CC364X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' (CE743A) Magenta Original LaserJet Toner Cartridge',
#         ' (CE742A) Yellow Original LaserJet Toner Cartridge',
#         ' (CB403A) Magenta Original LaserJet Toner Cartridge',
#         ' (CE741A) Cyan Original LaserJet Toner Cartridge',
#         ' 2000 Page-Yield',
#         ' (CE740A) Black Original LaserJet Toner Cartridge',
#         ' 1400 Page-Yield',
#         ' (C9722A) Yellow Original LaserJet Toner Cartridge',
#         ' (CF512A) Yellow Original LaserJet Toner Cartridge',
#         ' (CB435D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' (C9720A) Black Original LaserJet Toner Cartridge',
#         ' (C9721A) Cyan Original LaserJet Toner Cartridge',
#         ' (CF511A) Cyan Original LaserJet Toner Cartridge',
#         ' (CF513A) Magenta Original LaserJet Toner Cartridge',
#         ' (C9723A) Magenta Original LaserJet Toner Cartridge',
#         ' (CB402A) Yellow Original LaserJet Toner Cartridge',
#         ' 9500 Page-Yield', ' Black Original LaserJet Toner Cartridge',
#         ' (C9733A) Magenta Original LaserJet Toner Cartridge',
#         ' (C9731A) Cyan Original LaserJet Toner Cartridge',
#         ' (Q6000A) Black Original LaserJet Toner Cartridge',
#         ' (Q6002A) Yellow Original LaserJet Toner Cartridge',
#         ' (Q6001A) Cyan Original LaserJet Toner Cartridge',
#         ' 18000 Page-Yield',
#         ' (C9730A) Black Original LaserJet Toner Cartridge',
#         ' (C9732A) Yellow Original LaserJet Toner Cartridge',
#         ' (C7115A) Black Original LaserJet Toner Cartridge',
#         ' (Q6003A) Magenta Original LaserJet Toner Cartridge',
#         ' (CF501X) High Yield Cyan Original LaserJet Toner Cartridge',
#         ' (CF503X) High Yield Magenta Original LaserJet Toner Cartridge',
#         ' (Q2613X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (Q6471A) Cyan Original LaserJet Toner Cartridge',
#         ' (CF502X) High Yield Yellow Original LaserJet Toner Cartridge',
#         ' (CE272A) Yellow Original LaserJet Toner Cartridge',
#         ' (CE273A) Magenta Original LaserJet Toner Cartridge',
#         ' (CF210X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (Q2612D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' 11000 Page-Yield', ' 9000 Yield', '1500 Page-Yield',
#         ' 31000 Page-Yield',
#         ' (Q6511X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CE310A) Black Original LaserJet Toner Cartridge',
#         ' (CE313A) Magenta Original LaserJet Toner Cartridge',
#         ' (CB435A) Black Original LaserJet Toner Cartridge', ' 5400 Yield',
#         ' (Q7516A) Black Original LaserJet Toner Cartridge',
#         ' 5900 Page-Yield',
#         ' (CE402A) Yellow Original LaserJet Toner Cartridge', ' 41',
#         ' (CE401A) Cyan Original LaserJet Toner Cartridge',
#         ' (CE403A) Magenta Original LaserJet Toner Cartridge', ' 4', ' 23',
#         ' 25', ' (CF462X) Yellow Original LaserJet Toner Cartridge',
#         ' (CF463X) Magenta Original LaserJet Toner Cartridge',
#         ' (CF400X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' (CF283X) High Yield Black Original LaserJet Toner Cartridge',
#         ' 11', ' (CE320A) Black Original LaserJet Toner Cartridge',
#         ' (Q6461A) Cyan Original LaserJet Toner Cartridge', ' C736 Series',
#         ' (Q5953A) Magenta Original LaserJet Toner Cartridge',
#         ' (Q6460A) Black Original LaserJet Toner Cartridge',
#         ' 21000 Yield',
#         ' (Q1339A) Black Original LaserJet Toner Cartridge', ' 10',
#         ' 6000 Yield', ' 9000 Page Yield',
#         ' (Q6463A) Magenta Original LaserJet Toner Cartridge',
#         ' (CF214A) Black Original LaserJet Toner Cartridge',
#         ' (Q6462A) Yellow Original LaserJet Toner Cartridge',
#         ' 1800 Yield', ' 2-pack Black Original LaserJet Toner Cartridges',
#         ' (CE311A) Cyan Original LaserJet Toner Cartridge',
#         ' (Q2624A) Black Original LaserJet Toner Cartridge',
#         ' 1080 Page-Yield', ' 2070 Yield',
#         ' (C4127X) High Yield Black Original LaserJet Toner Cartridge',
#         ' 2250 Page-Yield',
#         ' (Q7581A) Cyan Original LaserJet Toner Cartridge',
#         ' (Q7583A) Magenta Original LaserJet Toner Cartridge',
#         ' Return Progam',
#         ' (C4182X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (C8061X) High Yield Black Original LaserJet Toner Cartridge',
#         ' 5500 Page-Yield', ' 2600 Page-Yield', ' 2200 Page-Yield', ' 35',
#         ' 300 Page-Yld', ' 331-0778 (810WH) High-Yield Toner', ' 15',
#         ' 17', ' 9900 Yield',
#         ' (C4096A) Black Original LaserJet Toner Cartridge',
#         ' (Q2612L) Economy Black Original LaserJet Toner Cartridge',
#         ' 6300 Yield', ' 1200 Page-Yield',
#         ' (CE310A-D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' (CF341A) 3-pack Cyan/Magenta/Yellow Original LaserJet Toner Cartridges',
#         ' 30000 Page-Yield', ' 3500 Yield', ' 15000 Page-Yield',
#         ' 8500 Page-Yield', ' 2520 Yield',
#         ' (CB540A-D) 2-pack Black Original LaserJet Toner Cartridges',
#         ' (CE259A) 3-pack Cyan/Magenta/Yellow Original LaserJet Toner Cartridges',
#         ' Reman', ' (C4092A) Black Original LaserJet Toner Cartridge',
#         ' 331-0719 (MY5TJ) High-Yield Toner',
#         ' (CE321A) Cyan Original LaserJet Toner Cartridge',
#         ' (Q7582A) Yellow Original LaserJet Toner Cartridge',
#         ' (Q7553X) High Yield Black Original LaserJet Toner Cartridge',
#         ' (CF371A-M) 3-pk Cyan/Magenta/Yellow Original LaserJet Toner Cartridges',
#         ' 5850 Yield',
#         ' (CE322A) Yellow Original LaserJet Toner Cartridge',
#         ' (CE323A) Magenta Original LaserJet Toner Cartridge', ' 2 Pack',
#         ' 3-pack Cyan/Magenta/Yellow Original LaserJet Toner Cartridges',
#         ' 8', ' 480-0068 (4800068) Toner', ' 22500 Page-Yield',
#         ' (Q1338A) Black Original LaserJet Toner Cartridge',
#         ' 2340 Page-Yield', ' 1350 Yield',
#         ' (Q7551X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' 4500 Page-Yield', ' 30', ' 1400 Page-Yld', 'F/2330-6K',
#         ' (CF033A) Magenta Original LaserJet Toner Cartridge',
#         ' (CF032A) Yellow Original LaserJet Toner Cartridge',
#         ' 2100 Page-Yield',
#         ' (Q6511A) Black Original LaserJet Toner Cartridge',
#         ' 2700 Page-Yield', ' 331-0717 (8WNV5) High-Yield Toner',
#         ' 331-0716 (769T5) High-Yield Toner',
#         ' 331-0718 (NPDXG) High-Yield Toner', ' 20000 Yield',
#         ' 21600 Yield', ' 27K Page Yield',
#         ' 331-0780 (5GDTC) High-Yield Toner',
#         ' 331-0779 (5M1VR) High-Yield Toner',
#         ' 331-0777 (79K5P) High-Yield Toner', ' 11250 Yield',
#         ' (CE505X) High-Yield Black Original LaserJet Toner Cartridge',
#         ' (Q5949X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' (Q7570A) Black Original LaserJet Toner Cartridge', ' 7500 Yield',
#         ' 13', ' 8000 Yield',
#         ' (C3903A) Black Original LaserJet Toner Cartridge',
#         ' (Q7553X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' 2500 Yield',
#         ' (CF287X-D) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' Replacement for Canon 137 (9435B001AA)',
#         ' Replacement for HP 55AM (CE255AM)', ' 4300 Page-Yield',
#         ' 1980 Yield', ' (CF300A) Black Original LaserJet Toner Cartridge',
#         ' (CF320X) High Yield Black Original LaserJet Toner Cartridge',
#         ' Laser', ' 2400 Page-Yield', ' 6100 Page-Yield',
#         ' (CF410XD) 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' (Q2613A) Black Original LaserJet Toner Cartridge',
#         ' 4k Page Yield', '1400 Page-Yield', ' 9450 Yield',
#         ' 43200 Page-Yield', ' 45000 Page-Yield',
#         ' (Q2672A) Yellow Original LaserJet Toner Cartridge',
#         ' (Q2670A) Black Original LaserJet Toner Cartridge',
#         ' 2-pack High Yield Black Original LaserJet Toner Cartridges',
#         ' 2250 Yield', ' 20', ' 11700 Yield', ' 13000 Yield',
#         ' 18000 Yield', ' 4400 Page-Yield',
#         ' (CE278A) Black Original LaserJet Toner Cartridges'], dtype=object),
#  array([' Yellow', None, ' 2 Cartridges (L0R46AN)', ' Cyan', ' 12oz',
#         ' 10oz', ' Magenta', ' 2 Cartridges (N9H63FN)',
#         ' Yellow Original Ink Cartridges', ' White',
#         ' Yellow Original Ink Cartridge', ' .5mm',
#         ' 12 oz (Fits Large Lids)', '600 Page-Yield', '000 Page-Yield',
#         ' 100/Pack', ' 9/10" Thick', ' 8-1/2 x 11',
#         ' Tri-Color 2-pack Original Ink Cartridges', ' 12 o zPump  Bottle',
#         ' Clear', ' 16oz', ' Tri-Color', ' Green/Pink/Red/Yellow',
#         ' 300/Carton', ' 1000/Carton', ' Pink', ' 10oz Squat',
#         ' Black/Cyan/Magenta/Yellow', ' 16.5oz', ' Black', ' 1200/Carton',
#         ' 8oz', ' 6', ' 2', ' 10', ' Yellow (3 pack)', ' 9',
#         ' 4500 Page-Yield', ' Toner', ' MICR High-Yield Toner Secure',
#         '  Black', '300 Page-Yield', '100 Page-Yield', ' 2600 Page-Yield',
#         '500 Page-Yield', ' 3/PK', ' 20K Page Yield', ' 6000 Page-Yield',
#         '400 pg. yield', '000 pg. yield', '100 pg. yield',
#         ' 25K Page Yield', '500 Page Yield', ' 5000 Page-Yield',
#         ' 7000 Page-Yield', ' 2000 Page-Yield', ' 1000 Yield',
#         ' 113R00726 Laser Toner', ' 3000 Page-Yield', '11000 Yield',
#         ' 2/PK', ' 8000 Page-Yield', ' 2200 Page-Yield',
#         ' 2800 Page-Yield', ' 113R00724 Laser Toner', ' 2500 Page-Yield',
#         ' F/3110C-8K', ' 1400 Page Yield', ' 1400 Page-Yield',
#         ' 6500 Yield', ' 2300 Page-Yield', ' 310-8095 Laser Toner',
#         ' Standard Yield', ' Yields approx. 3', ' 310-8093 Laser Toner'],
#        dtype=object))

# %%
## Now processing the data from coffee_req
coffee_req_num_by_date = coffee_req.groupby(['Requisitioning Date','Category']).size().reset_index(name='req_times')[['Requisitioning Date','req_times']]
coffee_req_num_by_date.columns = ['date','req_times']
# coffee_req_num_by_date['date'] = pd.to_datetime(coffee_req_num_by_date['date'])
cqd = coffee_req_num_by_date.set_index('date')
# print(cqd.index)
cqm = cqd.resample('MS').sum().to_period('M')
cqy = cqd.resample('YS').sum().to_period('Y')
cqy.plot(kind='bar')
cqy.plot()
cqm.plot()
cqy
# Out:
#       req_times
# date
# 2016       9820
# 2017      11494
# 2018      11967
# 2019      10644
# 2020        895
# 2021        382

# %%
## Now processing the data from toner_req
toner_req_num_by_date = toner_req.groupby(['Requisitioning Date','Category']).size().reset_index(name='req_times')[['Requisitioning Date','req_times']]
toner_req_num_by_date.columns = ['date','req_times']
# toner_req_num_by_date['date'] = pd.to_datetime(coffee_req_num_by_date['date'])
tqd = toner_req_num_by_date.set_index('date')
# print(cqd.index)
tqm = tqd.resample('MS').sum().to_period('M')
tqy = tqd.resample('YS').sum().to_period('Y')
tqy.plot(kind='bar')
tqy.plot()
tqm.plot()
tqy
# Out:
#       req_times
# date
# 2016       4255
# 2017       4183
# 2018       4051
# 2019       3208
# 2020        387
# 2021        144

# %%
# remove unnecessary column
coffee = coffee_req[~coffee_req['Part - Supplier Part Number'].str.contains("Unclassified")]
toner = toner_req[~toner_req['Part - Supplier Part Number'].str.contains("Unclassified")]
coffee.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   after removing the cwd from sys.path.
#        Requisition ID  Requisitioning Date  ... Part - Supplier Part Number Category
# count           45193                45193  ...                       45193    45193
# unique          16285                 1129  ...                         573        1
# top          SH312986  2017-03-13 00:00:00  ...                     GMT6520   Coffee
# freq               44                  131  ...                        2534    45193
# first             NaN  2016-01-06 00:00:00  ...                         NaN      NaN
# last              NaN  2021-02-17 00:00:00  ...                         NaN      NaN
#
# [6 rows x 7 columns]

# %%
toner.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#        Requisition ID  Requisitioning Date  ... Part - Supplier Part Number Category
# count           16221                16221  ...                       16221    16221
# unique           8916                 1088  ...                         971        1
# top          SH247710  2017-03-06 00:00:00  ...                   HEWCE505A    Toner
# freq               16                   50  ...                         347    16221
# first             NaN  2016-01-12 00:00:00  ...                         NaN      NaN
# last              NaN  2021-02-17 00:00:00  ...                         NaN      NaN
#
# [6 rows x 7 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

items, counts =np.unique(sorted(coffee['Part - Supplier Part Number']), return_counts=True)

temp = pd.DataFrame(data={'items': items,'counts': counts}).sort_values(by=['counts'])

items, counts = temp['items'][-20:][::-1],temp ['counts'][-20:][::-1]

plt.figure(figsize=(16,24))                        #resize the figure
labels = items                                     #define the labels as Supplier Part Number
sizes = counts                                     #define the size corresponds to its count
colors = cm.rainbow(np.linspace(0, 1, len(labels)))#define the color for each sector
explode = (0,)*len(sizes)                          #make distance between sectors

patches,text1,text2 = plt.pie(sizes,
                      explode=explode,
                      labels=labels,
                      colors=colors,
                      labeldistance = 1,           
                      autopct = '%3.2f%%',         
                      shadow = False,              #no shadow
                      startangle =90,              #counter-clockwise
                      pctdistance = 0.6)           #value distance from the center of the pie


plt.axis('equal')
# plt.legend()
plt.show()

# %%
items, counts =np.unique(sorted(coffee['Part - Supplier Part Number']), return_counts=True)

temp = pd.DataFrame(data={'items': items,'counts': counts}).sort_values(by=['counts'])

items, counts = temp['items'],temp ['counts']

plt.figure(figsize=(16,180)) 
plt.barh(range(len(counts)), counts, height=0.7, color='steelblue', alpha=0.8)
plt.yticks(range(len(counts)), items)
plt.show()

# %%
items, counts =np.unique(sorted(toner['Part - Supplier Part Number']), return_counts=True)

temp = pd.DataFrame(data={'items': items,'counts': counts}).sort_values(by=['counts'])

items, counts = temp['items'][-20:][::-1],temp ['counts'][-20:][::-1]

plt.figure(figsize=(16,24))                        #resize the figure
labels = items                                     #define the labels as Supplier Part Number
sizes = counts                                     #define the size corresponds to its count
colors = cm.rainbow(np.linspace(0, 1, len(labels)))#define the color for each sector
explode = (0,)*len(sizes)                          #make distance between sectors

patches,text1,text2 = plt.pie(sizes,
                      explode=explode,
                      labels=labels,
                      colors=colors,
                      labeldistance = 1,           
                      autopct = '%3.2f%%',         
                      shadow = False,              #no shadow
                      startangle =90,              #counter-clockwise
                      pctdistance = 0.6)           #value distance from the center of the pie


plt.axis('equal')
# plt.legend()
plt.show()

# %%
items, counts =np.unique(sorted(toner['Part - Supplier Part Number']), return_counts=True)

temp = pd.DataFrame(data={'items': items,'counts': counts}).sort_values(by=['counts'])

items, counts = temp['items'],temp ['counts']

plt.figure(figsize=(16,160)) 
plt.barh(range(len(counts)), counts, height=0.7, color='steelblue', alpha=0.8)
plt.yticks(range(len(counts)), items)
plt.show()

# %%
items, counts =np.unique(sorted(coffee['Part - Supplier Part Number']), return_counts=True)

temp = pd.DataFrame(data={'items': items,'counts': counts}).sort_values(by=['counts'])

items, counts = temp['items'][-20:][::-1],temp ['counts'][-20:][::-1]



print(items, counts)
# Out:
# 204        GMT6520
# 145        GMT4061
# 227        GMT6663
# 237        GMT6732
# 343      ITD102042
# 249        GMT6792
# 231        GMT6694
# 315        GMT9572
# 112        GMT0845
# 318        GMT9577
# 130       GMT14734
# 443      NES753032
# 317        GMT9576
# 128       GMT14731
# 169        GMT6003
# 285        GMT7522
# 232        GMT6700
# 18     DIE60052101
# 124        GMT1252
# 216        GMT6602
# Name: items, dtype: object 204    2534
# 145    2378
# 227    1616
# 237    1293
# 343    1132
# 249    1124
# 231    1083
# 315     991
# 112     934
# 318     867
# 130     778
# 443     776
# 317     775
# 128     771
# 169     728
# 285     710
# 232     707
# 18      640
# 124     561
# 216     536
# Name: counts, dtype: int64

# %%
total_number = sum([ i * 24 for i in counts]) - counts.tolist()[4] - counts.tolist()[11] # ??????????????????
print("the total number of eighteen most used K-cup is " ,total_number, " pieces")
# Out:
# the total number of eighteen most used K-cup is  500508  pieces

# %% [markdown]
# ### Componets for Plastic coffee pod
#
# total: 3.0213 g
#
# Shell total: 1.7908 g + 0.7841 g (ring) = 2.5749 g [Polypropylene]
#
# Lid total: 0.2462 g = Aluminum (24%) PET coating (12%) LDPE (50%) Printing ink (14%)
#
# Filter Total: 0.2002 g (6.63%) = Kraft paper, bleached (79%) + LDPE (21%)
#
# reference: https://www.nature.com/articles/s41598-020-65058-1/tables/3

# %%
print("the total weight of waste includes:")
print("total weight: ", 3.0213 * total_number, " g")
print("total weight of Polypropylene: ", 2.5749 * total_number, " g")
print("total weight of Aluminum:", 0.0591 * total_number, "g")

print("total weight of PET coating: ", 0.0295 * total_number, " g")
print("total weight of LDPE: ",( 0.1231 + 0.042 )* total_number, " g")
print("total weight of Printing ink: ", 0.0345 * total_number, " g")
print("total weight of bleached Kraft paper: ", 0.1582 * total_number, " g")
# Out:
# the total weight of waste includes:
# total weight:  1512184.8204  g
# total weight of Polypropylene:  1288758.0492  g
# total weight of Aluminum: 29580.0228 g
# total weight of PET coating:  14764.985999999999  g
# total weight of LDPE:  82633.8708  g
# total weight of Printing ink:  17267.526  g
# total weight of bleached Kraft paper:  79180.3656  g

# %% [markdown]
# factor for Plastic coffee cream
#
# total: 12.9777 - 10.6310 = 2.3467 g
#
# <!-- Shell total: 1.7908 g + 0.7841 g (ring) = 2.5749 g [Polypropylene]
#
# Lid total: 0.2462 g = Aluminum (24%) PET coating (12%) LDPE (50%) Printing ink (14%)
#
# Filter Total: 0.2002 g (6.63%) = Kraft paper, bleached (79%) + LDPE (21%) -->

# %%
print("total waste for the top two creams: ITD102042 + NES753032")
total2 = (counts.tolist()[4] + counts.tolist()[11]) * 2.3467
print("total weight: ", total2 , " g")

print("total weight of Polypropylene: ", 2.5749 / 3.0213 * total2, " g")
print("total weight of Aluminum:", 0.0591 / 3.0213 * total2, "g")

print("total weight of PET coating: ", 0.0295/3.0213 * total2, " g")
print("total weight of LDPE: ",0.1231 / 3.0213 * total2, " g")
# Out:
# total waste for the top two creams: ITD102042 + NES753032
# total weight:  4477.5036  g
# total weight of Polypropylene:  3815.9481083109918  g
# total weight of Aluminum: 87.58496764968721 g
# total weight of PET coating:  43.71838486744116  g
# total weight of LDPE:  182.4316331248138  g
