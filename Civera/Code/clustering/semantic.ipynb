# %%
import pandas as pd
import numpy as np
import spacy
import mysql.connector

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Load Data

# %%
chunksize = 1000
for chunk in pd.read_csv('./actor_action_desc.csv', chunksize=chunksize):
    print(chunk.head())
    break
# Out:
#            0                  1  \
# 0  Plaintiff  Application filed
# 1  Plaintiff   Appearance filed
# 2  Plaintiff  Application filed
# 3      Court    Event scheduled
# 4      Court  Return of Service
#
#                                                    2
# 0  Application filed on 04/27/2011 at Boston Muni...
# 1  Appearance for Potfolio Recovery Associates, L...
# 2  Supplementary process application filed; filin...
# 3         HEARING SCHEDULED for 06/09/2011 10:00 AM.
# 4  Return of service on complaint and summons to ...

# %%
temp = chunk.iloc[:10].values
for description in temp[:,2]:
    doc = nlp(description)
    for i,token in enumerate(doc):
        print(token.text, token.tag_, token.head.text, token.dep_)
    print('\n\n')
# Out:
# Application NN filed nsubj
# filed VBD filed ROOT
# on IN filed prep
# 04/27/2011 CD on pobj
# at IN filed prep
# Boston NNP Court compound
# Municipal NNP Court compound
# Court NNP at pobj
# , , Court punct
# Dorchester NNP Div compound
# Div NNP Court appos
# .. . filed punct
#
#
#
# Appearance NNP Appearance ROOT
# for IN Appearance prep
# Potfolio NNP Associates compound
# Recovery NNP Associates compound
# Associates NNPS for pobj
# , , Appearance punct
# Llc NNP filed nsubj
# filed VBN Appearance acl
# by IN filed agent
# Attorney NNP STEPHEN compound
# STEPHEN NNP by pobj
# A. NNP Appearance punct
# WIENER NNP MA nmod
# 340 CD WIENER nummod
# Main NNP Suite compound
# Street NNP Suite compound
# Suite NNP WIENER appos
# 959 CD Suite nummod
# Worcester NNP MA compound
# MA NN MA ROOT
# 01608 CD 0613 compound
# - HYPH 0613 punct
# 0613 CD MA appos
# BBO NNP MA appos
# # $ MA appos
# 656119 CD MA punct
#
#
#
# Supplementary JJ process amod
# process NN application compound
# application NN filed nsubj
# filed VBD filed ROOT
# ; : filed punct
# filing NN fee compound
# fee NN filed npadvmod
# of IN fee prep
# $ $ 30.00 nmod
# 30.00 CD of pobj
# and CC fee cc
# surcharge NN fee conj
# of IN surcharge prep
# $ $ 15.00 nmod
# 15.00 CD of pobj
# paid VBN 15.00 acl
# ; : filed punct
# summons NNS application appos
# issued VBN summons acl
# for IN issued prep
# D01 NNP for pobj
#   _SP D01 nummod
# THOMAS NNP IRBY compound
# IRBY NNP D01 appos
# , , IRBY punct
# JR NNP IRBY appos
# . . summons punct
# and CC filed cc
# sent VBD filed conj
# to IN sent dative
# STEPHEN NNP WIENER compound
# A. NNP WIENER compound
# WIENER NNP to pobj
# for IN WIENER prep
# service NN for pobj
# ( -LRB- service punct
# G.L. NNP service appos
# c.224 NNP G.L. nummod
# § NNP service appos
# 14 CD § nummod
# ; : filed punct
# c.262 ADD filed dep
# § NNP c.262 appos
# 2 CD § nummod
# , , § punct
# 4C NN § appos
# ) -RRB- c.262 punct
# . . filed punct
#
#
#
# HEARING VBG HEARING ROOT
# SCHEDULED VBN HEARING dobj
# for IN HEARING prep
# 06/09/2011 CD AM nummod
# 10:00 CD AM nummod
# AM NN for pobj
# . . HEARING punct
#
#
#
# Return NN Return ROOT
# of IN Return prep
# service NN of pobj
# on IN Return prep
# complaint NN on pobj
# and CC complaint cc
# summons NNS complaint conj
# to IN Return prep
# D01 NNP to pobj
#   _SP D01 nummod
# THOMAS NNP IRBY compound
# IRBY NNP Return appos
# , , IRBY punct
# JR NNP IRBY npadvmod
# . . Return punct
# : : Return punct
# Officer NN service compound
# service NN SERVED nsubj
# SERVED VBD SERVED ROOT
# at IN SERVED prep
# last JJ abode amod
# and CC last cc
# usual JJ last conj
# abode NN at pobj
# . . SERVED punct
#
#
#
# CONTINUED JJ CONTINUED ROOT
# FOR IN CONTINUED prep
# PAYMENT NN FOR pobj
# until IN CONTINUED prep
# 12/15/2011 CD AM nummod
# 10:00 CD AM nummod
# AM NN until pobj
# . . CONTINUED punct
#
#
#
# Capias NNP issued nsubj
# issued VBD issued ROOT
# for IN issued prep
# D01 NNP THOMAS compound
# THOMAS NNP IRBY compound
# IRBY NNP for pobj
# , , IRBY punct
# JR NNP IRBY npadvmod
# . NNP issued punct
# ; : issued punct
# arrest NN issued dep
# after IN authorized mark
# sunset NN authorized nsubjpass
# has VBZ authorized aux
# not RB authorized neg
# been VBN authorized auxpass
# authorized VBN arrest advcl
# ( -LRB- G.L. punct
# G.L. NNP arrest appos
# c.224 NNP G.L. nummod
# § NNP G.L. appos
# 18 CD G.L. nummod
# ) -RRB- G.L. punct
# ; : G.L. punct
# ( -LRB- issued punct
# Miller NNP issued appos
# , , Miller punct
# Hon NNP Miller npadvmod
# . . Hon punct
# Rosalind NNP H compound
# H NN H ROOT
# ) -RRB- H punct
# ; : sent punct
# sent VBN sent ROOT
# to IN sent dative
# Attorney NNP STEPHEN compound
# STEPHEN NNP BBO#656119 compound
# A. NNP BBO#656119 compound
# WIENER NNP BBO#656119 compound
# BBO#656119 NN to pobj
# for IN BBO#656119 prep
# service NN for pobj
# . . sent punct
#
#
#
# Case NN Inactivated nsubj
# Inactivated VBN Inactivated ROOT
# : : Inactivated punct
# Capias NNP Inactivated appos
# outstanding JJ Capias amod
# . . Inactivated punct
#
#
#
# No DT Capias det
# Capias NNP returned nsubj
# returned VBD returned ROOT
#
#
#
# Notice NN Notice ROOT
# of IN Notice prep
# dismissal NN of pobj
# of IN dismissal prep
# supplementary JJ process amod
# process NN of pobj
# without IN Notice prep
# prejudice NN without pobj
# filed VBN prejudice acl
# by IN filed agent
# P01 NNP POTFOLIO nmod
#   _SP POTFOLIO compound
# POTFOLIO NNP ASSOCIATES compound
# RECOVERY NNP ASSOCIATES compound
# ASSOCIATES NNPS by pobj
# , , ASSOCIATES punct
# LLC NNP ASSOCIATES conj
# . . Notice punct

# %%
mydb = mysql.connector.connect(host='73.38.248.152', user='buspark', password='U@5p1r3!')

if (mydb):
    print("Connection Successful")

else:
    print("Connection Unsuccessful")

mycursor = mydb.cursor()

mycursor.execute("Show databases")

for db in mycursor:
    print(db)
# Out:
# Connection Successful
# ('information_schema',)
# ('civica_courtdocs',)
# ('wp_courtdocs',)
# ('wp_courtdocs_NORMALIZED',)

# %%
action_null = pd.read_sql("SELECT * FROM wp_courtdocs.cdocs_case_action_index as c_a_index \
                          WHERE c_a_index.action = ' ' and c_a_index.actor = ' ' LIMIT 0, 1000;"
                          ,con = mydb)
action_null.head()
# Out:
#    case_action_id  case_id actor action  \
# 0           12248    12238
# 1           12250    12238
# 2           12251    12238
# 3           12254    12238
# 4           12308    12304
#
#                                          description  date_time  \
# 0  NOTICE:  Citation on Petition for Formal Adjud... 2014-09-30
# 1                  Citation Filed; Served as Ordered 2014-10-31
# 2  An Interested Person,Johanna Soris, Asst. Atto... 2014-10-31
# 3   Letters of Authority for Personal Representative 2014-11-06
# 4  NOTICE:  Citation on Petition for Formal Adjud... 2014-07-02
#
#    file_reference_number        last_indexed
# 0                      0 2017-02-05 14:49:43
# 1                      0 2017-02-05 14:49:43
# 2                      0 2017-02-05 14:49:43
# 3                      0 2017-02-05 14:49:43
# 4                      0 2017-02-05 14:49:43

# %%
action_null['description'].tolist()
# Out:
# ['NOTICE:  Citation on Petition for Formal Adjudication Issued.',
#  'Citation Filed; Served as Ordered',
#  'An Interested Person,Johanna Soris, Asst. Attorney General , Filed Form MPC 455 toPetition for Formal Adjudication and for the appointment of PR',
#  'Letters of Authority for Personal Representative',
#  'NOTICE:  Citation on Petition for Formal Adjudication Issued.',
#  'Suspicious Death Affidavit',
#  'Citation Filed; Served as Ordered',
#  'Letters of Authority for Personal Representative',
#  'Assent of Mary Jeanne Mullen',
#  'It is ordered that notice by made by Publication, Mail, In hand service.  If by publication, published in The Recorder, Greenfield.\n\n',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary dated 12/29/10',
#  'Inventory Issued',
#  'Inventory  Filed',
#  'Subsequent Action First and Final Account filed',
#  'Appearance by attorney Deborah T Jankowski Esq.\n\n',
#  'Judgment on First and Final Account',
#  "An Interested Person,Curtis Janey, o/b/o Isaiah C. Janey , Filed Form MPC 455 topetition for formal probate of Leah Casey Tracey's will and appointment of Stanley E. Tracy",
#  'NOTICE:  Citation on Petition for Formal Adjudication Issued.',
#  'Citation Filed; Served as Ordered',
#  'Letters of Authority for Personal Representative',
#  'Will dated February 4, 2000',
#  'NOTICE:  Citation on Petition for Formal Adjudication Issued.',
#  'Citation Filed; Served as Ordered',
#  'Letters of Authority for Personal Representative',
#  'ATTESTED Copy issued',
#  'Will dated June 8, 2012',
#  'NOTICE:  Citation on Petition for Formal Adjudication Issued.',
#  'Citation Filed; Served as Ordered',
#  'Bond of Michael G. Duffy Approved Clement A Ferris\nallowed 8/4/2014',
#  'Letters of Authority for Personal Representative',
#  'Statement of Confirmation of Testamentary Trustee',
#  'Decree on Statement of Confirmation of a Testamentary Trustee dated August 18, 2014 Atty/Ptys ND 08/18/2014',
#  'Disclaimer of Interest in Life Insurance Policy on the Life of Robert B. Duffy of Evelyn M. Duffy by Michael G. Duffy, her attorney in fact',
#  'PLAINTIFF HAS NOTIFED THE DEFENDANT OF THE PAYMENT REVIEW DATE',
#  'Motion FOR SHORT ORDER NOTICE ON CITATION////case sent to potter',
#  'Motion short order of notice Allowed 01/12/2010\n\n',
#  'It is ordered that notice be made by Mail.  If by publication, published in , .\n\nSeven Day Notice',
#  'Will Eleven pages 07/07/2011',
#  'Letters of Authority for Personal Representative',
#  'It is ordered that notice by made by Publication.  If by publication, published in Foxboro Reporter, Foxborough.\n\n',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  'Bond without Approved Unassigned\n\n\n\n',
#  'Inventory Issued',
#  'Inventory  Filed',
#  'Subsequent Action on first and final Account filed on 12/7/11',
#  '6 Release of All Demands and Assent to Account',
#  'Judgment on First and Final Account 12/7/11',
#  'R 41(a)(1) Voluntary Dismissal',
#  'Misc Entry: Served Notice to Show Cause was not returned to court',
#  'Case # 1206cv468 Transferred from BMC -West Roxbury to Somerville District Court',
#  'Misc Entry:\n\n1334 SC 995 (Attleboro DC)',
#  'Petition',
#  'Judgment/Decree on Subsequent Action',
#  '',
#  'Appearance limited to this date only filed for plaintiff by Mandy L. Spaulding Esq., Esquire, BBO No. 663286.\n\n',
#  'Attorney Daniels, Jr., Esq., Richard S representing Midland Funding as of Thu Dec 09 00:00:00 EST 2010',
#  ' Defendant Discovery Requests\n\n',
#  'R 41(a)(1) Voluntary Dismissal',
#  'Will   3 pages',
#  'Misc Entry:\n\n1332 CV 0972',
#  'Will Five pages dated June 30, 1989',
#  'Assent and Waiver of Notice and Waiver of Sureties, Jeffrey S. Beeler',
#  'Assent and Waiver of Notice and Waiver of Sureties, Michael A. Beeler',
#  'Assent and Waiver of Notice, Renunciation and Waiver of Sureties, John D. Beeler',
#  'Assent and Waiver of Notice and Waiver of Sureties, John Beeler',
#  'Assent and Waiver of Notice and Waiver of Sureties, Jason F. Beeler',
#  'Letters of Authority for Personal Representative',
#  'It is ordered that notice by made by Publication, Mail.  If by publication, published in Amherst Bulletin, Amherst.\n\n',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  'Inventory Issued',
#  'Inventory  Filed',
#  "Satisfaction and Release of Creditor's Claim",
#  'Agreement',
#  'Small Claims Complaint, Over $500 but Under $2000',
#  'Third Party Complaint and Motion to Intervene as Plaintiff  MGL chapter 262 section 2 Receipt: 62371 Date: 07/14/2014',
#  'Bond James C. Brown of Walp[ole,Mass personal Representative Approved Hon. Dorothy M Gibson\n-dated 02/26/2014',
#  'Subsequent Letter Issued 8 In hand @ counter',
#  "Defendant's copy of judgment returned - Moved left no address.",
#  'Execution Writ for possession of commercial premises in favor of P01  CHRISTOPHER T. NATALE (valid 20 years; G.L. c.235  17); sent to P01  CHRISTOPHER T. NATALE for service.',
#  'Origin 1, Type E95, Track F.',
#  'SERVICE RETURNED (summons): Iris Velazquez, service made on 4/30/2014\n(certified mail)',
#  "Defendant Iris Velazquez's MOTION to Intervene",
#  'Motion (P#3) DENIED for failure to comply with SC Rule 9A. (John S.\nMcCann, Justice) Notices mailed 5/21/2014',
#  'Request upon clerk to default (55a) re: Iris Velazquez by Comm of\nMass;Affidavit in support',
#  'Affidavit that Iris Velazquez is not in military service',
#  'Default (55a) as to defendant Iris Velazquez. Copies mailed 5/30/2014',
#  "Plaintiff Comm of Mass' MOTION for judgment of default against Iris\nVelazquez",
#  'Motion (P#7) ALLOWED (John S. McCann, Justice) Notices mailed 6/5/2014',
#  'Default judgmnt (55b2) by court for the plaintiff v defendantIris\nVelazquez . See Order. ( John S. McCann, Justice), Copies mailed\n6/5/2014',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0  Receipt: 8582  Date: 05/18/2011',
#  'Renunciation of Right to Appointment, Nomination of Personal Representative',
#  'Waiver of Notice',
#  'Bond Personal Representative Approved \n\n',
#  'Case transferred in to Lynn District Court from BMC - Central: Transfer by Dist Ct Chief Justice/Reg Adm Justice\n\ndefendant has moved  (BMC DOCKET NUMBER 1101SC0522)',
#  'Notice concerning next court event, to wit - 02/15/2013 12:00 PM Payment Review-- sent to parties.\n\nPlease note: This case has been transferred from Boston Municipal Court. A new Docket Number has been assigned and a payment review hearing is scheduled in Lynn District Court.\n\n\n\nPrevious Docket Number 1101SC0522',
#  'Appearance limited to this date only filed for plaintiff by Gina Marie Desrochers Esq., Esquire, BBO No. 681910.\n\n',
#  'Agreement',
#  'It is ordered that notice by made by Publication.  If by publication, published in Quincy Sun, Quincy.\n\n',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  'Bond without Approved Unassigned\n\n',
#  'Inventory Issued',
#  'Service insufficient.',
#  'Assent, Waiver of Notice, Renouncement and Waiver of Sureties',
#  'Bond for Faith A. Richard Approved Julie Matuschak\n\ndated 01/09/13',
#  'Letters of Authority for Personal Representative',
#  'Order; parties notified.',
#  "Misc Entry: Defendant files copy of answer to plaintiff's interrogatories.",
#  'CMC held; continued with notice for: Pretrial Conference (CV)\nDate: 10/02/2013  Time: 09:00 AM\nResult: Event Continued',
#  'Event Re-Scheduled with notice for\nEvent: Pretrial Conference (CV)\nDate: 03/12/2014  Time: 09:00 AM. Trial Order to the parties for Jury Trial 04/11/2014 and lobby conference 04/03/2014.\nResult: Not Held But Event Resolved',
#  'Notice sent to parties.\nA Notce to the Parties was generated and sent to:\nPlaintiff:  Mark C Gildea, Esq.\nDefendant:  James E Costello, Esq.\nDefendant:  James E Costello, Esq.',
#  'Notice sent to parties to comply with Trial Order for conference 04/03/2014 and jury trial 04/11/2014.',
#  'Assent',
#  'Findings and Order',
#  'Agreement',
#  'Agreement',
#  'Agreement',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0  Receipt: 7323  Date: 04/25/2012',
#  'Origin 1, Type E95, Track F.',
#  'SERVICE RETURNED (summons): Dingle R Fullerton, service made on\n4/23/2014 (certified mail)',
#  'Request upon clerk to default (55a) re: Dingle R Fullerton by Comm of\nMass & Affidavit in support of request',
#  'Affidavit that Dingle R Fullerton is not in military service',
#  'Default (55a) as to defendant Dingle R Fullerton. Copies mailed\n5/27/2014',
#  "Plaintiff Comm of Mass' MOTION for judgment of default against Dingle\nR Fullerton",
#  'Motion (P#6) ALLOWED (Daniel M Wrenn, Justice) Notices mailed 6/5/2014',
#  'Default judgment (55b1) (See Judgment) (Daniel M Wrenn, Justice)\nEntered and certified copy mailed 6/5/14',
#  'Misc Entry:  CMC Report filed.',
#  'Pretrial conference report filed.',
#  'Misc Entry:  The defendant has no current ability to pay this debt at this time.',
#  'Information and Rights of Interested Parties',
#  'It is ordered that notice by made by Publication, Mail.  If by publication, published in Jamaica Plain Gazette, Boston.\n\n',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  '2 Executor Certificates         Mailed',
#  'Inventory Issued',
#  "Misc Entry:  Plt.'s Motion to Compel Production of Documents filed.",
#  'Misc Entry:  Plt. request for Default Judgment under rule 33A, filed, not scheduled.',
#  'Notice sent to parties. Copy of allowed motion to dismiss\n\nA Notce to the Parties was generated and sent to:\n\nPlaintiff:  JA Enterprises, LLC\n\nDefendant:  Raymond A Yox, Esq.',
#  'SP Summons and Complaint - Foreclosure',
#  'Notice to show cause requested by judgment creditor as judgment debtor has not paid as ordered.',
#  'Misc Entry:  Attorney Callahan forgot to have the defendant served notice to show cause hearing.  New notice was issued.',
#  "Summons mailed to Plaintiff's Counsel as requested.",
#  'Judgment creditor requests issuance of notice to show cause as debtor has not paid as ordered.',
#  'DEFENDANTS NOTICE OF JUDGMENT RETURNED.',
#  '',
#  'CMC held; continued with notice for\nEvent: Pretrial Conference (CV)\nDate: 04/10/2013  Time: 09:00 AM',
#  'Event Re-Scheduled at request of Defendant for: Pretrial Conference (CV)\nDate: 05/08/2013  Time: 09:00 AM. Settlement pending.',
#  'Plaintiff Pre Trial Memo',
#  'Notice sent to parties for Bench Trial 08/14/2013.',
#  'Small Claims Complaint, Over $500 but Under $2000',
#  '1Blank Summons and 1 trustee summons MGL 262 section 4b  Receipt: 11979  Date: 09/01/2011',
#  'Findings: Finding and Order of approval of attachment on trustee process.\n',
#  'Order; parties notified.',
#  'Notice sent to parties.\nA Notce to the Parties was generated and sent to:\nPlaintiff:  Kenneth C Wilson, Esq.\nDefendant:  Michele M Moran\nTrustee:  Michael J Colognesi, Esq.',
#  'Misc Entry:\n\nCapias served   60.00',
#  'Taken under advisement ( Uhlarik, J). Plaintiff was present- Attorney Anctil for defendant.  Plaintiff granted leave to file written opposition within 1 week, by 10/20/11.  Defendant counsel to file copy of motion for summary judgment via fax (no motion in file)',
#  'Misc Entry: The parties jointly request that the case be dimsissed without prejudice.  Signed and allowed by First Ast C-M Joseph Kattar',
#  'Statement of Voluntary Executor',
#  'Origin 1, Type E95, Track F.',
#  'SERVICE RETURNED (summons): Saleh Nouhou, Randy Frye, service made on\n4/23/2014 (certified mail)',
#  'Request upon clerk to default (55a) re: Saleh Nouhou, Randy Frye by\nComm of Mass; Affidavit in Support',
#  'Default (55a) as to defendants Saleh Nouhou and Randy Frye. Copies\nmailed 5/30/2014',
#  'Affidavit that Saleh Nouhou and Randy Frye are not in military service',
#  "Plaintiff 's MOTION for default judgment",
#  'Motion (P#6) ALLOWED (Janet Kenton-Walker, Justice) Notices mailed\n6/10/2014',
#  "DEFAULT JUDGMENT; It is ORDERED and ADJUDGED: 1. That the defendant\n$323.00 in US Currency, seized on June 6, 2013, is hereby forfeited\nas to the interested parties, Saleh Nouhou and Randy Frye; 2. That\nthe defendant $323.00 in uS Currency, the amount of $161.50 in US\nCurrency be forfeited to the Comm of Mass through the District\nAttorney's Office for the Middle District to be used for education,\nInvestigation and prosecution of cases and the use thereof as\nprovided for under G.L. c.94C, sec.47; 3. That the balance of the\ndefendant currency in the amount of $161.50 in US Currency be\nforfeited to the Massachusetts State Police to be used for the same\npurpose as stated above; 4. This judgjment forfeits any and all\ninterests that Saleh Nouhou and Randy Frye may have in the defendant.\n(see judgment). (Janet Kenton-Walker, Justice), Entered and Copies\nmailed 6/10/2014",
#  'Request for Temporary Restraining Order filed',
#  'Civil Fee: MGL Chapter 185C Section 19; Chapter 262 Section 2\n\n\n\n\n\nDismissed Amount:       120.00\n\nDismissed Date: 07-jan-2010\n\nDismissed Type: INDIGENCY\n\nDismissed By: RAPPK\n\nComments:',
#  'The court has waived $135.00 in court costs for Plaintiff Rafael Rivera.\n\n',
#  'Referred to Housing Specialist ~ J.B. ~ phone service to Defendant',
#  'Agreement',
#  'Service insufficient; plaintiff advised to obtain better address.',
#  'It is ordered that notice by made by Publication.  If by publication, published in Milford Daily News, Franklin.\n\n',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  'Bond without Approved Unassigned\n\n',
#  'Inventory Issued',
#  'Inventory  Filed',
#  'PLAINTIFF ABSENT, DEFENDANT PRESENT, DEFT HAS NOT MADE PAYMENTS YET, WILL CONTACT PLAINTIFF. NO ACTION TAKEN.',
#  'Notice to show cause requested by judgment creditor as judgment debtor has not paid as ordered.',
#  'Notice to show cause issued against D01 ROBERT HARTHAN (Uniform Small Claims Rule 9[a]); sent to P01 DONALD J. VACHON for service.',
#  'Appearance limited to this date only filed for plaintiff by Gina Marie Desrochers Esq., Esquire, BBO No. 681910.\n\n',
#  'Satisfaction of judgment demonstrated and ordered noted on docket.',
#  'SP Summons and Complaint - Foreclosure',
#  'Request of Massachusetts Housing Finance Agency to issue execution\n\n',
#  'Return of Execution',
#  '2 Renunciations of Right to Appointment, Nomination of Personal Representative ,nominations ,assents and waivers',
#  'Bond PRP Approved \nJack Harney',
#  'Letters of Authority for Personal Representative',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0 Receipt: 23235 Date: 07/18/2013',
#  'Appearance limited to this date only filed for plaintiff by Samantha Jane Court, Esq., Esquire, BBO No. 675318.',
#  'CMC held; continued with notice for\nEvent: Pretrial Conference (CV)\nDate: 04/10/2013  Time: 09:00 AM',
#  'Corrected judgment to issue: Although judgment on line #15 is correct the notice of judgment that was issued to the parties was the wrong judgment that had been entered initially but corrected before notices were issued. Due to clerical error those notice\ns were mistakenly sent to the parties instead of the correct one that was printed after.',
#  "CORRECTED JUDGMENT SENT TO THE PARTIES :Judgment by Default for P01 WALDO BROS. COMPANY to recover of D01 JONATHAN WEYDT after default the sum of $13,121.84 plus prejudgment interest of $1,213.69 and costs of $247.20 for judgment total of $14,582.73 ( O'S\nhea, Hon. Daniel J. ); parties notified.",
#  'Misc Entry:\nEXECUTION RETURNED TO ATTORNEY PER REQUEST- CASE NOT DISMISSED.',
#  'Findings and Order',
#  'Returned Mail from the def.  (Deceased) for Nicholas Brown and Angela Peterson',
#  "After notice and opportunity to appear for the following event:\n10/01/2013 02:00 PM Hearing\nthe above entitled matter is dismissed for the following reason(s): * Plaintiff's request.",
#  'Will 05/31/1994',
#  'NOTICE:  Citation on Petition for Formal Adjudication Issued.',
#  'Citation Filed; Served as Ordered',
#  'Letters of Authority for Personal Representative 1 Letter Mailed',
#  'SP Summons and Complaint - Foreclosure',
#  'Referred to Housing Specialist (cpk)',
#  'Return of Execution, possession only',
#  'Appearance of Counsel of Walter H. Porr, Jr., Esq. as Counsel for Def. filed.',
#  "Defendant's Opposition to Plaintiff's Motion to Vacate filed.",
#  'Agreement',
#  'Agreement',
#  'Agreement',
#  'Agreement',
#  'Prejudgment interest waived by plaintiff(s).',
#  'Prejudgment interest waived by plaintiff(s).',
#  '1 Blank Summons and 1 trustee summons MGL 262 section 4b  Receipt: 11978  Date: 09/01/2011',
#  'Findings: Finding and Order of approval of attachment.\n',
#  'Default not entered and Notice of Inability to Enter Default issued in the summary process case because the following has not be filed: * Return of Service for your Summons and Complaint\n\nOther:\n\n',
#  'SP Summons and Complaint - Foreclosure',
#  'After notice and opportunity to appear for the following event:\n\n03/03/2011 02:00 PM Summary Process Trial \n\nthe above entitled matter is dismissed for the following reason(s): * By order of the court..\n\nPROPER DOCUMENTS NOT PROVIDED',
#  'Case Disposed',
#  "Misc Entry:  \nFaxed letter received from defendant; she want's to continue makine $50.00 monthly payments.  Defendant has provided an updated address.  Please see file.",
#  'off list.',
#  'Financial Notes:\n\n$5.00 Remitted  Clerical error.  paid $195 not $200.',
#  'Misc Entry: Request for Discovery Interrogatories and production of Documents',
#  'Misc Entry:  Motion to vacate suggesion of bankruptcy and resote matter to trila list and re issue execution for possession and money damages  against Karteka Ingram Johnson',
#  '(Tape 08-23-2010 from 10:23:36 to 10:26:00 ).',
#  'Hearing held at which plaintiff was present and defendant was not present ( Macy, Hon. Joseph I. ) (Tape 08-30-2010 from 10:07:13 to 10:08:44 ).',
#  'Motion  #2 to Attach Wages and Successive Service of Trustee Summons waived or withdrawn by moving party.',
#  'Findings: and order of approval of attachment on trustee  process $7,837.93.',
#  'Misc Entry: All parties notified of review date scheduled for 12/17/12.',
#  'Misc Entry: On 2/24/14 the defendant was found to have no present ability to pay.',
#  'Appearance limited to this date only filed for plaintiff by Samantha Jane Court, Esq., Esquire, BBO No. 675318.',
#  'Small Claims Complaint, Over $500 but Under $2000',
#  'Origin 1, Type E95, Track F.',
#  'SERVICE RETURNED (summons): Julio Matos-Sanchez, service made on\n4/29/2014 (certified mail)',
#  'SERVICE RETURNED (summons): Jose Valle-Torres, service made on\n5/14/2014 (incomplete)',
#  'Request upon clerk to default (55a) re: Julio Matos-Sanchez, & Jose\nValle-Torres by Comm of Mass & Affidavit in support of request',
#  'Affidavit that Julio Matos-Sanchez, & Jose Valle-Torres are not in\nmilitary service',
#  'Default (55a) as to defendants Julio Matos-Sanchez, & Jose\nValle-Torres. Copies mailed 5/30/2014',
#  "Plaintiff Comm of Mass' MOTION for judgment of default against Julio\nMatos-Sanchez, & Jose Valle-Torres",
#  'Motion (P#6) ALLOWED (Richard T. Tucker, Justice) Notices mailed\n6/4/2014',
#  'DEFAULT JUDGMENT (See Order) ( Richard T. Tucker, Justice), Entered\nand Copies mailed 6/4/2014',
#  'Original Execution returned back to the Plaintiff',
#  'Misc Entry: req for execution filed 11/3/2012',
#  'Misc Entry:  Original execution returned.  Execution missing the Judgment Creditor.',
#  'Execution for possession issued',
#  'Appearance limited to this date only filed for plaintiff by Gina Marie Desrochers Esq., Esquire, BBO No. 681910.\n\n',
#  "Attorney O'Brien, Jr., Esq., Lawrence E representing N Star Elextric and Gas Corporation as of Thu Dec 09 00:00:00 EST 2010",
#  "Notice sent to parties.\nA Notce to the Parties was generated and sent to:\nPlaintiff:  Lawrence E O'Brien, Jr., Esq.\nCourt inquiring if court is to transfer case to Dudley, per motion",
#  'Misc Entry:\nCase file being sent to Dudley District Court. Parties notified.',
#  "Misc Entry:\nDefendant's notice of the case being transferred was returned and unablr to be forwarded",
#  'Prejudgment interest waived by plaintiff(s).',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0  Receipt: 11874  Date: 08/31/2011',
#  'Misc Entry: Execution Writ of Money Judgment issued as to Karina Silva in the amount of $2,651.88 and sent to Stephen A. Greenbaugh, Esq. for service.',
#  'Misc Entry: Execution Writ of Money Judgment issued against Jesus Mercado in the amount of $2,651.41 and sent to Stephen A. Greenbaum, Esq. for service.',
#  'Small Claims Complaint, Over $500 but Under $2000',
#  'Findings and Order mailed this date',
#  'Misc Entry:   EXECUTION 0960CV0003   (WAREHAM DISTRICT COURT)',
#  'Service insufficient; plaintiff advised to obtain better address.',
#  'Misc Entry:  CASE REMOVED FROM LIST.  PLTFF UNABLE TO SERVE, ATTEMPTING TO LOCATE NEW ADDRESS.',
#  'Misc Entry:   EXON MAILED OUT.',
#  'Appearance limited to this date only filed for plaintiff by Samantha Jane Court, Esq., Esquire, BBO No. 675318.',
#  'Appearance limited to this date only filed for plaintiff by Samantha Jane Court, Esq., Esquire, BBO No. 675318.',
#  "Misc Entry:\n\n\n\nPlaintiff's request for exemption from time standards",
#  'Disclaimer',
#  '2 Assents',
#  'It is ordered that notice by made by Publication.  If by publication, published in The Sun Chronicle, Wrentham.\n\n',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  'Bond without Approved Unassigned\n\n',
#  'Inventory  Filed',
#  'Subsequent Action on first and final Account filed on 9/28/11',
#  '2 Assents of first and final account',
#  'Judgment on First and Final Account  10/13/11',
#  'Motion  (Emergency Ex-parte) to Stay the Use of Execution was denied.\n\nNotices issued.',
#  'Misc Entry:neitherm party at call of the list/case deemed closed',
#  'Request for Temporary Restraining Order filed',
#  'Findings and Order',
#  'Referred to Housing Specialist--DAS',
#  'Agreement',
#  'Case Disposed',
#  'After notice and opportunity to appear for the following event:\n\n10/18/2013 09:00 AM Hearing on Request for Preliminary Injunction\n\nthe above entitled matter is dismissed for the following reason(s): * By order of the court..',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0',
#  'Misc Entry: case was 0564SC628',
#  'case tramsfered from small claims #1112SC518',
#  'Bankruptcy stay of proceedings as to Maureen Doiron ended by 11042227 on file (11 U.S.C. 362).\n',
#  'Motion  Plaintiffs relief from judgment entered against the Defendant allowed.\n\n',
#  'Appearance limited to this date only filed for plaintiff by Gina Marie Desrochers Esq., Esquire, BBO No. 681910.\n\n',
#  'Misc Entry: Motion for wage attachment and motion for successive service',
#  'Misc Entry:  Motion allowed',
#  'Request for Temporary Restraining Order filed',
#  'Civil Fee: MGL Chapter 185C Section 19; Chapter 262 Section 2\n\n\n\n\n\nDismissed Amount:       120.00\n\nDismissed Date: 07-jan-2010\n\nDismissed Type: INDIGENCY\n\nDismissed By: RAPPK\n\nComments:',
#  'Referred to Housing Specialist, J Burdell called LL left message,  tenants to serve by sheriff.',
#  'The court has waived $135.00 in court costs for Plaintiff Eric D Wheelock, Emily Bower.\n\n',
#  'Agreement',
#  'Agreement',
#  'Referred to Housing Specialist, J. Burdell',
#  'Agreement',
#  'Referred to Housing Specialist, J. Burdell',
#  'Assent of Paul J Graham',
#  'Assent of Anna L Graham',
#  'It is ordered that notice by made by Publication, Mail.  If by publication, published in Daily Hampshire Gazette, Worthington.\n\n',
#  'It is ordered that notice by made by Publication.  If by publication, published in Daily Hampshire Gazette, Worthington.\n\n',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  'Assent OF WILLIAM R. GRAHAM',
#  'Inventory  Filed',
#  'Case transferred in to Quincy District Court from Marlboro District Court: Transfer by Trial Ct Chief Justice for Adm and Mgm',
#  'Referred to Housing Specialist, JEH',
#  'SP Summons and Complaint - Foreclosure',
#  'Request of Federal National Mortgage Assoc. to issue execution\n\n',
#  'Return of Execution, unsatisfied',
#  'Findings: SUMMARY PROCESS FINDINGS.',
#  "No Action Taken on Def.'s Motion to Extend Time to Answer Plaintiff's Complaint ~ No answer required in small claims.",
#  'Case transferred to regular civil docket.  Civil Action No. 1562cv377',
#  'On 2/22/2011 the plaintiff was present & the defendant was not present.  A Capias was Ordered.',
#  'Notice of Appeal-MGL 218 section 23, Small Claims appeal, $25 fee  Receipt: 17127  Date: 01/19/2012',
#  'Small Claims cash depositÂ\xa0in lieu of Appeal Bond due.  Receipt: 17127  Date: 01/19/2012',
#  'Order: On 4/30/13-Defendant is ordered to pay the Plaintiff $200 per month beginning 5/30/13 with a payment review of 8/6/13 at 1:00 PM.; parties notified.',
#  'Appeal bond/deposit ordered released to Kalami Fuels Inc D/B/A Action Oil & Septic.',
#  'Order: On 07/29/2014 Defendant ordered to pay Plaintiff $2,000.00 within 30 days.  Case stands continued to 09/30/2014 @ 1:00 PM for payment review.; parties notified.',
#  'Service insufficient; plaintiff advised to obtain better address.',
#  'SP Summons and Complaint - Foreclosure',
#  'Memorandum of Wells Fargo Bank\n\nassignment of mortgage',
#  'Will 08/13/2013',
#  'NOTICE:  Citation on Petition for Formal Adjudication Issued.',
#  'Citation Filed; Served as Ordered',
#  'Motion to Amend Petition For Appointment of P.R. And Probate of Will',
#  'Letters of Authority for Personal Representative',
#  'Misc Entry:\n\nLETTER FROM PLAINTIFF- ACCOUNT SETTLED- CAPIAS DATED 7/19/12 RETURNED UNSERVED',
#  'Prejudgment interest waived by plaintiff(s).',
#  'Case dismissed no parties appeared.  Execution returned to plaintiff.',
#  "Misc Entry:  Defendant's change of address:  from 101 Pine Hill Drive, Palmer, MA 01069 ro 3171 Foster Street, Palmer, MA 01069.",
#  '30 DAy Order Requested.\n\nApplies To: Midland Funding LLC As Assignee of Chase Bank USA, N.A. (Plaintiff); Burbee, Gene (Defendant)',
#  'PRETRIAL CONFERENCE SCHEDULED on 3/15/2011 09:00 AM RESCHEDULED for 6/21/2011 09:00 AM. Reason: Request of all parties.',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0  Receipt: 14099  Date: 10/04/2012',
#  'Case transferred in to Worcester District Court from Lawrence District Court: Transfer by Trial Ct Chief Justice for Adm and Mgm\nLawrence District Court No. 0918SC2322',
#  "Attorney O'Brien, Jr., Esq., Lawrence E representing N Star Gas Corp as of Thu Dec 09 00:00:00 EST 2010",
#  'Misc Entry: was 1062SC1054',
#  'Misc Entry:  Deft. to pay $20.00 monthly',
#  'Pretrial conference report filed.',
#  'Small Claims Complaint, Over $500 but Under $2000',
#  'Findings and Order mailed this date',
#  'Misc Entry:\n\nExecution returned to attorney per request.',
#  'Copy of Foreclosure Deed filed',
#  'Misc Entry: correspondence from defendant',
#  'Defendant filed second copy of interrogatories to be returned to him on hearing date.',
#  'Defendant, David Adao, had filed an extra set of his discovery paperwork and had asked that it be returned to him at time of hearing. Paperwork returned to him by mail with his copy of notice to parties',
#  "received correspondence from defendant requesting certified copies of the Judges's Oath of office and his surety bonding company infor and current validation thereof.",
#  'Request brought to the attention of Judge Merrick',
#  "Per Judge Merrick, the information that Mr. Adao is requesting is not information that the Clerk's Office has.  Mr. Adao can attain that information from the Office of the Secretary of State",
#  'CASE HAS PRIOR DOCKET ENTRIES',
#  'Order: On 4/30/13-Defendant is ordered to pay the Plaintiff $450 per month beginning 5/30/13 with a payment review of 8/6/13 at 1:00 PM.; parties notified.',
#  'Notice to show cause requested by judgment creditor as judgment debtor has not paid as ordered.',
#  'Order: On 09/01/2015 defendant ordered to pay plaintiff $175.00 per month beginning 10/01/2015.  Payments are to be made by money order and are due the 1st of each month.  Case stands continued to 03/01/2016 at 1:00 PM for payment review.; parties notified.',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0 Receipt: 19517 Date: 04/23/2014',
#  'Codicil to Will',
#  'It is ordered that notice by made by Publication, Mail.  If by publication, published in Daily Hampshire Gazette, South Hadley.\n\n',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  'Inventory Issued',
#  'SP Summons and Complaint - Foreclosure',
#  'Request of U.S.Bank National Association to issue execution\n\n',
#  'Default not entered and Notice of Inability to Enter Default issued in the summary process case because the following has not be filed: .\n\nOther:\n\nAddress on Military Affidavit does not match address on Summons & Complaint',
#  'Request of U.S.Bank National Association to issue execution\n\n',
#  'Default not entered and Notice of Inability to Enter Default issued in the summary process case because the following has not be filed: * Rental Account Affidavit, * Military Affidavit.\n\nOther:\n\n',
#  'Prejudgment interest waived by plaintiff(s).',
#  'Service insufficient; plaintiff advised to obtain better address. Incomplete service on defendant at 404 Main Street, Hudson, MA.',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due. Receipt: 58923 Date: 09/19/2013',
#  'Small Claims Complaint for $500 or Less',
#  'Returned Mail deft Marchand, ret to sender',
#  'Case Disposed',
#  'After notice and opportunity to appear for the following event:\n\n10/23/2013 10:00 AM Small Claims Trial\n\nthe above entitled matter is dismissed for the following reason(s): * Plaintiff failed to appear..',
#  'CASE MGMT CONFERENCE SCHEDULED on 12/21/2010 09:00 AM RESCHEDULED for 3/29/2011 09:00 AM. Reason: Request of all parties.',
#  'PAYMENT REVIEW OFF LIST/ DEFENDANT MAKING PAYMENTS',
#  'Findings: SUMMARY PROCESS FINDINGS.',
#  'Request for Temporary Restraining Order filed',
#  'Referred to Housing Specialist, Mediation Failed',
#  'Findings and Order',
#  'Correspondence received from party or attorney',
#  'Correspondence received from party or attorney',
#  'Appearance by attorney for Sheune Y Hwu',
#  'Agreement',
#  'Case transferred in to Worcester District Court from Dudley District Court: Transfer by Dist Ct Chief Justice/Reg Adm Justice\nDudley District Court No. 0864SC000005',
#  'Plaintiff provided court with new address for defendant:  63 Warr Ave Wareham, MA 02571',
#  'Short order of notice to Brian McGinnis for 10/16/2014 02:00 PM Motion Hearing (CV).\nPlaintiff to notify defendant by noon 12/15/14',
#  'Attachment by trustee process in amount of $18,003.18 allowed ex parte against Brian McGinnis; trustee summons issued to Greylock Federal Credit Union As it is Trustee (Mass.R.Civ.P. 4.2).',
#  'Suggestion of Death',
#  'Bond PRP Approved \nJack Harney',
#  'Letters of Authority for Personal Representative',
#  'CHANGE OF ADDRESS OF DEFENDANT PROVIDED BY PLAINTIFF/ 314 GATEHOUSE DRIVE, EAST WAREHAM, MA 02538-1370',
#  'Notice of Appeal-MGL 218 section 23, Small Claims appeal, $25 fee. Applies To: Sullivan, Rose (Defendant)  Receipt: 15084  Date: 12/26/2012',
#  'Small Claims cash depositin lieu of Appeal Bond due.Applies To: Sullivan, Rose (Defendant)  Receipt: 15084  Date: 12/26/2012',
#  'Misc Entry:\n\nCORRESPONDENCE FROM DEFENDANT',
#  'Order: JUDGEMENT VACATED; CASE DISMISSED SEE SUMMARY PROCESS 1210SU273; parties notified.',
#  'plaintiff request execution be returned-case to remain open',
#  'execution returned this date-#WOCV2008-02461-Worcester Superior Court',
#  'Agreement for order against D03  GEORGE R. FROLLO in amount of $891,834.00',
#  'Agreement for order against D01  WILLIAM FRASIER in amount of $891,834.00',
#  'Agreement for order against D03  GEORGE R. FROLLO in amount of $891,834.00',
#  ' Defendant Discovery Requests\n\n',
#  'Rescheduled\n\nEvent: Summary Process Trial\n\nDate: 08/10/2010  Time: 09:00 AM\nResult: Not held but resolved',
#  'Appearance by attorney for Diane Taylor and \n\n',
#  'Referred to Housing Specialist (mab)',
#  'R 41(a)(1) Voluntary Dismissal',
#  'Will 10/18/2013',
#  'NOTICE:  Citation on Petition for Formal Adjudication Issued.',
#  'Letters of Authority for Personal Representative   MAILED ONE',
#  'Massachusetts Estate Tax Closing Letter',
#  'Misc Entry: was docket 0762SC1839',
#  'Small Claims Complaint, Over $5000',
#  'Findings and Order mailed this date',
#  'Agreement',
#  'R 41(a)(1) Voluntary Dismissal',
#  'Statement of Voluntary Executor',
#  'Notice of Claim ESTATE RECOVERY',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0 Receipt: 63382 Date: 07/30/2014',
#  'RECEIVED COPY OF CHECK FROM DEFENDANT TO PLAINTIFF FOR $447.13',
#  'Misc Entry:   EXECUTION 1313CV0127',
#  'Appearance limited to this date only filed for plaintiff by Dawn Marie Marsella, Esq., Esquire, BBO No. 564679.',
#  'Misc Entry:   MILITARY AFFIDAVIT REQUIRED PRIOR TO ISSUING A CAPIAS.',
#  'Appearance limited to this date only filed for plaintiff by Dawn Marie Marsella, Esq., Esquire, BBO No. 564679.',
#  'Service insufficient; plaintiff advised to obtain better address.',
#  'Misc Entry: Change of Address for Defendant from 1268 Broadway #2, Saugus, MA to 175 Blossom St, Boston, MA 02114',
#  'No ability to pay continued generally',
#  'Attested photocopies of court documents.Â\xa0 Receipt: 38074 Date: 12/10/2013',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0  Receipt: 8589  Date: 05/18/2011',
#  '3 Assents',
#  'Waiver of Sureties on the Bond and assent',
#  'Bond PRP Approved \nJack Harney',
#  'Letters of Authority for Personal Representative',
#  'Misc Entry:   Agreement of the parties governing enty of judgment filed',
#  "Order: THE COURT DENIES THE DEFENDANT'S FILING OF A THIRD PARTY COMPLAINT AND RECOMMENDS A SEPARATE COMPLAINT. (Check #7959 in the amount of $185 is being returned). ( Johnson Smith, Hon. Emogene ); parties notified.",
#  'Order ( Johnson Smith, Hon. Emogene ); parties notified.',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0  Receipt: 8591  Date: 05/18/2011',
#  'Short order of notice to Luis Zambrano A/K/A Luis A Zambrano for 10/16/2014 02:00 PM Motion Hearing (CV).\nPlaintiff to notify defendant by noon 12/15/14',
#  'Attachment by trustee process in amount of $6,066.65 allowed ex parte against Luis Zambrano A/K/A Luis A Zambrano; trustee summons issued to Legacy Banks As it is Trustee (Mass.R.Civ.P. 4.2).',
#  'Small Claims Complaint, Over $500 but Under $200',
#  'The court has waived $$50.00 in court costs for Plaintiff Jessica Huddleston.',
#  'Case Disposed',
#  'Findings, Rulings & Order for Entry of Judgment',
#  'Returned Mail-P findings-remailed 05/16/14',
#  'Misc Entry:\n\nCLERICAL ERROR//DEFENDANT APPEARED 12/6/12 CASE CONTINUE TO 5/2/13///RECALLING ORIGINAL CAPIAS',
#  'Petition for appt. of a successor trustee',
#  'Decree Appointing Pasquale Di Felice,Successor Trustee,dated 08/12/2014',
#  'Misc Entry: Defendant in court on the capias on 3/4/13 and agrees to make "voluntary" monthly payments of $10.00 beginning on 3/30/13.',
#  'Service insufficient; plaintiff advised to obtain better address.',
#  'Case transferred in to Worcester District Court from Springfield District Court: Transfer by Dist Ct Chief Justice/Reg Adm Justice\nSpringfield District Court Docket No. 0723SC3524',
#  'OFF LIST~NEITHER SIDE APPEARED',
#  'OFF LIST~NEITHER SIDE APPEARED',
#  'SP Summons and Complaint - Foreclosure',
#  'Affidavit pursuant to Rule 10',
#  'Returned Mail',
#  'Origin 1, Type B03, Track F.',
#  'On 2/22/2011 the plaintiff was present & the defendant was not present.  A Capias was Ordered.',
#  'Neither party was present.  A status request was sent to the plaintiff.',
#  'CASE MGMT CONFERENCE SCHEDULED on 12/21/2010 09:00 AM RESCHEDULED for 1/25/2011 09:00 AM. Reason: Defendant ill.',
#  'Motion  to vacate judgment allowed Hon. Fredric D Rutberg\n\nCourt deems motion as general denial of amount claimed; Plaintiff to provide documentation of debt & amount to defendant by 4/3/15.',
#  'Misc Entry:  Off list.',
#  "Summons given in hand to Plaintiff's attorney",
#  "Misc Entry: Plaintiff's Notice of Hearing on request for default judgment marked for 9/12/11 at 10:00 A.M. filed.",
#  'Misc Entry: Plaintiff filed copy of Notice of Hearing on request for default filed. Hearing was not scheduled on list by clerical error.',
#  'Misc Entry: At the Default Judgment Hearing, Attorney Jamie Ranney present - Defendant not present; Default Judgment hearing continued to 10/11/11 by agreement of parties.',
#  'Misc Entry:  Attorney Jamie Ranney present - Defendant not present; Default Judgment in the amount of $7,629.00 allowed.',
#  'Findings: FINDINGS OF THE COURT.\n\nThe Court finds for the Plaintiff by default and assesses damages in the sum of $7,629.00.',
#  "Attorney O'Brien, Jr., Esq., Lawrence E representing N Star Electric & Gas Corp as of Thu Dec 09 00:00:00 EST 2010",
#  'Misc Entry: was 0942SC209',
#  'R 41(a)(1) Voluntary Dismissal',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0 Receipt: 63381 Date: 07/30/2014',
#  'Prejudgment interest waived by plaintiff(s).',
#  'Agreement',
#  'Agreement',
#  'Change of Address by City of Springfield, Code Enforcement Department',
#  'R 41(a)(1) Voluntary Dismissal',
#  'Misc Entry:\n\nPRIOR JUDGMENT',
#  'Indigency request for waiver, substitution or payment by the Commonwealth of fees/costs entered on 10/14/2011 allowed (G.L. c.261 27B).\n\n',
#  'Misc Entry: Pltfs request to continue',
#  'Misc Entry: There is no Small Claim session on the original date of 12/22/11, all matters have been rescheduled.',
#  'Motion to remove default (Uniform Small Claims Rule 8)  allowed.\n\n',
#  'On 5/26/10 appearance of counsl filed for Plff for CMC Session',
#  'Pretrial conference report filed.',
#  'Appearance of counsel filed for Plff for PTC session',
#  'Pretrial conference report filed.',
#  'Pretrial conference report filed.',
#  'Appearance limited to this date only filed for plaintiff by Robert Spavento Esq., Esquire, BBO No. 681523.\n\n',
#  "Attorney O'Brien, Jr., Esq., Lawrence E representing NSTAR Electric Co. as of Tue Oct 04 00:00:00 EDT 2011",
#  'Misc Entry:  Deft. to produce Tax returns and pay stubs',
#  'Misc Entry:  Deft. agrees to pay $240.00 by 9/11/14',
#  'Notice of Claim ESTATE RECOVERY PROGRAM',
#  '',
#  'Service insufficient; plaintiff advised to obtain better address.',
#  'neither party, off list',
#  "Misc Entry:  Notified plaintiff per Mr. McCue's request.  He needs to fill a motion (treble damages)with notice to the defendant.  Mr.McCue needs to near this motion.",
#  'Misc Entry: Plaintiffs Motion to Amend Judgment alld w/o opposition  PJM',
#  'Execution returned-Judgment Vacated',
#  'Execution returned to creditor',
#  'Certified Copy of the Record Certificate of Service',
#  "Memo In Opposition Of The Board of Review's Supplemental Memo Of Law",
#  '2/2013 all Parties Present 2nd Session 11:35 a.m.-12:20 a.m. continued 3/6/13 @9:00 a.m.',
#  'Taken under advisement.on 2/20/13     All Parties Appeared ON 4/24/13',
#  "Order;    Memorandum of Decision & Order: For the above reasons I find that the decision of the Board of Review was based on an error of law was unsupported by substanial evidence,  and was arbitrary or capricious an abuse of discretion or otherwise not in accorance with law. Guarino v. Dir of the Div of Emp't. sec 393 Mass.89,90-91. As a result the subtantial rights of the plaintiff were prejudiced.  The Decision of the Board Review reversing the Decision of the Review Examiner must be reversed.  The Decision of the Review Examiner rendering the plaintiff eligible for unemployment  benefits must be reinstated. Judgments shall enter in favor of the Plaintiff against the defendants  parties notified.",
#  'Notice sent to parties.\nA Notce to the Parties was generated and sent to:\nPlaintiff:  Libby G Fulgione, II, Esq.\nDefendant:  Francis X. Cavanaugh, Esq.\nDefendant:  Robert V Collins, Jr., Esq.',
#  'transfered from small claims 1112SC530',
#  'Case transferred in to Gardner District Court from Orange District Court: Transfer by Dist Ct Chief Justice/Reg Adm Justice\n',
#  'Appearance limited to this date only filed for plaintiff by Janel Bennett Hebert Esq., Esquire, BBO No. 639861.\n',
#  'Appearance limited to this date only filed for plaintiff by Janel Bennett Hebert, Esq., Esquire, BBO No. 639861.',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0  Receipt: 12037  Date: 01/27/2012',
#  'Misc Entry: Defendant in court on the capias on 5/20/13 and agrees to pay $250.00 on that day and the balance by 5/24/13.',
#  'Misc Entry: Defendant in court on the capias on 3/17/14. This case was "Satisfied in Full" on that date.',
#  'Notice sent to parties for new  magistrate hearing',
#  'Dismissal requested by P01  FRANKLIN COMMONS, LP.',
#  'Attested photocopies of court documents.Â\xa0  Receipt: 917  Date: 10/13/2011',
#  'Motion  for default judgment and hearing on assessment of damages and issuance of notice to sell allowed Hon. Brian F Gilligan\n\n',
#  "Misc Entry:Judgment and Order ret'd marked Satisfied in full filed",
#  'Motion for continuance (Mass.R.Civ.P.40[b]) of case management conference allowed Maria Abascal\n\nNotices issued.',
#  'Motion under advisement by judicial officer',
#  'Small Claims Complaint, Over $500 but Under $2000',
#  'Indigency request for waiver, substitution or payment by the Commonwealth of fees/costs filed on 01/20/2010 allowed (G.L. c.261 27C) ( Brown, C-M Whitney J. ).',
#  'request for Habe',
#  'habe issued to essex county correctional facility',
#  'request for habe from Bristol county for Sean Murphy filed',
#  'Habe issued & faxed to bristol county',
#  'habe issued for both parties & faxed',
#  'Both Parties to be Habed',
#  'Misc Entry:two Habes issued, on to MCI Shirley Medium and one to Bristol County Correctional Facility',
#  'Misc Entry:Deft. being transferred to Ohio to appear in front of Grand Jury Proceedings',
#  'Misc Entry:notice for status returned for David Nassor marked refused unable to forward',
#  'Misc Entry:Habe issued for both parties',
#  'Misc Entry:Off List cannot locate David Nassor, Habes cancelled on both',
#  'Notice concerning next court event, to wit - 06/20/2012 09:00 AM Magistrate Hearing-- sent to parties.\n\n',
#  "The defendant's notice of Judgment was returned to the court marked, Attempted Not Known.  The defendant's address was corrected to Palmer, MA & the notice was remailed.",
#  'Assent',
#  "Misc Entry: Plaintiff's Attorney request for a Payment Review hearing.",
#  'Motion  Small Claims Execution. allowed.',
#  'Summary Process: MGL Chapter 185C Section 19;  Chapter 262 Section 2',
#  'Returned Mail of Yazmin Santiago',
#  "Plaintiff's Application for Execution",
#  'Returned Mail deft, return to sender',
#  "Attorney O'Brien, Jr., Esq., Lawrence E representing NSTAR Gas Company as of Tue Oct 04 00:00:00 EDT 2011",
#  'SP Summons and Complaint - Foreclosure',
#  'Deft Default Jdgmnt Returned Mail 10/10/2010',
#  "Misc Entry: left message on defendant's  machine and spoke to Krissy at the  plaintiff's office and told them that the notice is coming",
#  'Request for Temporary Restraining Order filed',
#  'Civil Fee: MGL Chapter 185C Section 19; Chapter 262 Section 2\n\n\n\n\n\nDismissed Amount:       120.00\n\nDismissed Date: 07-jan-2010\n\nDismissed Type: INDIGENCY\n\nDismissed By: RAPPK\n\nComments:',
#  'The court has waived $135.00 in court costs for Plaintiff Ines Morales.\n\nService in hand move out in process-KB',
#  'Order-mailed',
#  'Agreement reviewed by P. Montori, dismiss on 5-31-10 if full compliance',
#  'On 2/22/2011 the plaintiff was present & the defendant was not present.  A Capias was Ordered.',
#  'CASE MGMT CONFERENCE SCHEDULED on 11/23/2010 09:00 AM RESCHEDULED for 12/7/2010 09:00 AM. Reason: Request of all parties.',
#  'CASE MGMT CONFERENCE SCHEDULED on 12/7/2010 09:00 AM RESCHEDULED for 1/11/2011 09:00 AM. Reason: Request of all parties.',
#  'CASE MGMT CONFERENCE SCHEDULED on 1/11/2011 09:00 AM RESCHEDULED for 1/25/2011 09:00 AM. Reason: Request of all parties.',
#  'CASE MGMT CONFERENCE SCHEDULED on 1/25/2011 09:00 AM RESCHEDULED for 3/15/2011 09:00 AM. Reason: Request of all parties.',
#  'CASE MGMT CONFERENCE SCHEDULED on 3/15/2011 09:00 AM RESCHEDULED for 5/3/2011 09:00 AM. Reason: Request of all parties.',
#  'Misc Entry:  Matter trans. to Springfield District Court, Parties notified.',
#  'Defendant has no current ability',
#  'OFF LIST.',
#  'CMC held; continued with notice for: Pretrial Conference (CV)\nDate: 05/15/2013  Time: 09:00 AM',
#  'PT begun; continued with notice for: Pretrial Conference (CV)\nDate: 08/14/2013  Time: 09:00 AM',
#  'Pretrial conference report filed. Trial Order to the parties for jury trial 10/04/2013.',
#  'Case transferred in to Worcester District Court from Dudley District Court: Transfer by Dist Ct Chief Justice/Reg Adm Justice\n\nDudley District Court No. 0764SC0656',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0',
#  'Misc Entry: plaintiff Rex Quartulli came in to pick up check that was mailed to the court certified.  Verified his ID and advised him not to mark case satisfied until the check clears.  Gave him our fax #',
#  '2 Assents',
#  'Bond PRP Approved \nJack Harney',
#  'Letters of Authority for Personal Representative',
#  'Inventory  Filed',
#  'Closing Statement',
#  'An Interested Person,Jarrod McCarthy , Filed Form MPC 455 to closing Statement',
#  'An Interested Person,Rachel Lancione , Filed Form MPC 455 to closing Statement',
#  'Prejudgment interest waived by plaintiff(s).',
#  'Origin 1, Type E95, Track F.',
#  'SERVICE RETURNED (summons): Lance Deboise, service made on 4/23/2014\n(certified mail)',
#  'Request upon clerk to default (55a) re: Lance Deboise by Comm of\nMass; Affidavit in Support',
#  'Default (55a) as to defendant, Lance DeBoise. Copies mailed 5/27/2014',
#  'Affidavit that Lance DeBoise is not in military service',
#  "Plaintiff Comm of Mass's MOTION for judgment of default against Lance\nDeboise",
#  'Motion (P#6) ALLOWED (Janet Kenton-Walker, Justice) Notices mailed\n6/4/2014',
#  'Default judgmnt (55b2) by court for the plaintiff v defendant Lance\nDeboise . See Order. ( Janet Kenton-Walker, Justice), Copies mailed\n6/4/2014',
#  'Bankruptcy stay of proceedings as to D01  MARGARET WHITE ended by 10-41438 on file (11 U.S.C. 362)',
#  'Misc Entry:\n\nagreed motion to allow plaintiff until 4/20/14 to file answer',
#  'Motion to transfer to court with proper venue  allowed Hon. Maurice R Flynn, III.\n\nAll parties notified.',
#  'ALL ORIG. PLEADINGS & CERTIFIED COPY OF DOCKET SHEET SENT TO SALEM DIST. COURT VIA CERTIFIED MAIL.',
#  'Case transferred in to Worcester District Court from Leominster District Court: Transfer by Dist Ct Chief Justice/Reg Adm Justice\nLeominster District Court No. 1161SC680473',
#  'OFF LIST per plaintiffs request.',
#  "Summons mailed to Plaintiff's Counsel as requested.",
#  "Misc Entry: Plaintiff's request as to status of Default Judgment filed.",
#  'Blank Summons other than Summons in Small Claims NON CASE MGL 262 section 4b  Receipt: 1854  Date: 11/22/2011',
#  "Misc Entry: Plaintiff's Request for new summons filed.",
#  "Misc Entry:  Summons mailed to Plaintiff's Counsel as requested.",
#  'Attorney fees waived by plaintiff(s).',
#  "Misc Entry: Plaintiff's waiver of Counts II, IV filed.",
#  "Misc Entry: Plaintiff's Attestation of True Copy of Original Promissory Note filed.",
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  'Attorney fees waived by plaintiff(s).',
#  'Defendants request for Production of documents filed with her answer',
#  'An Interested Person,(2) , Filed Form MPC 455 toassent and waiver of notice, renunciation, nomination, waiver of sureties',
#  'Bond of Vicki J. Mishou Approved \nJuly 11, 2013 by Benjamin F. Harley, Judicial Case Manager/Magistrate',
#  'Inventory  Filed',
#  'Decree of Sale of Real Estate dated 08/07/2013',
#  'Appearance by attorney for CF SBC UST 3, LLC',
#  'Agreement',
#  'Appearance by attorney for CF SBC UST 3, LLC',
#  'Agreement',
#  'Change of Address by City of Springfield, Code Enforcement Department',
#  'Agreement',
#  'Agreement',
#  'Agreement',
#  'Agreement',
#  'R 41(a)(1) Voluntary Dismissal',
#  'Appearance by attorney for Pa Ling Wu\n\n',
#  'Findings and Order',
#  'Request of Pa Ling Wu to issue execution\n\n',
# ...
#  'Findings and Order',
#  'Returned Mail-Wayne Lawrence and Eric Roach agreed upon order dated 1-14',
#  'Defendant files acceptance of service.',
#  'Findings: finding for possession and rent in the amount of $1,248.60.\n\n',
#  'Misc Entry:\n\nBy agreement and Plaintiff notified Defendant of new date 03/09/2016.',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0 Receipt: 45252 Date: 04/14/2014',
#  'Will 12/27/1990',
#  'Misc Entry:\n Court recieved agreement',
#  'Summary Process: MGL Chapter 185C Section 19;  Chapter 262 Section 2',
#  'Defendant Discovery Requests\n\n;Interrogatories and Document Requests',
#  'Referred to Housing Specialist, AC mediated agreement',
#  'On 6/2/10 at Case management conference Deft defaulted - CMC Report filed  (Dist Ct Standing Order 1-98) ( McKeon, C-M Kathleen M. ). (Judge Paul Mahoney)',
#  'Order ( Gailey, Hon. Timothy H. ); parties notified. At the call of the case management conference the Defendant failed to appear after notice sent by the Court and is defaulted. It is further ordered that the Plaintiff shall complete all necessary action\n, including marking the case for hearing before a justice of this court, under MRCP Rule 55(b)(2) so that the case is brought to final judgment within 30 days, or said action shall be dismissed.',
#  'Motion  made in open court to vacate dismissal allowed Hon. Timothy H Gailey.\n\n',
#  'Correspondence from Stephen A. Wiener, Esq. requesting case NOT be dismissed as defendant has been paying.',
#  'Case transferred in to Plymouth District Court from Worcester District Court: Transfer by Dist Ct Chief Justice/Reg Adm Justice',
#  'Attachment in amount of $20,000.00 allowed against D02  ANDREW B. BUNTIN ( McGovern, Hon. James J. ); writ of attachment issued (Mass.R.Civ.P. 4.1.(f)).',
#  'Appearance limited to this date only filed for plaintiff by Christine Lynn Butler Esq., Esquire, BBO No. 646570.\n',
#  'Appearance limited to this date only filed for plaintiff by Christine Lynn Butler Esq., Esquire, BBO No. 646570.\n',
#  'Bond of Robert L. Macomber Approved \nJuly 15, 2013 by Benjamin F. Harley, Judicial Case Manager/Magistrate of Probate',
#  'Inventory  Filed',
#  'R 41(a)(1) Voluntary Dismissal',
#  'Deft came in at 10:10 on 9/18/14 Case continued to 2/19/15',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0 Receipt: 23237 Date: 07/18/2013',
#  'Off list, request of Pltf.',
#  'Findings: finding for possession and rent.\n\n',
#  'Notice sent to parties.\n\nA Notce to the Parties was generated and sent to:\n\nPlaintiff:  Davdi G. Piper, Jr. Pres. Pine Tree Village, Inc.\n\nDefendant:  Christina Piunti\n\nPlaintiff:  David G. Piper, Jr. Pres. Pine Tree Village, Inc.',
#  'Prejudgment interest waived by plaintiff(s).',
#  'Defendant has no ability to make payments at this time.',
#  'OFF LIST~NEITHER SIDE APPEARED',
#  'on 8/21/13 Deft defaulted',
#  'Notice of Claim by MA Estate Recovery',
#  'Hearing held at which both plaintiff and defendant were present ( Sullivan, Hon. James M. ) (Tape 1st session from 12:00 pm to ?? ).',
#  'Stipulation filed: plff. agrees to stay execution through 5/31/11\n\npursuant to terms of "Amended Agreeement".',
#  '4 Assents  and waivers',
#  'It is ordered that notice by made by Publication.  If by publication, published in Westwood Press, Westwood.\n\n',
#  'Motion for appt of temp executor Allowed 01/05/2011\n\n',
#  'Order appt temp executor',
#  'Bond temp executor Approved Rick Schmidt\n\n',
#  'Inventory Issued',
#  'Citation Filed; Served as Ordered',
#  'Decree Appointing Fiduciary',
#  'Bond WITHOUT Approved Unassigned\n\n',
#  'Service insufficient',
#  'Service insufficient; plaintiff advised to obtain better address.',
#  'Appearance limited to this date only filed for Unifund Corporation by Edwin Herbert Howard, Esq., 241700 BBO No.',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0 Receipt: 21668 Date: 02/13/2014',
#  'Notice sent to parties for new magistrate hearing date',
#  'Notice sent to parties for new magistrate hearing.',
#  'Attorney Daniels, Jr., Esq., Richard S representing Midland Funding as of Thu Dec 16 00:00:00 EST 2010',
#  'Request for Temporary Restraining Order filed',
#  'Referred to Housing Specialist, DMZ faxed to water dept, LL accepted phone service and copy mailed to  LL.',
#  'The court has waived $$135.00 in court costs for Plaintiff Robyn Pearson.',
#  'Returned Mail deft, ret to sender',
#  'Agreement',
#  'Referred to Housing Specialist--DAS',
#  'Transferred to regular civil docket (G.L. c.218 24; Uniform Small Claims Rule 4(a)).',
#  'Notice sent to parties. of Case Management',
#  'NOTICE OF CMC sent to all parties. (CMC IS AS TO ERIK DORSEY & KRISTIN A. SANTANGELO, ALIAS) #12',
#  'Notice sent to parties.\n\nA Notce to the Parties was generated and sent to:\n\nPlaintiff:  Thomas M. Palmer, Esq.\n\nDefendant:  Robert Dorsey\n\nDefendant:  Paul E. Kelleher, Esq.\n\nDefendant:  David G Prentiss, Esq.',
#  'Motion  #20 to continue pre-trial conference (assented to ) allowed Hon. Bernadette L Sabra\n\n- copy to parties',
#  'NOTICE OF PRE-TRIAL sent to all parties. #21',
#  'Pre-Trial Conference Report filed.   #25',
#  'NOTICE OF JURY TRIAL sent to all parties. #26',
#  'Notice sent to parties.\n\nA Notce to the Parties was generated and sent to:\n\nPlaintiff:  Thomas M. Palmer, Esq.\n\nDefendant:  Paul E. Kelleher, Esq.\n\nDefendant:  Paul E. Kelleher, Esq.\n\nDefendant:  David G Prentiss, Esq.',
#  'Discharge of Debtor.',
#  'ON 1/05/2011 an agreement for continuance was filed.  The case was continued to 6/21/2011.  A copy was given in hand to both parties.  As a Judgment has not entered as yet, this case needs to be continued to a trial date.  The court will continued this ca\nse to 6/15/2011.',
#  'Origin 1, Type B04, Track F.',
#  'Filing fee paid in the amount of $275.00 including $15.00 surcharge\nand $20.00 security fee.',
#  'Plaintiffs First Request for Production of Documents to Defendant,\nConsigli Construction Co. Inc.',
#  "Atty Michael F Ashe's notice of appearance for Deft Consigli\nConstruction Co Inc",
#  'ANSWER: Deft Consigli Construction Co Inc- CJ',
#  'ORDER OF DISMISSAL (SON 1-88) re: John Doe; service not complete by\ndeadline. Entered and copies mailed 8/14/14',
#  "Case status changed to 'Needs status review' at service deadline\nreview",
#  'Court received Subpoena of Marois Brothers, Inc.',
#  "Plaintiff Todd Drolet's MOTION to amend complaint, Affidavit of\ncompliance, & cert of service",
#  'Motion (P#6) ALLOWED (David Ricciardone, Justice) Notices mailed\n3/25/2015',
#  'Amended complaint of Plaintiff Todd Drolet- CJ',
#  'Received from\nDefendant Marois Brothers Inc: Answer to amended complaint;',
#  'Service Returned for\nDefendant Marois Brothers Inc: Service through person in charge / agent;',
#  "Plaintiff Todd Drolet's  Joint Motion to extend tracking deadline(s)",
#  'off list',
#  'Petition for violation of sanitary code filed',
#  'Tenant Petition for Violation of Sanitary Code, MGL 111, S.127C\n\n\n\nDismissed Amount:         2.00\n\nDismissed Date: 08/04/2010\n\nDismissed Type: MUNICIPALITY WAIVER MGL185C SEC 19\n\nDismissed By: RAPPK\n\nComments:',
#  'R 41(a)(1) Voluntary Dismissal',
#  'Will 08/04/2004',
#  'Agreement for order against Donna M Noel in amount of 10,146.32 after mediation.\n',
#  'Origin 1, Type B19, Track A.',
#  'Standard Affirmative Oefenses of Defendant Siemens Industry, Inc.\nIncorrectly named as Successor-in-interest To Murray Electrica\nProducts l(Defendant)',
#  'Plaintiffs Robert T. Moscaritolo and Ignazia M. Moscaritolos MOTION\nto substitute parties and to amend complaint to add counts for\nwrongful death and punitive damages against all defendants; Affidavit\nof Compliance with Sup. Crt. Rule 9A',
#  'Amended ANSWER: Siemens Industry, Inc. As Successor To Murray\nElectrical',
#  'Stipulation of Dismissal ONLY as to Hobart Brothers Company without\nprejudice and without costs. The action shall remain pending against\nall other parties.',
#  "Defendant, General Electric Company's EMERGENCY MOTION For Protective\nOrder pursuant to MRCP, Plaintiff's Opposition, Defendant's Reply to\nPlaintiff's Opposition, Defendant's Objection and Motion for Review\nof the Findings of the Special Master.",
#  "Defendant Trane U.S. Inc., f/k/a American Standard Inc., f/k/a's\nMOTION to admit Tricia A. Nibarger, Esq. as counsel pro hac vice for\nTrane U.S. Inc., f/k/a American Standard Inc., f/k/a",
#  "Defendant Burnham Corporation's MOTION for leave to file Reply Brief\nto plff's opposition to deft's motion for Summary Judgment",
#  'Motion (P#32) ALLOWED (Hely, J.)',
#  "Plaintiffs' MOTION to file opposition to Defendant Trane U.S. Inc.,\nf/k/a American Standard Inc., f/k/a's Motion for Summary Judgment in\nexcess of twenty page limit of Mass. Civ. P. Rule 9A(b)(4)",
#  "Defendant Union Carbide Corporation's MOTION for leave to file\nMemorandum in excess of 20 pages",
#  "Plaintiffs' MOTION for leave to file opposition to deft, Union\nCarbide Corporation's Motion for Summary Judgment in excess of twenty\npage limit of Mass. R. Civ.P. Rule 9A(b)(4).",
#  "Defendant Union Carbide Corporation's MOTION for leave to file a\nReply in excess of ten pages to plaintiffs' opposition to deft's\nmotion for Summary Judgment.",
#  "Defendant, Graybar Electric Company, Inc's MOTION for Summary\nJudgment, pursuant to Mass.R.Civ.P. 56; Defendant, Graybar Electric\nCompany, Inc's Memorandum in support of its motion for Summary\nJudgment; Deft's Request for Hearing.",
#  "Plaintiff Ignazia M. Moscaritolo's MOTION for leave to file\nopposition to deft, Graybar Electric Company, Inc's motion for\nSummary Judgment in excess of twenty page limit of Mass. Civ. p. Rule\n9A(b)(4)",
#  "Defendant Graybar Electric Company, inc.'s MOTION for leave to file\nReply Memorandum in support of its motion for Summary Judgment",
#  "Defendant CBS Corporation, f/k/a Viacom, Inc., Successor By Merger To\nCBS's REQUEST for leave to submit a Reply in support of the Motion\nfor Summary Judgment.",
#  "Plaintiff's MOTION for leave to file opposition to defendants motion\nfor summary judgment in Excesss of Twenty Page limits of\nMASS.r.civ.p.rule 9a (b)(4)",
#  "Defendant Rockwell Automation, Inc.'s MOTION for leave to file a\nreply brief to plaintiffs; opposition to motion for summary judgment",
#  "Defendant Rockwell Automation, Inc.'s MOTION to admit Scott J. Wilkov\nEsq as counsel pro hac vice for Rockwell Automation, Inc.",
#  'Motion (P#46) ALLOWED (Hely, J.)',
#  "Defendant Rockwell Automation, Inc.'s MOTION to strike certain\ntestimony of Robert T. Moscaritolo.",
#  "Defendant Rockwell Automation, Inc.'s MOTION in limine to to adopt\nall motions in Limine by other defendants",
#  "Defendant Rockwell Automation, Inc.'s MOTION in limine to preclude\ntestimony of Mr. Moscaritolo regarding presence of Asbestos in\nAllen-Bradley Products.",
#  "Defendant Rockwell Automation, Inc.'s MOTION in limine to preclude\nintroduction of certain opinions of Dr. Holstein.",
#  "Plffs' ominibus supplement to their Opposition to deft Burnham LLC\nf/k/a Burnham Corporation's motion for summary judgment.",
#  "Defendant Cooper Crouse-Hinds, Inc.'s MOTION to strike Certain\nTestimony of Robert Moscaritolo; Plff's Opposition to Defendant\nCooper Industries, LLC's Motion to Strike Certain Testimony of Robert\nMoscaritolo.",
#  "Defendant Cooper Crouse-Hinds, Inc.'s MOTION for leave to file a\nReply Memorandum to Plff's Opposition to Defendant Cooper Industries,\nLLC's Motion to Strike Certain Testimony of Robert Moscaritolo.",
#  "Defendant, Homasote Company's MOTION to Strike Robert Moscaritolo's\nVideo Trial Testimony, Plaintiff's Opposition.",
#  "Defendant Graybar Electric Company, inc.'s MOTION to join defendant\nCooper Industries motion to strike certain testimony of Robert T\nMoscarito",
#  "Court received: Plaintiff's Supplement To Her Oppositiion to\nDefendant Union Carbide Corporation's MOTION for Summary Judgment",
#  "Defendant General Electric Company's emergency MOTION to preclude\nEugene Mark, M.D.'s trial testimony.",
#  'Stipulation of partial dismissal as to Siemens Industry, Inc., with\nprejudice, without costs.',
#  'Stipulation of partial dismissal as to Burnham LLC, with prejudice,\nwithout costs',
#  "Plaintiff's Emergency MOTION to enforce her settlement agreement with\ndefendant, Waldo Bros. Company",
#  'Stipulation of partial dismissal as to Crane Co., Individually & As\nSuccessor To National-U.S. Radiator, with prejudice, without costs',
#  "Plaintiffs' MOTION to Enforce their Settlement Agreement with\nDefendant Trane U.S. Inc., fka American Standard Inc., f/k/a\nAmerican, successor by Merger between American Radiator Company and\nGerard Dembowski, Individually And As Parent, Guardian And Next\nFriend.",
#  'Joint MOTION to dismiss General Electric Company.',
#  "See case MICV10-3860, for Plaintiffs' emergency MOTION to enforce\ntheir settlement agreements with deft CBS Corporation, Certificate of\nservice., pleading# 51",
#  'Stipulation of partial dismissal as to Trane U.S., Inc., f/k/a\nAmerican Standard Inc., fka American, with prejudice, without costs',
#  'Stipulation of partial dismissal. Pursuant To MASS.R. Civ.P.41\n(a)(1)(ii) and Pre-Trial Order No.9(V)(H), the Plaintiff, Ignazia M.\nMoscaritolo, Individually and as Executrix of the Estate of Robert\nMoscaritolo, and the Defendant Rockwell Automation, Inc., successor\nby merger to the Allen-Bradley Company, hereby jointly stipulate to a\ndismissal of all claims against the defedant Rockwell Automation,\nInc.., successor by merger to the Allen-Bradley Company only, with\nprejudice and without costs. The above-captioned action shall remain\npending against all other parties',
#  "Plaintiff Ignazia M. Moscaritolo's Emergency MOTION to enforce her\nSettlement Agreement with Defendant, ECR International, Inc.",
#  'Stipulation of partial dismissal as to Homasote Company, with\nprejudice, without costs. The above-captioned action shall remain\npending against all other parties',
#  'Joint MOTION to dismiss Waldo Bros Company',
#  'Stipulation of partial dismissal as to Graybar Electric Company,\ninc., with prejudice of all claims assertedby the palintiffs against\nGarybar ONLY in the above-captioned action and with each party to\nbear their own costs and fees. All rights of appeal are hereby waived.',
#  'Misc Entry:matter Off List',
#  'Service insufficient; plaintiff advised to obtain better address.',
#  "Misc Entry:gave defendant's notice to plaintiff for sheriff service",
#  'Service insufficient; plaintiff advised to obtain better address.',
#  'Misc Entry:Plaintiff supplied toe court with new address for def. and requests both parties notifications go to plaintiff for proper service',
#  "Misc Entry:Rec'd letter appearance of counsel for defendant.  They are trying to work something out with plaintiff's counsel",
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0 Receipt: 21669 Date: 02/13/2014',
#  'Satisfaction of judgment demonstrated and ordered noted on docket.',
#  'Misc Entry: Defendants request to continue',
#  'Misc Entry: Pltfs request to continue',
#  'SECOND SESSION, PLAINTIFF ONLY, 9:37 A.M., FLYNN, J',
#  "Findings: Summary Process Finding for Pltffs' possession and account annexed in the amount of $2250.00.  Parties notified 11/9/12.",
#  'Misc Entry:  Service  Incomplete.',
#  'Findings: and Order of Approval of Attachment on Trustee Process.',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0 Receipt: 23223 Date: 07/18/2013',
#  'Small Claims Filing FeeÂ\xa0for claim of $500 or less due.Â\xa0Â\xa0  Receipt: 3181  Date: 09/19/2011',
#  'Service insufficient; plaintiff advised to obtain better address.',
#  'Misc Entry:Military affidavit needed',
#  ' Defendant Discovery Requests\n\n',
#  'Rescheduled\n\nEvent: Summary Process Trial\n\nDate: 08/05/2010  Time: 09:00 AM\nResult: Not held but resolved',
#  'Rescheduled\n\nEvent: Review\n\nDate: 12/09/2010  Time: 09:00 AM\nResult: Held',
#  'Affidavit pursuant to Rule 10',
#  'Order',
#  'Service insufficient; plaintiff advised to obtain better address.']

# %% [markdown]
# ## Semantic Role Labelling

# %%
from allennlp.predictors.predictor import Predictor
import allennlp_models.tagging

# %%
predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz")
# Out:
# error loading _jsonnet (this is expected on Windows), treating C:\Users\dell\AppData\Local\Temp\tmpbt8nfpe9\config.json as plain json

# %%
example_1 = 'Massachusetts Estate Tax Closing Letter'
example_2 = "Motion for appointment of special process server filed by 1835 Middlesex Street Condominium Trust by its Board of Trustees."
example_3 = "Inventory filed"
example_4 = "Attorney fees waived by plaintiff(s)."

# %%
sentence = example_4
pred = predictor.predict(sentence)
words = pred['words']
for obj in pred['verbs']:
    v = obj['verb']
    tags = obj['tags']
    arg0 = ''
    arg1 = ''
    if "B-ARG0" in tags:
        start = tags.index("B-ARG0")
        end = max([i for i, x in enumerate(tags) if x == "I-ARG0"] + [start]) + 1
        arg0 = words[start:end]

    if "B-ARG1" in tags:
        start = tags.index("B-ARG1")
        end = max([i for i, x in enumerate(tags) if x == "I-ARG1"] + [start]) + 1
        arg1 = words[start:end]
        
    print('subject:',arg0)
    print('v:',v)
    print('object:',arg1)
    print('\n')
# Out:
# subject: ['by', 'plaintiff(s']
# v: waived
# object: ['Attorney', 'fees']
