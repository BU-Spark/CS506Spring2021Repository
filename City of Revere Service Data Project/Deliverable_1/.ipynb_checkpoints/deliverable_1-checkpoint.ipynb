# %%
#modules
import pandas as pd
import numpy as np

# %%
#directory for data
mainDir = '/home/gsirio/spring2021/cs506/spark/Project - City Of Revere/data_0224'
file = '/tracks_census_block_group_by_address_city_of_revere_0224.csv'

# %%
#Processing Data
df = pd.read_csv(mainDir+file,sep=',')
df.drop([1,2,3])
# Out:
# /home/gsirio/anaconda3/envs/tf-cpu-440/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (101,102,103,104,105,106,107,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Filters:                                Unnamed: 1  \
# 0             NaN                                       NaN
# 4      5-120A1-2A     36 LEE BURBANK HWY, Revere, MA, 02151
# 5          5-80-4     49 LEE BURBANK HWY, Revere, MA, 02151
# 6      5-120A1-2B     40 LEE BURBANK HWY, Revere, MA, 02151
# 7       6-120B-15    251 LEE BURBANK HWY, Revere, MA, 02151
# ...           ...                                       ...
# 15607   26-426C-1         WASHINGTON AVE, Revere, MA, 02151
# 15608   21-342C-1               BROADWAY, Revere, MA, 02151
# 15609    5-210A-1       BELLE ISLE INLET, Revere, MA, 02151
# 15610    5-210A-8          CHELSEA RIVER, Revere, MA, 02151
# ...
